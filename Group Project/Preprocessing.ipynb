# %% [markdown]
# # Library Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import csv

# %% [markdown]
# # Data Import

# %% [markdown]
# Dataset URL: https://www.aminer.org/citation

# %%
data = pd.read_csv('DBLP_citation.csv')

# %%
data
# Out:
#                                                      title  \
# 0        OQL[C++]: Extending C++ with an Object Query C...
# 1         Transaction Management in Multidatabase Systems.
# 2                             Overview of the ADDS System.
# 3        Multimedia Information Systems: Issues and App...
# 4                                 Active Database Systems.
# ...                                                    ...
# 1632437  The Structure and Properties of Color Spaces a...
# 1632438             Tremor: From Pathogenesis to Treatment
# 1632439                       Quantitative Neurophysiology
# 1632440          Access Control in Data Management Systems
# 1632441  Lung Sounds: An Advanced Signal Processing Per...
#
#                                                    authors  year  \
# 0                                     ['José A. Blakeley']  1995
# 1        ['Yuri Breitbart', 'Hector Garcia-Molina', 'Ab...  1995
# 2                       ['Yuri Breitbart', 'Tom C. Reyes']  1995
# 3           ['Stavros Christodoulakis', 'Leonidas Koveos']  1995
# 4        ['Umeshwar Dayal', 'Eric N. Hanson', 'Jennifer...  1995
# ...                                                    ...   ...
# 1632437                                    ['Eric Dubois']  2009
# 1632438               ['Giuliana Grimaldi', 'Mario Manto']  2008
# 1632439                           ['Joseph V. Tranquillo']  2008
# 1632440                                  ['Elena Ferrari']  2010
# 1632441                    ['Leontios J. Hadjileontiadis']  2008
#
#                                                      venue       id  \
# 0                                  Modern Database Systems        0
# 1                                  Modern Database Systems        1
# 2                                  Modern Database Systems        2
# 3                                  Modern Database Systems        3
# 4                                  Modern Database Systems        4
# ...                                                    ...      ...
# 1632437  The Structure and Properties of Color Spaces a...  1632437
# 1632438             Tremor: From Pathogenesis to Treatment  1632438
# 1632439                       Quantitative Neurophysiology  1632439
# 1632440          Access Control in Data Management Systems  1632440
# 1632441                                        Lung Sounds  1632441
#
#          references                                           abstract  \
# 0                []                                                NaN
# 1                []                                                NaN
# 2                []                                                NaN
# 3                []                                                NaN
# 4        ['995520']                                                NaN
# ...             ...                                                ...
# 1632437          []                                                NaN
# 1632438          []                                                NaN
# 1632439          []                                                NaN
# 1632440          []  Access control is one of the fundamental servi...
# 1632441          []                                                NaN
#
#          citation_count
# 0                     5
# 1                     0
# 2                     0
# 3                     2
# 4                    16
# ...                 ...
# 1632437               0
# 1632438               0
# 1632439               0
# 1632440               0
# 1632441               0
#
# [1632442 rows x 8 columns]
