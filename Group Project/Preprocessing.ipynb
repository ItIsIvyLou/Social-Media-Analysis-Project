# %% [markdown]
# # Library Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
import ast
from collections import Counter
import spacy
from textblob import TextBlob
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.corpus import stopwords
import re
import string

# %% [markdown]
# # Data Import

# %% [markdown]
# Dataset URL: https://www.aminer.org/citation

# %%
data = pd.read_csv('DBLP_citation.csv')

# %%
data.head(3)
# Out:
#                                                title  \
# 0  OQL[C++]: Extending C++ with an Object Query C...
# 1   Transaction Management in Multidatabase Systems.
# 2                       Overview of the ADDS System.
#
#                                              authors  year  \
# 0                               ['José A. Blakeley']  1995
# 1  ['Yuri Breitbart', 'Hector Garcia-Molina', 'Ab...  1995
# 2                 ['Yuri Breitbart', 'Tom C. Reyes']  1995
#
#                      venue  id references abstract  citation_count
# 0  Modern Database Systems   0         []      NaN               5
# 1  Modern Database Systems   1         []      NaN               0
# 2  Modern Database Systems   2         []      NaN               0

# %%
# Function to convert string-lists to Python lists
def convert_to_list(data):
    try:
        return ast.literal_eval(data)
    except:
        return []  # Returns an empty list if there's an error in conversion

# Convert the string representations to lists
data['authors'] = data['authors'].apply(convert_to_list)
data['references'] = data['references'].apply(convert_to_list)

# Convert id to string
data['id'] = data['id'].astype(str)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1632442 entries, 0 to 1632441
# Data columns (total 8 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   title           1632442 non-null  object
#  1   authors         1632442 non-null  object
#  2   year            1632442 non-null  int64
#  3   venue           1630753 non-null  object
#  4   id              1632442 non-null  object
#  5   references      1632442 non-null  object
#  6   abstract        653506 non-null   object
#  7   citation_count  1632442 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 99.6+ MB

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Missing values

# %%
data.isna().sum()
# Out:
# title                  0
# authors                0
# year                   0
# venue               1689
# id                     0
# references             0
# abstract          978936
# citation_count         0
# dtype: int64

# %%
preprocessed_data = data.copy()
preprocessed_data['abstract'] = preprocessed_data['abstract'].fillna('')
preprocessed_data['venue'] = preprocessed_data['venue'].fillna('')
preprocessed_data.isna().sum()
# Out:
# title             0
# authors           0
# year              0
# venue             0
# id                0
# references        0
# abstract          0
# citation_count    0
# dtype: int64

# %% [markdown]
# ## Create New Feature

# %%
preprocessed_data['AUTHOR_COUNT'] = preprocessed_data['authors'].apply(lambda x: len(x))
preprocessed_data['REF_COUNT'] = preprocessed_data['references'].apply(lambda x: len(x))

# %% [markdown]
# ## Rename the column

# %%
preprocessed_data.rename(columns={'citation_count': 'ISCITED_COUNT'}, inplace=True)

# %% [markdown]
# ## Delete Invalid Rows

# %%
preprocessed_data['year'].describe()
# Out:
# count    1.632442e+06
# mean     1.801409e+03
# std      6.012202e+02
# min     -1.000000e+00
# 25%      1.995000e+03
# 50%      2.003000e+03
# 75%      2.007000e+03
# max      2.011000e+03
# Name: year, dtype: float64

# %%
preprocessed_data = preprocessed_data[preprocessed_data['year'] >= 1800] # Remove the rows with year = -1

# %%
preprocessed_data.describe()
# Out:
#                year  ISCITED_COUNT  AUTHOR_COUNT     REF_COUNT
# count  1.469015e+06   1.469015e+06  1.469015e+06  1.469015e+06
# mean   2.001926e+03   1.580486e+00  2.612094e+00  1.583045e+00
# std    7.600157e+00   1.103237e+01  1.547260e+00  4.705101e+00
# min    1.936000e+03   0.000000e+00  1.000000e+00  0.000000e+00
# 25%    1.999000e+03   0.000000e+00  2.000000e+00  0.000000e+00
# 50%    2.004000e+03   0.000000e+00  2.000000e+00  0.000000e+00
# 75%    2.007000e+03   0.000000e+00  3.000000e+00  0.000000e+00
# max    2.011000e+03   4.474000e+03  1.140000e+02  6.170000e+02

# %% [markdown]
# ## Check Language

# %%
non_eng_chars = set(''.join(preprocessed_data['title'].str.replace(r'[a-zA-Z\s]+', '')))

print("Non-English characters used in the 'title' column:", non_eng_chars)
# Out:
# Non-English characters used in the 'title' column: {'č', '®', '½', '扩', 'æ', 'c', '>', ']', '·', 'T', 'ﬁ', '…', '"', '_', '制', '超', 'j', 'Ö', '中', '下', 'U', 'd', 'm', '*', '及', '方', '“', 'I', 'Δ', '1', 'ß', '展', '服', 'v', '析', '：', '8', "'", '(', '`', 'à', '关', '本', '5', 'Ê', '发', 'í', '药', 'ℓ', '匹', 'V', '@', '\x93', '<', 'è', '\\', '配', 'Ç', '系', 'ç', '&', 'ä', '³', '¹', '体', '\x97', '逻', '\x92', 'o', '¾', 'a', '络', 'µ', 'N', 'Y', 'Z', 'L', 'ê', '组', 'μ', '于', 'D', 'A', 'R', 'l', '}', '面', 'J', '-', '≠', '基', '研', 'Ó', '合', '资', 'Í', '述', 'ô', 'λ', 'ú', 'e', '\x91', '演', '«', 'Ï', 'î', 'S', 'Ô', 'Û', 'C', '学', '取', 'Ò', '护', '\x80', 'Å', '/', 'Ì', 'M', 'k', 'r', ';', '识', 'q', '{', '´', ' ', 'F', '源', '户', 'x', '过', '医', '–', '究', 'ć', '协', '现', '流', '©', '|', '理', '定', '\x9c', '义', '±', '程', '‘', 'Ü', 'g', '?', '4', 'Ω', 'W', 'π', 'å', '号', 'Q', 'Ä', 'u', 'ª', '•', '—', '息', '\x99', 'b', 'Î', '~', 'ö', '容', 'ε', 'ý', '习', '点', '建', 'é', '#', 'È', '¬', '”', 'Á', '辑', '用', 'â', '的', '算', '0', '!', 'ø', 'ó', '法', 'Ø', 'ù', '²', 'G', '网', '知', '6', 'z', '¯', 'ò', 'Õ', 'À', '$', 'E', '描', '\xad', '°', '9', '¥', 'É', 'P', 'α', ':', 'H', '[', 't', 'h', '.', '%', '=', 'á', 'ë', '符', '变', 'y', 'Ã', '务', '信', '动', '分', '3', '可', '7', '2', 'Ñ', '™', '推', 'B', 'Æ', 'û', 'i', '\x84', '¢', 'ü', '图', 'O', 'n', '×', '文', '保', '提', '内', '化', '向', '模', '调', 'ã', '+', '\x94', '\xa0', 'Â', 'η', 'ì', '种', 'ñ', '架', '»', '一', 'õ', ',', '¿', '£', 'p', '^', '自', 'K', '框', ')', 'ï', 'β', 'X', 'Ð', 'Ł', '换', '语', '§', '∞', 's', '\x96', 'Σ', 'f', 'w', '献'}

# %%
english_chars = set(string.ascii_letters + string.punctuation + ' ')

# Function to check if all characters in a title are English
def is_english(col):
    return all(char in english_chars for char in col)

# Filter the DataFrame to keep only rows with English titles
english_only_data = preprocessed_data[preprocessed_data['title'].apply(is_english)]
english_only_data = english_only_data[english_only_data['abstract'].apply(is_english)]
english_only_data = english_only_data[english_only_data['venue'].apply(is_english)]

# %% [markdown]
# ## Check Punctuation

# %%
non_alphabetic_chars_set = set(re.findall(r'[^a-zA-Z\s]', ''.join(english_only_data['title'])))
non_alphabetic_chars_list = list(non_alphabetic_chars_set)
print("List of unique non-alphabetic characters:", non_alphabetic_chars_list)
# Out:
# List of unique non-alphabetic characters: ['>', ']', '"', '_', '}', '~', '-', '*', '+', '#', ',', '!', "'", '`', '(', '^', '/', ')', ';', '{', '$', '@', '<', '\\', '|', ':', '[', '.', '%', '=', '&', '?']

# %%
for char in non_alphabetic_chars_list:
    titles_with_char = english_only_data[english_only_data['title'].str.contains(re.escape(char))]
    print(f'{char} Example:')
    print(titles_with_char['title'].iloc[3])
# Out:
# > Example:
# Turn it <u>this</u> way: grounding collaborative action with remote gestures.
# ] Example:
# Operating System Support [for Multimedia Databases].
# " Example:
# "Kage no Sekai": interactive animation of shadow based on physical action.
# _ Example:
# SA_MetaMatch: relevant document discovery through document metadata and indexing.
# } Example:
# A Lazy and Layered SMT($\mathcal{BV}$) Solver for Hard Industrial Verification Problems.
# ~ Example:
# Segmentation of Range Images in a~Quadtree.
# - Example:
# Requirements for a Performance Benchmark for Object-Oriented Database Systems.
# * Example:
# Leveraging Distance Table to Accelerate Data Location in Large-Scaled Data Intensive Grid Environment*.
# + Example:
# OZ+: An Object-Oriented Database System.
# # Example:
# Generic Programming for Scientific Computing in C++, Java, and C#.
# , Example:
# Title, Preface, Contents.
# ! Example:
# Like Rome, a mobile operator's empire wasn't built in a day!: a journey through the rise and fall of mobile network operators.
# ' Example:
# The 'Marseille Interpreter' - a Personal Perspective.
# ` Example:
# Using ``Live Information'' in a Multimedia Framework.
# ( Example:
# Open System Architecture for Controls within Automation Systems (OSACA).
# ^ Example:
# Software Offshoring ?^(a) Risks and Opportunities for Software Engineering Programs.
# / Example:
# TCP/IP Architecture, Protocols, and Services.
# ) Example:
# Open System Architecture for Controls within Automation Systems (OSACA).
# ; Example:
# A payment &amp; receipt business model in U-commerce environment.
# { Example:
# A Lazy and Layered SMT($\mathcal{BV}$) Solver for Hard Industrial Verification Problems.
# $ Example:
# An average running time analysis of a backtracking algorithm to calculate the measure of the union of hyperrectangles in $d$ dimensions.
# @ Example:
# Labeled @-Calculus: Formalism for Time-Concerned Human Factors.
# < Example:
# "<head>, <body>, Links and Code: An Introduction to Using HTML to Present Your Data".
# \ Example:
# Multiple Pass Streaming Algorithms for Learning Mixtures of Distributions in \mathbb .
# | Example:
# An O(sqrt(|v|) |E|) Algorithm for Finding Maximum Matching in General Graphs
# : Example:
# An Object-Oriented DBMS War Story: Developing a Genome Mapping Database in C++.
# [ Example:
# Operating System Support [for Multimedia Databases].
# . Example:
# Multimedia Information Systems: Issues and Approaches.
# % Example:
# %T Museum and Interactive Multimedia Information Service.
# = Example:
# A Parallel Time/Processor Tradeoff T.P=O(n^(log M)/M) for the Subset-Sum Problem.
# & Example:
# Datenbanken & Java - JDBC, SQLJ und ODMG
# ? Example:
# Logic Programming - Past or Future?

# %%
def clean_column(column):
    # Use raw strings for regex. Protect 'C++' and 'C#'
    column = column.str.replace(r'C\+\+', 'TEMPORARYCPP', regex=True)
    column = column.str.replace(r'C#', 'TEMPORARYCSHARP', regex=True)
    
    # Remove all non-alphabetic characters except spaces
    column = column.str.replace(r'[^a-zA-Z\s]', '', regex=True)
    
    # Restore 'C++' and 'C#'
    column = column.str.replace('TEMPORARYCPP', 'C++', regex=False)
    column = column.str.replace('TEMPORARYCSHARP', 'C#', regex=False)
    
    return column

# Clean the 'title', 'abstract', and 'venue' columns
clean_data = english_only_data.copy()
clean_data['title'] = clean_column(clean_data['title'])
clean_data['abstract'] = clean_column(clean_data['abstract'])
clean_data['venue'] = clean_column(clean_data['venue'])

# %%
non_alphabetic_chars_set = set(re.findall(r'[^a-zA-Z\s]', ''.join(clean_data['title'])))
non_alphabetic_chars_list = list(non_alphabetic_chars_set)
print("List of unique non-alphabetic characters:", non_alphabetic_chars_list)
# Out:
# List of unique non-alphabetic characters: ['+', '#']

# %%
for char in non_alphabetic_chars_list:
    titles_with_char = clean_data[clean_data['title'].str.contains(re.escape(char))]
    print(f'{char} Example:')
    print(titles_with_char['title'])
# Out:
# + Example:
# 0          OQLC++ Extending C++ with an Object Query Capa...
# 7          An ObjectOriented DBMS War Story Developing a ...
# 18                        C++ Bindings to an Object Database
# 99                The C++ Programming Language First Edition
# 101              The C++ Programming Language Second Edition
# 114                Advanced C++ Programming Syles and Idioms
# 134                       The Annotated C++ Reference Manual
# 156                              Inside the C++ Object Model
# 1657               WebPowered Databases The Low Level in C++
# 6527                       Programming languages OOP and C++
# 8367          Transformation from Test Language ATLAS to C++
# 9376       Transforming RTPA Mathematical Models of Syste...
# 20620      FSA An Efficient and Flexible C++ Toolkit for ...
# 25584      Abstract Interface Types in GNAT Conversions D...
# 25922              A Preprocessor Approach to Persistent C++
# 26719      Development and Performance Analysis of a Temp...
# 33477      PAMELAC++ Tight Integration of RuleBased Featu...
# 38388                          Datalog and TwoGroups and C++
# 42217      MC++ A Parallel Portable Monte Carlo Neutron T...
# 42272      An object oriented C++ approach for discrete e...
# 42324      A C++ Pooled Shared Memory Allocator for Simul...
# 42349                      Objectoriented modeling using C++
# 44437      New Development of APL Technology of Modelling...
# 44439      Translation of Nested APL to C++ Problems and ...
# 44719      The comparison of C++ and Mathematica in the g...
# 45997          From LOTOS to C++ Issues and Tool Development
# 46063      Functional Bulk Synchronous Parallel Programmi...
# 46366      An Extension of C++ for Efficient Support of S...
# 46809      Generic Programming for Scientific Computing i...
# 47020                     Dynamic Data Flow Analysis for C++
# 47309      Automatically Generating C++ Programs from LOT...
# 47405      Tool Support for Generating Passive C++ Test O...
# 49131      CORBA Java C++ and ODBMS for Distributed Web C...
# 49358      Reengineering CC++ Source Code by Transforming...
# 49976      The MGAPs programming environment and the C++ ...
# 51845                     An Executable Specification of C++
# 52896      Methodology for hardwaresoftware coverificatio...
# 54792      A Framework for Dynamic Checks in C Arrays via...
# 58827      Testing Embedded Systems by Using a C++ Script...
# 67882      A C++ Database Interface Based on the EntityRe...
# 69603                         DB  persistent objects for C++
# 70104                        A Style for Writing C++ Classes
# 70105      OR Gateway A System for Connecting C++ Applica...
# 70106         SIC  A System for Stochastic Simulation in C++
# 70107                       Concurrent RealTime Music in C++
# 70108      Implementing a LogiCBased Executable Specifica...
# 70110                            SpaceEfficient Trees in C++
# 70112              How Useful is Multiple Inheritance in C++
# 70113                                           Teaching C++
# 70114      Sharing Between Translation Units in C++ Progr...
# 70115                        Implementing Signatures for C++
# 70117                         NAPS  A C++ Project Case Study
# 70119      Sniff A Pragmatic Approach to a C++ Programmin...
# 70121                A Type Prameterization Language for C++
# 70122                          C++ From Research to Practice
# 70123                  DataLevel Parallel Programming in C++
# 70124                       Pointers to Class Members in C++
# 70125                               Lexical Closures for C++
# 70127        Modelling of Control Systems with C++ and PHIGS
# 70128                              C++ on a Parallel Machine
# 70129         HighPerformance Scientific Computing Using C++
# 70130      A C++ Class Hierarchy for Building UNIXlike Fi...
# 70132      The Separation of Interface and Implementation...
# 70135      A Portable implementation of C++ Exception Han...
# 70136      The Interaction of Pointers to Memhers and Vir...
# 70138      Automatic Detection of C++ Programming Errors ...
# 70141              Does C++ Really Need Multiple Inheritance
# 70145           Problems with Noninvasive Inheritance In C++
# 70146      Integrating the Sun Microsystems XDRRPC Protoc...
# 70148         Building WellBehaved Type Relationships in C++
# 70150      A Statically Typed Abstract Representation for...
# 70154          Debugging and Instrumentation of C++ Programs
# 70155                      Design Criteria for C++ Libraries
# 70156      A C++ Approach to Realtime Systems Task Interf...
# 70157      Pragmatic Issues in the Implementation of Flex...
# 70158                          C++ in a Changing Environment
# 70159                      Modelling Graphical Data with C++
# 70161      Supporting Truly ObjectOriented Debugging of C...
# 70162      Reliable Distributed Programming in C++ The Ar...
# 70165      Designing Portable Application Frameworks for C++
# 70166                                    A C++ Class Browser
# 70167      Garbage Collection and Runtime Typing as a C++...
# 70169                                              AvalonC++
# 70170                                  FIELD Support for C++
# 70171                     The Architecture of a C++ Compiler
# 70172      C A C++ like Language for DataParallel Computa...
# 70173               Adding New Code to a Running C++ Program
# 70174                         Implementing a Compiler in C++
# 70175                            CCEL A Metalanguage for C++
# 70177           Porting from Common Lisp with Flavors to C++
# 70178      Representing Semantically Analyzed C++ Code wi...
# 70180                           A C++ Interpreter for Scheme
# 70181                            A Copying Collector for C++
# 70182      C++ and Operating Systems Performance A Case S...
# 70183              Safe Efficient Garbage Collection for C++
# 70185       Experiences in the Design of a C++ Class Library
# 70186                               An AWK to C++ Translator
# 70187      Experiences in Writing a Distributed Particle ...
# 70189                                   C++ on the Macintosh
# 70191                   ObjectOriented Class Library for C++
# 70192      A C++ Library for Infinite Precision Floating ...
# 70195      Porting and Extending the C++ Task System with...
# 70196                                           Extended C++
# 70198      Extending the C++ Task System for RealTime Con...
# 70199      Two Extensions to C++ A Dynamic Link Editor an...
# 70201      The Object Binary Interface C++ Objects for Ev...
# 70203       An ObjectOriented Class Library for C++ Programs
# 70205                   FOGC++ A Fragmented Object Generator
# 70206                            Possible Directions for C++
# 70207                    SignatureBased Polymorphism for C++
# 70208                            Parameterized Types for C++
# 70209      Cdiff A Syntax Directed Differencer for C++ Pr...
# 70210                               Typesafe Linkage for C++
# 70211                         The C++ Information Abstractor
# 70212                   Run Time Type Identification for C++
# 70213      ObjectOriented Redesign Using C++ Experience w...
# 70214                                   A Set of C++ Classes
# 70215              Writing a ClientServer Application in C++
# 70216           Wrappers  Solving the RPC Problem in GNU C++
# 70217      Experience in Using C++ for Software System De...
# 70218           An Exception Handling Implementation for C++
# 70219              Runtime Access to Type Information in C++
# 70220                                            C++ vs Lisp
# 70221                               Writing a Gateway in C++
# 70224       Using C++ to Develop a WYSIWYG Hypertext Toolkit
# 70225                         Climbing the C++ Learning Tree
# 70226                             Exception Handling for C++
# 70228      A Poor Mans Approach to Dynamic Invocation of ...
# 70231         The Conduit A Communication Abstraction in C++
# 70234                               libg The GNU C++ Library
# 70235                                   Customization in C++
# 70237                             Type Identification in C++
# 70238                            Encapsulating a C++ Library
# 70240      LogiC++ An Integrated Logic and ObjectOriented...
# 76822      Using objects in shared memory for C++ applica...
# 76840        Concurrency abstractions in a C++ class library
# 76900      Realtime complexity metric tools for visualAge...
# 77006                     Architecture of the XL C++ browser
# 77127      Leveraging IBM visual age for C++ for reverse ...
# 77147      Grail a C++ library for finitestate machines a...
# 77183                                      Writing about C++
# 78612      Using constructors and subclasses in java and C++
# 78643      Using Z approach to objectoriented software te...
# 81422      Compilation of Generic Regular Path Expression...
# 81616                      The iRRAM Exact Arithmetic in C++
# 81618          Towards a real Real RAM a Prototype using C++
# 95950      ERC++ A Conceptual Data Model Based on Object ...
# 97996      A Tool to Automatically Detect Defects in C++ ...
# 99670                     CPPvm  Parallel Programming in C++
# 101045     Performance Evaluation and Comparison of C++ C...
# 102361     Comparative Performance Analysis of ClientServ...
# 102381     Experiences Migrating a Large Assembler Mainfr...
# 106013     Timed executable system specification of an AD...
# 110163             Runtime Support for Extended Types in C++
# 111911     A Semantics of the Separation of Interface and...
# 112173     Translating hierarchical predicate transition ...
# 112236     Heuristics for Computing Attribute Values of C...
# 112340                               ConC++ A Concurrent C++
# 112434     Measuring the Intensity of Object Coupling in ...
# 112719     IPCC++ A C++ Extension for InterProcess Commun...
# 112981       Mapping Petri Nets to Parallel Programs in CC++
# 115149     P a C++ Virtual Shared Grids Based Programming...
# 115213     TAU A Portable Parallel Program Analysis Envir...
# 116504      Building Independent Black Box Components in C++
# 116523     MiSFIT A Tool for Constructing Safe Extensible...
# 116531     Pattern Languages for Handing C++ Resources in...
# 116538        Design Patterns for Generic Programming in C++
# 116539     Preliminary Design of ADLC++  A Specification ...
# 116550     Compile Time Symbolic Derivation with C++ Temp...
# 116552        PSTLA C++ Persistent Standard Template Library
# 116553                         Embedded Programming with C++
# 116574         Program Explorer A Program Visualizer for C++
# 116575          A Framework for HigherOrder Functions in C++
# 116578            Composing Special Memory Allocators in C++
# 116584     Design Patterns for Dealing with Dual Inherita...
# 116911                        HPC++ and the HPC++Lib Toolkit
# 117514     CLab A C++ Library for Fast BacktrackFree Inte...
# 125021        Data Exchange with the Columbus Schema for C++
# 125025     A Tool for Process and Product Assessment of C...
# 125039     Weaving Aspects into C++ Applications for Vali...
# 125172     Fast Symbolic Evaluation of CC++ Preprocessing...
# 125390     SOLIDFX An Integrated Reverse Engineering Envi...
# 131530     Use of CC++ models for architecture exploratio...
# 132180     Towards a C++based design methodology facilita...
# 132244     Panel The Next HDL If C++ is the Answer What w...
# 136905     Runtime Code Generation in C++ as a Foundation...
# 136960     Generic Parallel Programming Using C++ Templat...
# 137172     DSL Implementation in MetaOCaml Template Haske...
# 138812                          The CoStLy C++ Class Library
# 139170     A Proposal to add Interval Arithmetic to the C...
# 140784     PC++ An ObjectOriented Database System for C++...
# 141901     CC++ progress or deadlock in systemlevel speci...
# 141931                          Hardware Synthesis from CC++
# 142532                   Hardware Synthesis from CC++ Models
# 142721     Techniques to Evolve a C++ Based System Design...
# 143206                         System Level Design Using C++
# 145064     Designing Linguistic Interfaces to an Object D...
# 147276     ObjectOriented Distributed Computing with C++ ...
# 147284             DCE Distributing C++Objects using OSF DCE
# 149268     Making C++ Object Persistent by Using a Standa...
# 149815      Design and Implementation of the spareC++ OODBPL
# 160223     Reliable Servers Design and Implementation in ...
# 161495     A CC++ SourcetoSource Compiler for Dependable ...
# 167504     Automated Translation of CC++ Models into a Sy...
# 167524           Validation and testing of sC++ applications
# 172915      PANDA  Supporting Distributed Programming in C++
# 173045     Bridging the Gap Between C++ and Relational Da...
# 173208                             On the Darker Side of C++
# 173224             Persistence and Migration for C++ Objects
# 173233     Modeling the C++ Object Model An Application o...
# 173287                  A Semantic Analysis of C++ Templates
# 173622     ROSE An Optimizing Transformation System for C...
# 173969     Requirements Issues for Performance Tools for ...
# 173981     Molecular Dynamics with C++ An ObjectOriented ...
# 174041       A Concurrency Control Mechanism for C++ Objects
# 174053     A Reflective Architecture for an Adaptable Obj...
# 174074             An OO Approach to C++ Compiler Technology
# 174216     Adapting C++ Exception Handling to an Extended...
# 174234     Handling Multiple Concurrent Exceptions in C++...
# 183379     Implementation of Automatic Lock Determination...
# 188067     A C++ Data Model Supporting Reachability Analy...
# 191451     Automatic Design Patterns Identification of C+...
# 195284     HWSW CoSimulation of Target C++ Applications a...
# 195964     The Design of an API for Strict Multithreading...
# 197914             Autoparallelisation of Sieve C++ Programs
# 202116     Improving the Build Architecture of Legacy CC+...
# 203254     A C++ compiler for FPGA custom execution units...
# 203495     Design of C++ Class Library and BitSerial Comp...
# 203789     Static Computation of Polynomialtime Functions...
# 203834     Extending C++ Static Computation of Polynomial...
# 207326     Forecasting Stock Returns Using Genetic Progra...
# 208657          Combining VDMSL Specifications with C++ Code
# 209386     Orion HighPrecision Methods for Static Error A...
# 212381     A C++ Binding for Penguin a System for Data Sh...
# 213303     Automatic Code Generation for SDL to C++ for a...
# 213458        Framework for Automatic SDL to C++ Translation
# 215558     A FPL Prototyping Package with a C++ Interface...
# 216286     C++ based design flow for reconfigurable image...
# 222634                RC++ A Rule Based Language for Game AI
# 222838                     ParoC++ Extending C++ to the Grid
# 224587                 C++ Function Object Binders Made Easy
# 224602                         MixinBased Programming in C++
# 225914     Open BEAGLE A New C++ Evolutionary Computation...
# 225915     Open BEAGLE A New Versatile C++ Framework for ...
# 235609     Generic Advice On the Combination of AOP with ...
# 235624     FeatureC++ On the Symbiosis of FeatureOriented...
# 235653                   Debugging C++ template metaprograms
# 235730     AOP A Generic AspectOriented Programming Frame...
# 235736     An Extension to the Subtype Relationship in C+...
# 242992     Parallel C++ Programming System on Cluster of ...
# 247886     Static and Dynamic Weaving in System Software ...
# 251162     XCATC++ Design and Performance of a Distribute...
# 251477     A Generic C++ Framework for Parallel MeshBased...
# 251494     ParoC++ A Requirementdriven Parallel Objectori...
# 253811     Design of HighPerformance C++ Package for Hand...
# 253845          EC++  EUROPA Parallel C++ A Draft Definition
# 254001     Experiences with the C++ Standard Template Lib...
# 254450            MPC++ Performance for Commodity Clustering
# 254633                                  High performance C++
# 254691     An Enhanced CC++ and FORTRAN API to Posix Threads
# 260517      On Facilitating the Reuse of C++ Graph Libraries
# 279719     ParoC++ A RequirementDriven Parallel ObjectOri...
# 280195               ClassdescMP Easy MPI Programming in C++
# 286528     AC++ Based Environment for Analog Circuit Simu...
# 286636     Interfacing Hardware and Software Using C++ Cl...
# 289082                              Rules in an Extended C++
# 289102                             On the Concurrency of C++
# 289505     Customizing C++ to Improve the Reusability of ...
# 308931                 Abstraction and the C++ Machine Model
# 310005     Functional Style in C++ Closures Late Binding ...
# 310041                         Functional programming in C++
# 310237                   Scrap scrap your boilerplate in C++
# 311938     An Image Processing Library Based on Abstract ...
# 341366     ObjectOriented EaseBased Parallel Primitives i...
# 342335                Portable Parallel Programming in HPC++
# 343026     A Method for Automatic Optimization of Dynamic...
# 344859     An Effective Strategy for Porting C++ Applicat...
# 351691                            Specifying Behavior in C++
# 360289     HPC++ Experiments with the Parallel Standard T...
# 361507       An Investigation into Coupling Measures for C++
# 361629     NonIntrusive Object Introspection in C++ Archi...
# 362200                    Using OCLQueries for Debugging C++
# 362518     MoHCAJava A Tool for C++ to Java Conversion Su...
# 363041     RoundTrip Engineering with Design Patterns UML...
# 363274     Flow Insensitive C++ Pointers and Polymorphism...
# 364135     Application and user interface migration from ...
# 364163           Mining Design Patterns from C++ Source Code
# 364225                  Restructuring Legacy C Code into C++
# 364235     Columbus  Reverse Engineering Tool and Schema ...
# 364383     CC++ Conditional Compilation Analysis using Sy...
# 364764     Reverse Engineering of the UML Class Diagram f...
# 364765     Static and Dynamic C++ Code Analysis for the R...
# 364766     Reverse Engineering of the Interaction Diagram...
# 364783     A collection of C C++ and Java code understand...
# 366728     A Unified Approach to Abstract Interpretation ...
# 367054           Interval Constraint Satisfaction Tool INC++
# 367212               MLC++ A Machine Learning Library in C++
# 367214     Data Mining Using MLC++ A Machine Learning Lib...
# 371072      MetadataBased XML Serialization for Embedded C++
# 397195     Bayesian and Fuzzy Logic Student Model in the ...
# 398944                          TURTLE  A CIPLibrary for C++
# 408114     C++ Expression Templates Performance Issues in...
# 408768     A Capabilities Based Communication Model for H...
# 408830     A C++ Implementation of the CoArray Programmin...
# 408996     A Generic C++ Framework for Parallel Mesh Base...
# 410243     ParoC++ A RequirementDriven Parallel ObjectOri...
# 410789     A Verified Integration of Parallel Programming...
# 411062     Integrating Functional and Imperative Parallel...
# 411637     Automatically translating a general purpose C+...
# 412319     C++ based System Synthesis of RealTime Video P...
# 412591     Efficient automated marshaling of C++ data str...
# 416246     Simulating Agent Based Processing in an ADS Us...
# 429627     DCim a C++ library for object oriented hardwar...
# 433960                       Will C++ Be Faster than Fortran
# 433962     Design and Performance Improvement of a RealWo...
# 433978     Evaluation High Level Parallel Programming Sup...
# 433984              Automatic RunTime Code Generation in C++
# 433988     A Framework for Parallel Adaptive Finite Eleme...
# 433989     Janus A C++ Template Library for Parallel Dyna...
# 434002     Processing Sparse Vectors During Compile Time ...
# 434009                 MC++and a Transport Physics Framework
# 434014     Parallel Array Class Implementation Using C++ ...
# 434015     Towards a Parallel C++ Programming Language Ba...
# 438285     Design and Application of a C++ Macromolecular...
# 444141     On Providing a HighLevel C Interface for an Ob...
# 444399     Program Instrumentation for Debugging and Moni...
# 444790     ICC++AC++ Dialect for High Performance Paralle...
# 444812     Design of an Integrated and Extensible C++ Pro...
# 444824     Using C++ Templates to Implement RoleBased Des...
# 446100     Balinda C++ Runtime Support for Concurrent Obj...
# 450274     A Parameterized Cost Model to Order Classes fo...
# 450573     Interoperability as a design issue in C++ base...
# 458734     ModelBased Reasoning for Domain Modeling in a ...
# 465161                                     GCcooperative C++
# 465375     An Empirical Study of the Use of Friends in C+...
# 465415                Program Visualisation using C++ Lenses
# 465443            An XMLBased Lightweight C++ Fact Extractor
# 465458     Data Mining Source Code to Facilitate Program ...
# 465706     Combining Preprocessor Slicing with CC++ Langu...
# 465853     Structural analysis and visualization of C++ c...
# 466792     Developing a practical parallel multipass rend...
# 466814     Higherorder functions and partial applications...
# 470711                    Generative Programming GP with C++
# 470753                Implicit and Dynamic Parameters in C++
# 471881     An Automated ObjectOriented Testing for C++ In...
# 472038     Verifying C++ with STL containers via predicat...
# 481027                        Preliminary Design of LarchC++
# 482965     Compositional C++ Compositional Parallel Progr...
# 483101     RunTime Fusion of MPI Calls in a Parallel C++ ...
# 484094                  Sweet Harmony The TalkC++ Connection
# 492249     Bridging CSP and C++ with Selective Formalism ...
# 492871     Measurement of Change Stable and ChangeProne C...
# 504287     Speedy An Integrated Performance Extrapolation...
# 520686     A Distributed ObjectOriented Platform Based on...
# 521574       An Aggregation Model and its C++ Implementation
# 521779     Program transformations for reengineering C++ ...
# 521861     Variant management for embedded software produ...
# 521984                         A Metaobject Protocol for C++
# 522053     Scopira an open source C++ framework for biome...
# 522094                         Hard realtime C++ versus RTSJ
# 522253     The dynamics of changing dynamic memory alloca...
# 522325     Function Minimization and Automatic Differenti...
# 522352     CHARM A Portable Concurrent Object Oriented Sy...
# 522660                  Issues in Moving from C to C++ Panel
# 522759     CViMe viewing conditionally compiled CC++ sour...
# 522833                      Slicing Class Hierarchies in C++
# 522884     Preliminary Defect Data from the Iterative Dev...
# 522889     An operational semantics and type safety proof...
# 522895     ET  An ObjectOriented Application Framework in...
# 522999                          CUTE C++ unit testing easier
# 523141     Refactoring support for the C++ development to...
# 523977           A C++ Native Interface for Interpreted JVMs
# 525801     Experimental Version of Parallel Programs Tran...
# 526033     Object Serialization and Remote Exception Patt...
# 529397     Parallelization of the C++ NavierStokes Solver...
# 529544       Generic Locking and DeadlockPrevention with C++
# 530808     Data Dependences Critical Path Evaluation at C...
# 534138     Modelling Agents in C++CL for ContentBased Ima...
# 534934       ObjectOriented Data Parallel Programming in C++
# 536869     DPC++ ObjectOriented Programming Applied to Cl...
# 538269                   C++ Templates as Partial Evaluation
# 542648     Algorithm specialization in generic programmin...
# 542799                     A Member Lookup Algorithm for C++
# 543547                    The RAPID C++ Environment Abstract
# 545875     Reducing Indirect Function call Overhead in C+...
# 546129                      A MarkandSweep Collector for C++
# 546673                               Specifying C++ concepts
# 547105           Two Approaches to Adding Persistence to C++
# 548259     pC++streams a Library for IO on Complex Distri...
# 548438     Efficient onthefly data race detection in mult...
# 549222     Programming with the HPC++ Parallel Standard T...
# 549316     MC++ Parallel Portable Monte Carlo Neutron Tra...
# 549688     Tip C++ A Parallel Programming Model Based on ...
# 552762     Measuring the ObjectOriented Properties in Sma...
# 554720               An Overview of MPC++  Extended Abstract
# 555901     ComputerAssisted Generation of PVMC++ Programs...
# 555904                  YLC A C++ Linda System on Top of PVM
# 555913                                    CPPvm  C++ and PVM
# 556007                  Modernizing the C++ Interface to MPI
# 556439     VisOOMPI Visual Tool for Automatic Code Genera...
# 557951     Rolebased access control for objectorientedC++...
# 559480     OMPC++  A Portable HighPerformance Implementat...
# 560312                                  SBC++ Simulator Team
# 562535     Efficient ClockCycle Precise Simulation at Arc...
# 562650     A CC++Based Functional Verification Framework ...
# 563984     The realtime behavior of dynamic memory manage...
# 566725                  Cappuccino  A C++ to Java translator
# 566797               C++ style class support under FIG Forth
# 567403     Virtual namespace functions an alternative to ...
# 567419      The design of an OCL querybased debugger for C++
# 567571     A mechanism for automatic object locking in C+...
# 567698     An enabling optimization for C++ virtual funct...
# 567769     An objectoriented design and implementation of...
# 568594                            Typesafe covariance in C++
# 568977                            Variadic templates for C++
# 569251     A C++ environment for dynamic unanticipated so...
# 574692     Implementing a parallel C++ runtime system for...
# 575472               Parallel CC++ convergence or divergence
# 575686     Poster reception  The SAGA C++ reference imple...
# 576778     Design of the CodeBoost Transformation System ...
# 576874     Specifying the Law of Demeter and C++ Programm...
# 576888             Evaluating C++ Design Pattern Miner Tools
# 576934     An Empirical Study of Function Overloading in C++
# 578555     An Automated C++ Code and Data Partitioning Fr...
# 579538                          C++ ist typsicher Garantiert
# 581825     TILCO Temporal Logic for RealTime Systems Impl...
# 581897     The Design of a Class Library to Support Teach...
# 583056     A C++ Framework for Developing Component Based...
# 583107     Reverse Engineering Interface Protocols for Co...
# 585020     DPET  A Simple C++ Design Pattern Extraction Tool
# 585144     Integration of Wrapper Preprocessor into CC++ ...
# 585420     A Tool to Automatically Generate Test Cases fo...
# 585521     Evaluation Issues in Generic Programming with ...
# 585522          Aspects of Memory Management in Java and C++
# 585786     A Garbage Collector Prototype for C++ Applicat...
# 586345     Implementation of an Obfuscation Tool for CC++...
# 586493                            Functional concepts in C++
# 587863                   Using ASIS to generate C++ bindings
# 588203                           A Comparison of Ada and C++
# 589649     Using classes early an objectbased approach to...
# 589705     Teaching parameter passing by example using th...
# 590055                  Teaching C++ to high school students
# 590085               Yet more Web exercises for learning C++
# 590106     The power of OOPS abstract heterogeneous data ...
# 590733     Changes in the advanced placement computer sci...
# 590774                  Software engineering C++ and Windows
# 590813     Teaching OOP in C++ using an artificial life f...
# 590835     Checkmate cornering C++ dynamic memory errors ...
# 590874     Function objects function templates and passag...
# 590875     A model C++ tree iterator class for binary sea...
# 590876            Automatic array algorithm animation in C++
# 590910     Objectoriented simulation of computer architec...
# 591002     Objectoriented design and programming an Eiffe...
# 591094            Advanced placement transition to C++ panel
# 591266     Using an environment chain model to teach inhe...
# 591748     Data space animation for learning the semantic...
# 600910                                       Distributed C++
# 600919     P a Parallel C++ Array Class Library for Archi...
# 601189     The Architecture of Montana An Open and Extens...
# 601289     Program Generalization for Software Reuse From...
# 606407      Test Bed for Plain CC++ Protocol Implementations
# 608672               Compiling C++ Programs to Java Bytecode
# 609639             On Typesafe Aspect Implementations in C++
# 612803     An interactive reverse engineering environment...
# 612813     HDPV interactive faithful invivo runtime state...
# 612828     Exploiting UML dynamic object modeling for the...
# 615026                             Compiling Distributed C++
# 615622     Directed Error Detection in C++ with the Assem...
# 616465            Opening Up The CC++ Preprocessor Black Box
# 617070     Issues in the Design of a Reflective Library f...
# 625090        Modeling and Verification of SC++ Applications
# 626168     Automatic Generation of Graphical User Interfa...
# 626337     A C++ class supporting statedeficient adjoint ...
# 635986     OODCE A C++ Framework for the OSF Distributed ...
# 636064     CSE  A C++ Servlet Environment for HighPerform...
# 638027                 Irregular DataParallel Objects in C++
# 642640     Building a Laboratory Information System Aroun...
# 653100          Union Schemas as a Basis for a C++ Extractor
# 653151                    Towards a Standard Schema for CC++
# 653352     Mappings for Accurately Reverse Engineering UM...
# 653379     An Experimentation Framework for Evaluating Di...
# 653391     An Automated Approach to Grammar Recovery for ...
# 661529                          FIRE Lite FAs and REs in C++
# 662081     Automatic Precompiled Headers Speeding up C++ ...
# 666047     Managing C++ OpenMP Code and Its Exception Han...
# 666065     A C++ Infrastructure for Automatic Introductio...
# 667843     DISC++ A C++ based library for object oriented...
# 668556     SimPack Getting Started with Simulation Progra...
# 669215       ObjectOriented Modeling and Simulation with C++
# 669216           Design of objectoriented simulations in C++
# 669217           Design of ObjectOriented Simulations in C++
# 669218           Design of ObjectOriented Simulations in C++
# 669219     An Introduction to ObjectOriented Simulation i...
# 669222          Building objectoriented simulations with C++
# 670919         Incremental state saving in SPEEDES using C++
# 676698              From ObjectZ to C++ A Structural Mapping
# 678175     A Feature Composition Problem and a Solution B...
# 678185     Implementation of a Finite State Machine with ...
# 685385     McC and Mc Unified C++ and C# Design Facts Ext...
# 690971         Programmation logique sous contraintes en C++
# 693150     Contrasting branch characteristics and branch ...
# 694729     Integrating Wireless Sensor Networks and the G...
# 698836                                        OOP via C++ C#
# 698940                 Online tutors for C++Java programming
# 698977     Webbased tutors for learning programming in C+...
# 702568                                   C  C++  JavaMM Java
# 708763     Usage modelbased automated testing of C++ temp...
# 709064     Design and Implementation of the Decompiler fo...
# 710920     IDE Support for testdriven development and aut...
# 717513     Teaching CC++ to computer science students wit...
# 718447     FLOPC++ An Algebraic Modeling Language Embedde...
# 719268     YetiSim a C++ simulation library with executio...
# 719560     Prototyping of a WLAN system using C++ based a...
# 719994     Problems Workarounds and Possible Solutions Im...
# 730526     A Comparison of CC++based SoftwareHardware Cod...
# 730729     Dynamic Demo System of Data Structure with C++MFC
# 731286                        Advances in AOP with AspectC++
# 732299     Overcoming issues to reach full adoption and b...
# 732328     Building heterogeneous plaftorm simulators in C++
# 732330     Performance Analysis and Automated C++ Modular...
# 732341     Fast BitAccurate C++ Datatypes For Functional ...
# 732427     A ToolSet for Table Based Direct Behavioral Co...
# 739022     Are scripting languages any good A validation ...
# 741854     Recognizing Design Patterns in C++ Programs wi...
# 753246                        C++ in Safety Critical Systems
# 753299     Software assessment using metrics A comparison...
# 763214     Design and application of PDBlib a C++ macromo...
# 764783     NCL a C++ class library for interpreting data ...
# 766204     libsequence a C++ class library for evolutiona...
# 766284     Objectoriented sequence analysis SCL  a C++ cl...
# 766614     Cluster Analyzer for Transcription Sites CATS ...
# 768432     libcov A C++ bioinformatic library to manipula...
# 768510     Bio a set of C++ libraries for sequence analys...
# 770455     Designing and Implementing Choices An ObjectOr...
# 775207     Comparing Java vs CC++ Efficiency Differences ...
# 786564                     Optimizing C++ Vector Expressions
# 786570                             Tensor Contraction in C++
# 788003                   Some Aspects of Binding GKS to C++
# 788518         CHC++ Coherent Hierarchical Culling Revisited
# 792244     A study of dynamic memory management in C++ pr...
# 792336                           C++ Solving Cs Shortcomings
# 792538     A type system for static and dynamic checking ...
# 792819     Adaptive resource utilization and remote acces...
# 806226     Inheritance of Synchronization and Recovery Pr...
# 806240           Improving C++ Performance Using Temporaries
# 807760     Synchronous C++ A Language for Interactive App...
# 810204     Java RMI performance and object model interope...
# 810561     Features from functional programming for a C++...
# 810562                       OpenMP versus threading in CC++
# 811071     MultiRace efficient onthefly data race detecti...
# 811305     Exception handling for a communicatingsequenti...
# 816602     A simple C++ library for manipulating scientif...
# 817735               ClassdescMP Easy MPI programming in C++
# 818633        Running C++ models undet the Swarm environment
# 818634       EcoLab Agent Based Modeling for C++ programmers
# 818663     Recursive function templates as a solution of ...
# 819065           Why C++ is not very fit for GUI programming
# 819074     C++ programming language for an abstract massi...
# 819075     Multimethods and separate static typechecking ...
# 819157                        A system for reflection in C++
# 819196                   C++ Templates as Partial Evaluation
# 819375      A Reasonable C++ Wrappered Java Native Interface
# 819380     Matrix Distributed Processing A set of C++ Too...
# 819385     LSJK  a C++ library for arbitraryprecision num...
# 821369     Classdesc and Graphcode support for scientific...
# 824985     Towards a diagrammatic modeling of the LinBox ...
# 825189     Checking C++ Programs for Dimensional Consistency
# 833304           Reliable RealTime Garbage Collection of C++
# 833310                      A Stub Generation System for C++
# 833342       A Critique of the Inheritance Principles of C++
# 833345     Controversy The Case Against Multiple Inherita...
# 833372                              TypeSafe Linkage for C++
# 833374                            Parametrized Types for C++
# 833378                          Multiple Inheritance for C++
# 833388     Controversy The Case for Multiple Inheritance ...
# 833402                                        YACC meets C++
# 856248     Review  Implementation of Automatic Lock Deter...
# 856471     DC++ distributed objectoriented system support...
# 858940     A DT Roundtable SystemonChip Specification and...
# 859295       Automatic Template Instantiation in DIGITAL C++
# 859316     Alias Analysis in the DEC C and DIGITAL C++ Co...
# 859320     Measurement and Analysis of C and C++ Performance
# 860139              The Computational Power of Compiling C++
# 870229     Symbolic and Abstract Interpretation for CC++ ...
# 870501     A Framework for Reverse Engineering Large C++ ...
# 891663               ABC++ Concurrency by Inheritance in C++
# 893607               Objectoriented preprocessor fit for C++
# 894617     Secure Coding in C and C++ Of Strings and Inte...
# 903107     Data Mining Using a Machine Learning Library i...
# 910557     The execution kernel of RC++ RETE a faster RET...
# 924336     Performance and power evaluation of C++ object...
# 924349     Translating hierarchical predicate transition ...
# 924396     LOD A C++ extension for OODBMSs with orthogona...
# 924938     An investigation of coupling reuse and mainten...
# 925044     Recovering UML class models from C++ A detaile...
# 925141     Mapping Petri nets to concurrent programs in CC++
# 925209     Enhanced reusability via polymorphic additive ...
# 926040      C++ im Nebenfachstudium Konzepte und Erfahrungen
# 928593                 Developing Web Services for C and C++
# 981010          Functional programming with the FC++ library
# 983434     Some Complexity Metrics for ObjectOriented Pro...
# 987141                   Effective C++ Learning and Teaching
# 987167                      An Afternoon with Eiffel and C++
# 987180        An Assessment of ObjectOriented Method and C++
# 987239                          A Quick Overview of LarchC++
# 987295                C++ Boundary Conditions and Edge Cases
# 987297                          Performance Testing C++ Code
# 987330             Complexity in C++ A Smalltalk Perspective
# 987335                              Surrogate Classes in C++
# 987367                               C++ as a First Language
# 987375       Garbage Collection in C++ No Panacea but Useful
# 987381                   C++ in the Classroom A Look Forward
# 987387                                       A decade of C++
# 987410                              A Standard C++ Appetizer
# 987412                                 Teaching Standard C++
# 987431     Direct Mapping of ObjectOriented Analysis Mode...
# 987470                            Resource Management in C++
# 987500     Forced Inheritance A New Approach for Providin...
# 987505     Moving from COBOL to C and C++ OOPs Biggest Ch...
# 987507                               Class Assertions in C++
# 987509     Incorporation and Implementation of Logical Ob...
# 987547        How to Roll your own Persistent Objects in C++
# 987561            IPCC++ InterProcess Communication with C++
# 987562                          Extensible Subobjects in C++
# 987563     IPCC++ A Concurrent C++ Based on a SharedMemor...
# 987567                             Using C++ Class Templates
# 987597     Incremental Loading in the Persistent C++ Lang...
# 987601         An ExceptionBased Assertion Mechanism for C++
# 987786             Global and Local Virtual Functions in C++
# 987869     Constructing persistent objectoriented models ...
# 987986     An efficient tool for recovering Design Patter...
# 988009                  ABS Assertion Based Subtyping in C++
# 988570     Para A High Level C++ Interface for Message Pa...
# 990429                               Metaprogramming and C++
# 994521      Grail A C++ Library for Automata and Expressions
# 995466     Framework of a multitasking C++ based programm...
# 995815     A study of the allocation behavior of C++ prog...
# 995858     On the study of software reuse using reusable ...
# 995970     Use of friends in C++ software an empirical in...
# 996653     Software reuse using C++ classes The question ...
# 997457     Coupling measures and change ripples in C++ ap...
# 1002024    Refining an ASM Specification of the Productio...
# 1002173             Compiling Abstract State Machines to C++
# 1004519           The design and implementation of AspectC++
# 1005730            C++ Common LispCLOS Eiffel oder Smalltalk
# 1008178    The Detection of Dangling References in C++ Pr...
# 1028657          A technique for tracing memory leaks in C++
# 1028664               Extending compound assignments for C++
# 1028676    Sniff a pragmatic approach to a C++ programmin...
# 1028835    The design and management of C++ class librari...
# 1028862              Writing efficient C++ programs abstract
# 1028892            Texas good fast cheap persistence for C++
# 1028906    Why C++ is not just an objectoriented programm...
# 1035888    Quaff efficient C++ design for parallel skeletons
# 1037698    Data Parallelism in C++ Template Programs a Ba...
# 1037773           DatTel A DataParallel C++ Template Library
# 1050635    A Constructive Criticism of the CC++ Proposal ...
# 1050821        Alberth O Precise Numerical Methods Using C++
# 1054235    An object oriented approach to parser generati...
# 1057220              Cjj a subset of C++ compliant with Java
# 1066968                     The C++ Interface in Objectivity
# 1066975                       Concurrency Annotations in C++
# 1067033                                 Java as a Better C++
# 1067150    Porting the mcc PowerPC CC++ Compiler into an ...
# 1067187                               Managing C++ libraries
# 1067201                Parsing with C++ Deferred Expressions
# 1067226    Consummating Virtuality to Support More Polymo...
# 1067232    A New Iteration Mechanism for The C++ Programm...
# 1067280                                Multithreading in C++
# 1067288       COST Common Object Support Toolkit C++ Toolbox
# 1067331     Two flaws of the current C++ language definition
# 1067359                Evolution of the C++ Standard Library
# 1067387       Uniprep  Preparing a CC++ Compiler for Unicode
# 1067431     A PathBased Method of Parallelizing C++ Programs
# 1067438         Generics in Java and C++ a comparative model
# 1067447         Iterators Evaluate Table Queries C++ Toolbox
# 1067502    C++ for Scientific Applications of Iterative N...
# 1067509                   Making C++ Concurrent and Realtime
# 1067516                          Using YACC and Lex with C++
# 1067518                        Parsing with C++ Constructors
# 1067554                     On the objectorientedness of C++
# 1067572     NDC++ An Approach to Concurrent Extension of C++
# 1067620             Monitoring Remote Sensing Devices in C++
# 1067679    Interactors A RealTime Executive with Multipar...
# 1067756                   Effective use of Assertions in C++
# 1067765                       Template Instantiation For C++
# 1067779    Functional Programming in C++ using the FC++ L...
# 1067781    Developing a Tool for Memoizing Functions in C...
# 1067801    The International Workshop on Parallel C++ IWP...
# 1067853    A Framework for Programming Denotational Seman...
# 1067942                         Java will be faster than C++
# 1067954    Using Producer and Consumer Manipulators to Ex...
# 1067975               Optimizing Away C++ Exception Handling
# 1067984           Lazy evaluation of C++ static constructors
# 1067997                                    Lazy Lists in C++
# 1068003     Implementation of a Database Factory C++ Toolbox
# 1068004               Comments on the law of demeter and C++
# 1068021    Some issues on the translator of Smalltalk to C++
# 1068041    An example of multiple inheritance in C++ a mo...
# 1068048    Adapters and Binders  Overcoming Problems in t...
# 1068063                         C++ versus LISP a case study
# 1068073           Fully static dimensional analysis with C++
# 1068120       XVF C++ introspection by extensible visitation
# 1068144                             The paradigm of open C++
# 1068145                      Macros for defining C++ classes
# 1068153    PointExtent Pattern for Dimensional Numeric Cl...
# 1068167                  C++s destructors can be destructive
# 1068176      ObjectOriented Programming in C++  A Case Study
# 1068178    A practical example of multiple inheritance in...
# 1068192    Casting in C++ Bringing Safety and Smartness t...
# 1068194    A New Resource for C++ Programmers and an Invi...
# 1068214    Raw pointers in application classes of C++ con...
# 1068338    Experience in Teaching ObjectOriented Programm...
# 1068546    Mixedsignal modeling with AleC++ Specific feat...
# 1069192    An improved method of selecting regression tes...
# 1071738                             C++ Programming Language
# 1072248    Multimethods in C++ using recursive deferred d...
# 1073065             Dynamic compilation of C++ template code
# 1073172    A domain specific embedded language in C++ for...
# 1073191                     A C++ Class for RuleBase Objects
# 1073198    Sensitivity Analysis of a Dynamical System Usi...
# 1073202    Distributed pC++ Basic Ideas for an Object Par...
# 1073209                 C++ and Massively Parallel Computers
# 1073212    Applications Demand ClassSpecific Optimization...
# 1073355    A Customisable Memory Management Framework for...
# 1073467    Multipletype objects in an enhanced C++ persis...
# 1073472    Signatures A Language Extension for Improving ...
# 1073578    Making C++ Objects Persistent the Hidden Pointers
# 1073630       Concurrency in the Objectoriented Language C++
# 1073673    Evaluating High Level Parallel Programming Sup...
# 1073693             Nonintrusive object introspection in C++
# 1073843    DESPC++ a discreteevent simulation package for...
# 1073875    Memory Allocation Costs in Large C and C++ Pro...
# 1073883    Flexible Symbol Table Structures for Compiling...
# 1074054    MultiArray a C++ library for generic programmi...
# 1074071    Concurrent C++ Concurrent Programming with Cla...
# 1074106     An ObjectOriented Class Library for C++ Programs
# 1074184             Issues in Porting Software from C to C++
# 1074356         Implementing Interactive Applications in C++
# 1074369          The Lambda Library unnamed functions in C++
# 1074475                    Foundations for Native C++ Styles
# 1074754                                List Iterators in C++
# 1074865            A RuleBased Extension to the C++ Language
# 1074905    GLU embedded in C++ a marriage between multidi...
# 1074910    Illustrating Client and Implementation Readabi...
# 1074912    Java Native Interface idioms for C++ class hie...
# 1074948    Comparing Observed Bug and Productivity Rates ...
# 1074960    An Efficient and Flexible C++ Library for Conc...
# 1075104    Design and Implementation Aspects of an Experi...
# 1075126    LOCAL A C++ framework for local search algorithms
# 1075166    A C++ Simulator Generator from Graphical Speci...
# 1075195       FC++ Functional tools for objectoriented tasks
# 1075275    Smart Enumeration in C++ Virtual Construction ...
# 1075307                                PARC++ A Parallel C++
# 1075350    Scientific computing with Java and C++ a case ...
# 1075441     Measuring Complexity in C++ Application Software
# 1075507       On Efficiency and Optimization of C++ Programs
# 1075513    Arithmetic Equality Constraints as C++ Statements
# 1075900    Correlation between AmountofReuse Metrics and ...
# 1076119       Parallel ObjectOriented Programming with QPC++
# 1076161    Error Detection in C++ through Dynamic Data Fl...
# 1076175    An online C++ class implementation and experience
# 1076205    A lightweight class library for extended persi...
# 1076238                     The Darker Side of C++ Revisited
# 1076247    Coupling a C++ Class with Existing Software A ...
# 1077018           Regression Test Selection for C++ Software
# 1089677    Implementing exact real arithmetic in python C...
# 1098554    Converging CSP specifications and C++ programm...
# 1120558    A framework for serviceoriented computing with...
# 1121319    C++ classes for linking optimization with comp...
# 1121808    Hybrid differentiation strategies for simulati...
# 1123212                      Implementing Signatures for C++
# 1127738    AC++ Data Model Supporting Reachability Analys...
# 1129757       Dynamic Verification of C++ Generic Algorithms
# 1129824             Using Larch to Specify AvalonC++ Objects
# 1137708    A Visual Interface for Effortless Animation of...
# 1178410    lsjk  a C++ library for arbitraryprecision num...
# 1178770    An objectoriented C++ implementation of Davids...
# 1179737    Usage modelbased automated testing of C++ temp...
# 1179761    An approach to implementing dynamic adaptation...
# 1182425       A denotational tracing domain for C++ programs
# 1182785    The treatment of deep vs shallow copy in intro...
# 1182919                Tracing the execution of C++ programs
# 1186235       From C++ Refactorings to Graph Transformations
# 1186330    Type Checking C++ Template Instantiation by Gr...
# 1202669    An Analysis of Faulty and FaultFree C++ Classe...
# 1205759    Generic Libraries in C++ with Concepts from Hi...
# 1210919          Garbage collection in the next C++ standard
# 1219688    SeqAn An efficient generic C++ library for seq...
# 1222123       Towards the Modularization of C++ Concept Maps
# 1225063    External Memory Search for Verification of Mul...
# 1226005    Combining preprocessor slicing with CC++ langu...
# 1232745    Supporting Students in C++ Programming Courses...
# 1243732    Analysis and Code Model Extraction for CC++ So...
# 1245630    Abstracting the template instantiation relatio...
# 1252761        Hash Table Performance in SAS C++ Java and VB
# 1253550       Towards transactional memory semantics for C++
# 1257669    A C++ Workbench with Accurate NonBlocking Garb...
# 1257682      A C++ Refactoring Browser and Method Extraction
# 1259014         Dynamic AspectC++ Generic Advice at Any Time
# 1259880         JavaC++ Bridge for Symbian based Smartphones
# 1263524    A New Concept of Effective Regression Test Gen...
# 1264054    TreeTime an extensible C++ software package fo...
# 1274897    A Semantic Definition of Separate Type Checkin...
# 1275383    Architecture and C++programming environment of...
# 1275491    Automatic Protocol implementation  generating ...
# 1275508                       Hardware programming using C++
# 1279298    C++ Bindings to External Software Libraries wi...
# 1304143       EBLearn OpenSource EnergyBased Learning in C++
# 1307747       The C++ Hybrid Imperative MetaProgrammer CHIMP
# 1307976    Towards a Reverse Engineering Dataflow Analysi...
# 1317444    Automatic Performance Model Transformation fro...
# 1337571    A Provably Correct Translation of the Calculus...
# 1338933    Algorithms Problem Solving and Data Structures...
# 1339356                        Dimensional Analysis with C++
# 1342023      Teaching C++ in a multiuser virtual environment
# 1342072    An automatic testing and grading method for a ...
# 1342166      A critique of the advanced placement C++ subset
# 1510339    A Comparison of Generic Template Support Ada C...
# 1511663    The aspectoriented design of the PUMA CC++ par...
# 1512996    Integrated and Automated Abstract Interpretati...
# 1518505    Bitstream processing for embedded systems usin...
# 1526793    ObjectOriented OpenMP Programming with C++ and...
# 1532719       C++ Tools for Exploiting Polyhedral Symmetries
# 1532750    CoCoALib A C++ Library for Computations in Com...
# 1532753    Complex Inclusion Functions in the CoStLy C++ ...
# 1536728    Exploiting Object Orientation to Parallelize a...
# 1537561    Constructing a Selforganizing C++ Programming ...
# 1540441    Identification of Idiom Usage in C++ Generic L...
# 1547475    Generic flowsensitive optimizing transformatio...
# 1565772    Automatic Offloading of C++ for the Cell BE Pr...
# 1571480           MultiPAS JAVA C++ and C# to Octave bridges
# 1579778    A Hybrid Model Checking and Runtime Monitoring...
# 1590648    An approach to find dynamic slice for C++ Program
# 1595130    A precompiler to reduce the memory footprint o...
# 1600272    A Program Transformation Technique to Support ...
# 1601366    AspectC++ An integrated approach for static an...
# 1603925                        Programming with C++ concepts
# 1603935       Simple and safe SQL queries with C++ templates
# 1603937       Design and evaluation of C++ open multimethods
# 1606259    Precise computation using range arithmetic via...
# 1613530    ROOT  A C++ framework for petabyte data storag...
# 1613556            Reduze  Feynman integral reduction in C++
# 1613681    CADNAC A version of CADNA for use with C or C+...
# 1617511    Automatic translation of CC++ parallel code in...
# Name: title, dtype: object
# # Example:
# 35309      Automatic Generation of the C# Code for Securi...
# 46809      Generic Programming for Scientific Computing i...
# 51838       Specification and Implementation Problems for C#
# 51891      An ASM Specification of C# Threads and the NET...
# 198679                        Adding Context Awareness to C#
# 204801         The Use of C# as a First Programming Language
# 208738               A Memory Model Sensitive Checker for C#
# 209345     Exploiting Abstraction for Specification Reuse...
# 222335     Fuzzy ObjectOriented Modelling with Metadata A...
# 444491            AspectOriented Programming with C# and NET
# 466738     Experience with integrating Java with new tech...
# 470765     Metaprogramming Library for the C# Programming...
# 525781               ParC# Parallel Computing with C# in Net
# 537626     Parallel C# The Usage of Chords and Higherorde...
# 548566     Design and implementation of a highperformance...
# 557360     Quality Assessment of Mutation Operators Dedic...
# 581466        Design of a ThreeTiered Visual C# NET Web Form
# 581503                               Exception Safety for C#
# 585325                                   C# Should CS Switch
# 609687              On the Integration of Classboxes into C#
# 681448     Communication and interaction protocols for mu...
# 685385     McC and Mc Unified C++ and C# Design Facts Ext...
# 693844     Objectoriented programming with dynamic classi...
# 698836                                        OOP via C++ C#
# 702399     ArchC# A New Architecture Description Language...
# 732121     Using C# Attributes to Describe Hardware Artef...
# 736711     CsharpSimpleModule writing OMNeT modules with ...
# 807272                    Building C# Programs with Patterns
# 807409                                   Assessing a C# Text
# 810140        Experience in integrating Java with C# and NET
# 810959     Using MPI with C# and the Common Language Infr...
# 820598     Mixing the Objective Caml and C# Programming M...
# 830064     C#  Connecting a Mobile Application to Oracle ...
# 830283     ShopList Programming PDA applications for Wind...
# 856812     IEEE Software RealTime Systems  C# and the NET...
# 893472     Activities and channels C# language extensions...
# 893609                      Compiler generation tools for C#
# 987721     The Correctness of the Definite Assignment Ana...
# 987730                      Managing Code Dependencies in C#
# 987734                                  Freely Annotating C#
# 987762                    C# and Java The Smart Distinctions
# 987784     Adding AspectOriented Programming Features to ...
# 987996                                Remoting in C# and NET
# 987997                            Delegates and Events in C#
# 987999       Generic RedBlack Tree and its C# Implementation
# 988001     A Pedagogical Experiment Introducing Students ...
# 988018     Alternative Implementation of the C# Iterator ...
# 1036300    Towards verification of C# programs A threelev...
# 1067373                        Generative programming for C#
# 1071216         C# and the NET Framework Ready for Real Time
# 1074137                               A research C# compiler
# 1095428    A flexible model for dynamic linking in Java a...
# 1123218               Modern concurrency abstractions for C#
# 1182547    Curb your objects an orthodox form for C# classes
# 1182758       Objectoriented recursive descent parsing in C#
# 1203749    An Experiment in Automatic Conversion of Legac...
# 1221329    Iterative Methods for Systems Solving  a C# ap...
# 1221337                          Athos  The C# GUI Generator
# 1233522    Developing a tokenizer and morphological parse...
# 1257668    Advanced mutation operators applicable in C# p...
# 1274895    A ModelView Implementation of Linked Custom Gr...
# 1302335    ToolSupported Advanced Mutation Approach for V...
# 1510339    A Comparison of Generic Template Support Ada C...
# 1512978    A Modular Verification Methodology for C# Dele...
# 1563688    ModelDriven Engineering Support for Building C...
# 1571480           MultiPAS JAVA C++ and C# to Octave bridges
# 1574833    Correctness issues of UML class and state mach...
# 1579518    The Implemention of ChineseTai Lue Electronic ...
# 1597330    Realization of UML Class and State Machine Mod...
# 1600252    Darwins World Simulation in C# The ModelView C...
# 1600254        Darwins World Simulation in C# An Interpreter
# 1613717    Code C# for chaos analysis of relativistic man...
# Name: title, dtype: object

# %%
non_alphabetic_chars_set = set(re.findall(r'[^a-zA-Z\s]', ''.join(clean_data['abstract'])))
non_alphabetic_chars_list = list(non_alphabetic_chars_set)
print("List of unique non-alphabetic characters:", non_alphabetic_chars_list)
# Out:
# List of unique non-alphabetic characters: ['+', '#']

# %%
for char in non_alphabetic_chars_list:
    titles_with_char = clean_data[clean_data['abstract'].str.contains(re.escape(char))]
    print(f'{char} Example:')
    print(titles_with_char['abstract'])
# Out:
# + Example:
# 156        Inside the C++ Object Model focuses on the und...
# 4571       This paper deals with genetic algorithm implem...
# 6551       Aristotle provides program analysis informatio...
# 6687       This panel will examine issues related to the ...
# 6789       This paper proposes an objectoriented developm...
# 8413       Determining interclass test order is one of th...
# 8741       Resource reservation is a vital issue for grid...
# 9943       With the advent of chipmultiprocessors we are ...
# 11465      The Circuit Object Organization Library is a C...
# 16477      This paper proposes a new practical automatic ...
# 22891      An object oriented relational database managem...
# 24221      Traditionally intrusion detection systems dete...
# 29249      Practical experience in porting a large virtua...
# 36763      We discuss scheduling techniques to be used fo...
# 42053      We present in this paper an expandable simulat...
# 42217      MC++ is a multigroup Monte Carlo neutron trans...
# 42272      Modelling and programming process requires a c...
# 42324      A pooled shared C++ allocator developed for us...
# 42348      To study the performance of new architectural ...
# 43132      A primary goal of AOSD in the context of syste...
# 43201      cJ is an extension of Java that allows superty...
# 43581      SOFL is a formal language and method for syste...
# 44141      Dataparallel applications are usually programm...
# 44232      The SmartArrays Software Develop Kit SDK is a ...
# 44439      This paper discusses the task of developing a ...
# 45709      Asynchronous data communication mechanisms ACM...
# 47020      Although data flow analysis has been successfu...
# 47155      Existing reverseengineering tools use algorith...
# 47164      The Object Constraint Language OCL is a precis...
# 47396      Components are the basic building blocks of en...
# 47403      This paper describes the translation of Object...
# 47405      A test oracel provides a means for determining...
# 47485      Managing the evolution of an OO system constit...
# 47621      Given a set of classes as input a class exerci...
# 49950      In this paper we present the development and i...
# 49976      The MGAP is a specialpurpose workstation copro...
# 52383      Renesas Technology Corp designers turned to Op...
# 53820      Hardwareassisted realtime garbage collection o...
# 58827      In this article we present a generic test equi...
# 59043      Goanna is an industrialstrength static analysi...
# 61179      Generative Programming GP is a computing parad...
# 61239      Preliminary results of Theia a software system...
# 61447      A smart and simple algorithm is presented in t...
# 62032      Proponents of active systems have proposed Eve...
# 62435      Optimizing method dispatch is a central issue ...
# 70109      Memory management is a critical issue for many...
# 70114      A C++ program database represents information ...
# 70115      In this paper we overview the design and imple...
# 70116      Separating interface from implementation in C+...
# 70134      We describe the design and implementation of a...
# 70152      For systems of C++ classes using virtual funct...
# 70161      Most debuggers do not support an objectoriente...
# 70170      FIELD is an open languageindependent programmi...
# 70175      C++ is an expressive language but it does not ...
# 70179      There are numerous times when a C++ user could...
# 70183      We propose adding safe efficient garbage colle...
# 70201      Objectoriented design and objectoriented langu...
# 70204      The meaning of the term object oriented is exa...
# 70219      The C++ language currently does not provide a ...
# 70222      Structured graphics are useful for building ap...
# 76822      This paper presents a design for instantiating...
# 76840      C++ is increasingly becoming the language of c...
# 76842      In this paper we review and analyze concurrenc...
# 76900      Anything that one cannot measure cannot be con...
# 76977      This paper describes practical design and impl...
# 76997      Objectoriented application frameworks are ofte...
# 77006      In this paper we describe the highlevel archit...
# 77071      To date most of the work on language support f...
# 77127      The IBM VisualAge for C++ development environm...
# 77147      Grail is a symbolic computation environment fo...
# 77183      Since its beginnings ten years ago C++ has gro...
# 77211      Eventbased tracers for visualizing distributed...
# 77224      Technologies developed over the past few years...
# 77342      Parsing contextdependent computer languages re...
# 77575      Chip fabrication technology continues to plung...
# 77676      The memory intensive nature of objectoriented ...
# 79930      The growing designproductivity gap has made de...
# 81523      Implementing a new programming language by the...
# 82737      This paper presents the gSOAPstub and skeleton...
# 82970      TACO Topologies and Collections is a template ...
# 83733      Policy enforcement is an integral part of many...
# 95228      In an objectoriented database system OODBS obj...
# 96018      We present the architecture and a performance ...
# 99652      M selfmigrating threads are C++ compiled objec...
# 99670      CPPvm is a C++ class library for message passi...
# 99750      Software DSM provides good programmability for...
# 106098     In this paper we describe the experimentation ...
# 106148     This paper presents an RTOScentric hardwaresof...
# 106189     We present a new design environment called Sys...
# 106319     We introduce CASTLE a design environment for e...
# 106334     Network hardware design is becoming increasing...
# 106346     The implementation of a cosynthesis design flo...
# 106459     Systemlevel and Platformbased design along wit...
# 110128     The Taligent Object System TOS is an objectori...
# 110143     The ObjectOriented Device Driver Model OODDM i...
# 110163     The Taligent frameworks rely on an extended ty...
# 111911     C++ uses class as the basis of subtypepolymorp...
# 112172     This paper describes a programming environment...
# 112173     The paper presents an approach to translate hi...
# 112195     Integrating parallel functions into the manipu...
# 112216     Exu is a new approach to automated support for...
# 112340     In this paper we propose a programming languag...
# 112434     Software metrics increase our ability to under...
# 112865     Statistical data show that it is much less exp...
# 113009     Over the past years the reengineering of legac...
# 114782     Within an environment of Parallel Objects aapp...
# 114881     This article presents a programming methodolog...
# 115965     This paper describes an active objectoriented ...
# 116507     This paper discusses a realization of object p...
# 116516     This paper describes a new object infrastructu...
# 116531     Using exception handling in C++ can lead to se...
# 116538     Generic programming is a paradigm whose wide a...
# 116540     Mainstream objectoriented languages such as C+...
# 116541     A methodology and language for specifying beha...
# 116550     C++ templates are already recognized as a powe...
# 116552     The C++ Standard Template Library provides eff...
# 116553     This paper presents uCR a C++ runtime package ...
# 116554     Objectoriented programming languages may encou...
# 116556     The Montana C++ programming environment provid...
# 116567     Texas is a highly portable highperformance per...
# 116574     Despite the obvious advantages of using object...
# 116575     C and C++ allow passing functions as arguments...
# 116578     The nature of complex high performance system ...
# 116579     Sometimes it is desirable to alter or optimize...
# 116587     During the development of BeyondSniff a distri...
# 122576     This paper presents the development of a desig...
# 125021     To successfully carry out a software maintenan...
# 125025     The present diffusion of the objectoriented pa...
# 125039     In this paper we describe temporal invariants ...
# 125104     Growing maintenance costs have become a major ...
# 125106     The assessment of the changeability of softwar...
# 125132     Objectoriented programming is about the creati...
# 125134     The purpose of this paper is to propose a benc...
# 125172     CC++ code relying on preprocessing can be quit...
# 125223     The CORET tool set serves to restructure legac...
# 125244     Constructors play an essential role in objecto...
# 125251     This paper presents Xrefactory a refactoring b...
# 125264     Recovering design pattern usage in source code...
# 125318     Many reverse engineering approaches have been ...
# 125349     Syntax analysis and metrics are combined to a ...
# 125390     Many C++ extractors exist that produce syntax ...
# 131183     In the following by considering the communicat...
# 131380     Designers can create completely new processors...
# 132180     It has long been the practice to create models...
# 132734     We present a programming interface called YAPI...
# 132955     Reactivity is one of the key features of hardw...
# 133451     Techniques for fast and accurate simulation of...
# 133617     This paper presents a prototype environment fo...
# 133955     This paper describes a data management package...
# 134603     It has long been the practice to create models...
# 134666     In modern day digital design flow highlevel mo...
# 134807     It has long been the practice to create models...
# 138026     The CTTNsystem is a computer program which pro...
# 138271     Arjuna is an objectoriented programming system...
# 138453     Our work involves the establishment of a stand...
# 138819     CXSC is an extensive and sophisticated C++ cla...
# 141383     The design process for an engine management sy...
# 141389     In this paper we present results in using the ...
# 141410     In this paper we present an experimental integ...
# 141549     Embedded systems design requires the developme...
# 141665     The opensource OnChip Communication Network OC...
# 141693     System design methodology is poised to become ...
# 141701     System level modeling with executable language...
# 141794     Reflection and automated introspection of a de...
# 141795     This article describes the Balboa component in...
# 142532     Software programming languages such as CC++ ha...
# 142721     Complex systemsonchip present one of the most ...
# 142722     This paper describes a simulation technique fo...
# 142817     Objectoriented modeling of hardware promises t...
# 142949     Simple and powerful modeling of concurrency an...
# 142982     This paper describes the experiences and resul...
# 143206     This paper discusses the use of C++ for the de...
# 143216     In this paper is proposed a technique to integ...
# 144072     A design methodology for the synthesis of digi...
# 147826     This work presents a methodology for mapping o...
# 147838     This paper presents new portable electronic me...
# 151496     In this paper we suggest the Unified Video Ret...
# 152281     This paper proposed a novel method to protect ...
# 155304     Document storage and retrieval capabilities of...
# 159659     The paper describes the use of an XML format t...
# 160223     AvalonC++ is a programming language that suppo...
# 161187     Fault simulation technology is essential key n...
# 161495     The present paper proposes a CC++ SourcetoSour...
# 161758     Abstract In embedded systems development safet...
# 161800     Abstract Componentbased software engineering t...
# 161840     Abstract As has been shown in previous work th...
# 167504     For complex systems that are reusing intellect...
# 167627     In this paper we describe the use of generic p...
# 167964     Motivation The computational identification of...
# 168082     Motivation A mass spectrum produced via tandem...
# 168084     Motivation Next generation sequencing technolo...
# 173050     Previous studies have shown that objectoriente...
# 174183     While objectoriented programming has been embr...
# 174216     This paper describes how correctness and robus...
# 174224     This paper describes a scheme of manipulating ...
# 174225     This paper presents a set of concepts and desi...
# 176697     We describe the engineering of Succinct DOM SD...
# 177375     Embedded systems are rapidly growing in size c...
# 177481     We present an integrated approach practices to...
# 178291     In this paper we propose an XSLTbased infrastr...
# 185151     In the last decades faster and more powerful c...
# 188067     A software repository provides a central infor...
# 194801     The quality of a test suite can be measured us...
# 195216     XCOM system consists of a binary component sta...
# 195471     The paper evaluates the most important Web pro...
# 195485     Heap management is responsible for the allocat...
# 197444     A well known structuring technique for a wide ...
# 197854     We describe a software solution to the problem...
# 197914     We describe an approach to automatic paralleli...
# 197919     STL dictionaries like map and set are commonly...
# 197927     We describe compiler and runtime optimisations...
# 197948     With support for CC++ Fortran MPI OpenMP and p...
# 203254     Abstract If reconfigurable processors are to b...
# 203313     Most commercial and academic floating point li...
# 203363     PAMBlox are objectoriented circuit generators ...
# 203495     This paper describes a C++ class library and b...
# 209099     TLM TransactionLevel Modeling was introduced t...
# 209734     While it is becoming more common to see model ...
# 220753     The use of computers as embedded components in...
# 224602     Combinations of C++ features like inheritance ...
# 226385     In this paper an objectoriented unified optimi...
# 226988     This paper presents a hybrid approach to detec...
# 234072     C As part of ARPAs RASSP Technology Program we...
# 234278     We propose a novel evolutionary approach to th...
# 235606     Most large software applications rely on an ex...
# 235615     Conceptssets of abstractions related by common...
# 235619     Component containers are a key part of mainstr...
# 235653     Template metaprogramming is an emerging new di...
# 235736     Families of independent classes where each cla...
# 235743     Multiple dispatch  the selection of a function...
# 235749     Large scale software is composed of libraries ...
# 235761     Concepts are a recently proposed extension to ...
# 239561     A previous report identified several usability...
# 242992     A parallel programming system called MPC++ pro...
# 245082     A key advantage for the use of a DomainSpecifi...
# 246784     The common view of component centered developm...
# 247769     Commercial offtheshelf repository management s...
# 248673     ObjectOriented Architecture OOA ComponentBased...
# 249539     The design and maintenance of large computatio...
# 251447     On multicore architectures with softwaremanage...
# 251464     Programmers of concurrent applications are fac...
# 251478     Dynamic Parallel Schedules DPS is a highlevel ...
# 251494     Adaptive utilization of resources in a highly ...
# 252785     The counterflow pipeline concept was originate...
# 253010     With the advent of ubiquitous multicore archit...
# 254704     Derivatives of almost arbitrary functions can ...
# 254803     This paper introduces a military application i...
# 255087     Abstract Within NASAs High Performance Computi...
# 255257     TACO is a template library that implements hig...
# 273952     It is a friendly humanmachine interaction to o...
# 279003     The SDESolver software package is our own prof...
# 280195     ClassdescMP is a distributed memory parallel p...
# 280236     Parallel computing in network of workstations ...
# 282933     Modeling and simulating pipelined processors i...
# 283863     Embedded software are becoming more and more p...
# 286490     This paper describes a cycle accurate model of...
# 289102     The paper presents a proposal for introducing ...
# 294700     This paper describes a new generalpurpose cont...
# 295444     We describe a new approach to manage the testi...
# 296044     In this paper we design the primary component ...
# 297157     Endtoend middleware predictability is essentia...
# 298892     In case of emergency we need to grasp the situ...
# 299356     Ode a database system and environment based on...
# 299403     Many efforts have been devoted to couple data ...
# 300895     The adoption of XML to represent any kind of d...
# 305259     A commonly held belief is that applications wr...
# 305332     Exception handling is a powerful mechanism tha...
# 309415     The Galois Subhierarchy GSH is a polynomialsiz...
# 309705     A test oracle provides a means for determining...
# 310041     This paper describes FC++ a rich library suppo...
# 310219     The paper investigates the impact of high leve...
# 310220     Software libraries rely increasingly on iterat...
# 310226     Generic libraries such as the C++ Standard Tem...
# 310237     Scrap Your Boilerplate SYB is a well studied a...
# 310260     Earlier studies have introduced a list of high...
# 327780     This paper presents a programming language whi...
# 336597     A new method for generating a square of a sign...
# 336710     A basic function of a Session Maintenance Prot...
# 344859     In this paper we present a solution for effici...
# 353072     This paper describes a set of tools that enabl...
# 359995     Derivatives of almost arbitrary functions can ...
# 360014     We present a parallel finite element solver fo...
# 361415     Polymorphism is an essential feature of the ob...
# 361497     The coupling dependency metric CDM is a succes...
# 361629     We describe the design and implementation of s...
# 361774     Many software testing and analyses tools manip...
# 361777     A common change to objectoriented software is ...
# 361788     We show how the state space exploration tool V...
# 361826     A summary of an ongoing case study of software...
# 361832     This paper reports the results of specifying m...
# 362169     This paper presents the first practical static...
# 362200     This demonstration will present a design and p...
# 362354     Many reverseengineering tools have been develo...
# 362382     This tutorial addresses how both the Object Ma...
# 362518     As Java increases in popularity and maturity m...
# 362899     This paper describes an experiment to use the ...
# 362966     Describes the enhancement of XVision a large l...
# 363311     This tutorial provides the basics that develop...
# 363312     This tutorial addresses how both the Object Ma...
# 363501     Template metaprogramming techniques can be use...
# 364135     An approach to reengineer BASIC PC legacy code...
# 364152     Many coupling measures have been proposed in t...
# 364178     The distributed development and maintenance pa...
# 364222     Programmers frequently have to retrieve and li...
# 364223     In this paper we describe the reengineering of...
# 364225     In this paper we describe restructuring of C c...
# 364247     Traceability is a key issue to ensure consiste...
# 364306     The size and complexity of hardware and softwa...
# 364334     Reverseengineered UML class diagrams are neith...
# 364339     An empirical study is presented that explores ...
# 364354     Objectoriented software engineering must addre...
# 364383     Conditional compilation is one of the most pow...
# 364402     MECASP is a research prototype aiming at the i...
# 364417     This paper presents an approach to automatic u...
# 364468     Maintenance is the set of activities performed...
# 364481     This empirical study analyzes changes in C++ s...
# 364572     The proposed metric for evaluating class libra...
# 364679     The success of an objectoriented software deve...
# 364741     The practice of software development continues...
# 364762     When designing a new application experienced s...
# 364766     In object oriented programming the functionali...
# 364851     Online software maintenance OSM is performed w...
# 364856     Since the Standard Template Library STL generi...
# 364913     Source code analysis is important for software...
# 364940     An approach to automatically identify the ster...
# 366709     Hoare and Hes unifying theories of programming...
# 366728     In this paper a unified approach to abstract i...
# 366769     This paper presents two methods for comparison...
# 367214     Data mining algorithms including machine learn...
# 367724     In this paper design and implementation of an ...
# 369444     Stepwise refinement is a powerful paradigm for...
# 370952     This paper presents a tabledriven streaming XM...
# 371043     Objectlevel coherence in distributed applicati...
# 371072     Mapping XML document schemas and Web Service i...
# 373028     In this paper we report on a parallel implemen...
# 396770     A key step in the semantic analysis of network...
# 404638     We present the Visual Code Navigator a set of ...
# 407974     The Distributed object migration environment D...
# 408743     In this paper we present a new coordination mo...
# 408768     Typical highperformance distributed applicatio...
# 408810     This paper describes a framework for providing...
# 408998     Dynamic Parallel Schedules DPS is a highlevel ...
# 409408     A software framework for the parallel executio...
# 409669     We introduce VLADYMIR a matrix library that pe...
# 409853     We introduce the allsoftware standard C++based...
# 410026     GRAPE Graph Processing Environment is an indus...
# 410243     Adaptive utilization of resources in a highly ...
# 410245     Efficient data access is important to achieve ...
# 410789     CC++ is an objectoriented parallel programming...
# 411062     We investigate the practical integration of fu...
# 411227     In this paper we evaluate Titaniums usability ...
# 413861     We present a graphbased intermediate represent...
# 416246     Currently public networks have an enormous num...
# 416352     An advanced highlevel approach for programming...
# 438076     This paper describes a platform package called...
# 438305     Motivation A growing body of research has conc...
# 440902     The complexity of todays hardware systems stea...
# 444283     In this paper we discuss a more complex class ...
# 444361     The runtime characteristics of Java such as hi...
# 444618     Objectoriented languages support many modern p...
# 446100     Runtime systems are critical to the implementa...
# 447856     AssertionBased Verification ABV using the PSL ...
# 448978     The transposition principle also called Telleg...
# 449504     In this paper we present a new method for solv...
# 449827     We consider the problem of determining whether...
# 449838     Until now the area of symbolic computation has...
# 450178     A practical application of objectoriented meas...
# 450274     In this paper we present the design and implem...
# 450312     For the testing of container classes and theal...
# 450470     The design of a hardware data path library is ...
# 450474     In the past the EDA industry and designers hav...
# 450495     The emerging technology of the SystemonChip So...
# 450562     The increasing use of programmable processors ...
# 450573     The increasing heterogeneity and complexity of...
# 450585     Various systemlevel corebased power evaluation...
# 450678     Design visualization is an important part of t...
# 450763     VeriSoft is a tool for systematically explorin...
# 457647     This paper presents a case study on a logic ci...
# 457702     In this paper we introduce a new routing schem...
# 458012     This paper presents a comparison between C and...
# 460118     We propose a method for the visualization of l...
# 464576     This paper proposes a methodology to develop c...
# 465195     Many useful programming language extensions an...
# 465312     Parsing programming languages is an essential ...
# 465344     Traceability is a key issue to ensure consiste...
# 465375     A commonly held belief is that the friend cons...
# 465502     This paper describes a prototype tool that fac...
# 465524     Objectoriented systems are particularly diffic...
# 465597     Recent advances in software engineering have p...
# 465706     Slicing C programs has been one of the most po...
# 465853     We present a method to detect and visualize ev...
# 466348     Reflective environments such as NET have provi...
# 466732     Objectoriented programming languages have alwa...
# 466738     Java programmers cannot but be aware of Micros...
# 466747     Compiletime program optimizations are similar ...
# 466814     Message passing based on libraries such as MPI...
# 471501     Domainspecific languages DSLs assist a domain ...
# 471555     Firewalls play a crucial role in network secur...
# 471852     Distributed applications typically interact wi...
# 471881     This paper proposes a concept named unit repea...
# 473365     There are various source code archives on the ...
# 482012     Voice over IP VoIP can be used in a wide varie...
# 482270     The development of new transport protocols or ...
# 482415     Design of a multithreaded object oriented C++ ...
# 482965     A compositional parallel program is a program ...
# 483382     The Standard Template Adaptive Parallel Librar...
# 483442     Hierarchically Tiled Arrays HTAs are data stru...
# 483446     We present a novel and efficient containercent...
# 483468     Certain highperformance applications like mult...
# 483677     This paper presents a set of C++ libraries cal...
# 483686     We build on prior work on intraarray memory re...
# 484094     A tight transparent and portable integration b...
# 485748     FTP Mirror Tracker is a software package writt...
# 488886     This paper describes the architecture and impl...
# 489968     We introduce our SimUTC toolkit a faulttoleran...
# 489974     NEUROGRAPH is a simulation environment for neu...
# 492249     CSP Communicating Sequential Processes is a us...
# 492871     Our previous studies of developers ability to ...
# 492986     In order to help software managers and enginee...
# 492990     Software testing costs would be reduced if man...
# 499806     InteGrade is a grid middleware infrastructure ...
# 499909     Current mappings of IDL to implementation lang...
# 503347     CLAM is a C++framework that offers a complete ...
# 510292     The ability to enhance singlethread performanc...
# 512849     This paper presents a middleware system called...
# 514396     A wide variety of singing synthesis models and...
# 521761     Although the Java programming language has ach...
# 521779     Componentbased software engineering enables ap...
# 521830     Optimizing method dispatch is a central issue ...
# 521934     The primary goal of a realtime system is predi...
# 521984     This paper presents a metaobject protocol MOP ...
# 522053     In MRI research labs algorithms are typically ...
# 522077     Row displacement dispatch tables implement mes...
# 522094     In the domain of hard realtime systems which l...
# 522165     Many modern programming languages support basi...
# 522201     We present an iterativedesign approach for reu...
# 522220     The use of dynamicallydispatched procedure cal...
# 522253     Changing the approach to dynamic memory alloca...
# 522263     Objectoriented programming languages provide a...
# 522332     Domainspecific languages DSLs assist an enduse...
# 522352     We describe Charm an object oriented portable ...
# 522377     The objective of this work is to define implem...
# 522563     Existing schemes for object layout and dispatc...
# 522588     Parametric polymorphism has become a common fe...
# 522595     The growing maturity of ODBMS technology is ca...
# 522603     Subjectoriented programming supports compositi...
# 522668     Domainspecific languages DSLs use idioms that ...
# 522686     Existing formalisms of inheritance are not suf...
# 522756     Dynamic memory management in C++ is complex es...
# 522809     Traditional implementations of multiple inheri...
# 522833     This paper describes an algorithm for slicing ...
# 522889     We present an operational semantics and type s...
# 522956     Programs sometimes crash due to unusable value...
# 522979     C++ is a very successful objectoriented langua...
# 522999     This article describes the design and use of t...
# 523044     The NET intermediate language MSIL allows expr...
# 523141     This article reveals our work on refactoring p...
# 523847     Software attacks often subvert the intended da...
# 528750     The numerical solution of partial differential...
# 528778     Several widely used and promising programming ...
# 528790     We present the AMESOS project which aims to de...
# 528814     The escript package is an extension of python ...
# 528829     A generic scientific simulation environment is...
# 528850     SyFi is an open source C++ library for definin...
# 529627     Many practical applications generate irregular...
# 529664     This paper describes the design of CODECompone...
# 530298     The development of a military safety critical ...
# 530342     Symbolic path simulation is becoming an increa...
# 533106     The development of numerical simulation softwa...
# 534138     Abstract We describe a hybrid system for deali...
# 534200     ASSIST is a structured parallel programming en...
# 534400     This paper discusses the key aspects and prese...
# 534427     Abstract Parallel programming is difficult The...
# 534466     Multicomputer systems are increasingly becomin...
# 534512     MuPC is a portable runtime system for Unified ...
# 534614     Failure detection protocols an important build...
# 538109     With the increasing miniaturization of transis...
# 538578     An important requirement of pervasive applicat...
# 541069     In this paper we study the feasibility for the...
# 542335     Both typeaccurate and conservative garbage col...
# 542339     A conservative garbage collector can typically...
# 542382     Languages that support abstraction and modular...
# 542423     Applications written in unsafe languages like ...
# 542510     Objectoriented languages like Java and Smallta...
# 542547     Typical classbased languages such as C++ and J...
# 542648     Generic programming has recently emerged as a ...
# 542799     The member lookup problem in C++ is the proble...
# 542843     Concepts are an essential language feature for...
# 543007     Building distributed systems is particularly d...
# 543014     Advanced type systems often need some form of ...
# 543023     Programs written in C and C++ are susceptible ...
# 545875     Modern computer architectures increasingly dep...
# 546056     Haskells type classes allow adhoc overloading ...
# 546673     C++ templates are key to the design of current...
# 546776     The need to fit together reusable components a...
# 546793     Game developers have long been early adopters ...
# 546892     Typepreserving compilation can improve softwar...
# 546966     This paper describes an interprocedural techni...
# 547979     Objectoriented languages fail to provide softw...
# 548046     SMLNET is a compiler for Standard ML that targ...
# 548259     The design and implementation of portable effi...
# 548292     Tiling has proven to be an effective mechanism...
# 548532     C or C++ programs relying on the pthreads inte...
# 554898     In this paper we develop a security verificati...
# 556440     Different programming paradigms utilize a vari...
# 557254     This paper presents an improvement to existing...
# 557418     Dynamic software updating enables running prog...
# 561040     Robot building projects are increasingly used ...
# 562535     Typically the design of hardware and software ...
# 562575     In this paper we present an efficient methodol...
# 562595     Our software synthesis tool CSP generates C++ ...
# 562622     This paper describes SoCBaseVL which is a CC++...
# 562650     This paper describes SoCBaseVL which is a CC++...
# 562789     Modeling a system with communicating concurren...
# 563970     Abstract For large realtime systems it is ofte...
# 564624     In this paper the semantics of interobject com...
# 565124     We describe a new implementation of HYTECH a s...
# 565479     Many of the benefits of Java including its inh...
# 567011     This article presents an strategy to combine i...
# 567025     A method for judging the reusability of C++ co...
# 567123     This paper presents specialized code generatio...
# 567130     A fundamental part of a systems quad floatingp...
# 567403     Virtual namespace functions VNFs are introduce...
# 567710     Most mainstream objectoriented languages like ...
# 567840     In this paper we present a molecular modeling ...
# 567994     Highly interactive applications are increasing...
# 568417     INADA is an enhanced C++ persistent programmin...
# 568594     We present a programming technique for impleme...
# 568703     Maintenance is really the normal state of an X...
# 568977     Generic functions and classes accepting a vari...
# 569251     In this paper we introduce a C++ environment f...
# 569319     A key benefit of generic programming is its su...
# 569414     This paper compares two hardware design flows ...
# 569824     Working collaboratively on complex software sy...
# 569879     Current online testing systems are lacks of su...
# 569920     Abstract Syntax Trees ASTs are commonly used t...
# 572207     Modern multicore processors suffer from the la...
# 572452     We are dealing with solving difficult SAT inst...
# 572464     In this paper we present a new system called C...
# 573785     For the rapid prototyping of mixedsignal syste...
# 573793     New programming languages paradigms have commo...
# 574880     Grid systems span manifold organizations and a...
# 575321     The use of parallel platforms despite increasi...
# 575557     This paper describes a set of tools for annota...
# 576020     We present an Adaptive Mesh Refinement benchma...
# 576837     In this paper we describe a new approach for t...
# 576842     Transformations of numerical source code may r...
# 576874     The Framework Constraint Language FCL is a too...
# 576888     Many articles and tools have been proposed ove...
# 578591     In this paper we present a new approach for ge...
# 581527     Objectoriented modeling plays an increasing ro...
# 581672     Much of the embedded software development mark...
# 581684     Enterprise software systems need to deal with ...
# 584684     The importance of software measurement increas...
# 584859     Fast fault recovery depends on immediate detec...
# 586272     SystemC is a popular open source library in C+...
# 586345     Obfuscation is one of the most effective metho...
# 587108     This work presents a simpler method to obtain ...
# 587110     This work presents a simple method to obtain f...
# 587210     In this work we developed a program to visuali...
# 587863     In this paper we describe an approach to autom...
# 587915     One of the novel features of GNAT is its unusu...
# 588114     Genetic and evolutionary algorithms inspired b...
# 588198     This paper describes our experience with selec...
# 588224     In this paper we describe a Software Reconnais...
# 588268     In this paper we describe our application of t...
# 588483     In this paper an objectbased approach to proto...
# 589649     In the heyday of structured programming many e...
# 589713     The Binary Search Tree serves as an important ...
# 590055     C++ was used to teach programming to beginning...
# 590085     This paper describes a set of author developed...
# 590346     Visual Basic is currently the most popular pro...
# 590453     Interest in teaching objectoriented programmin...
# 590458     In the context of our overall goal to bring th...
# 590466     Researchers have been developing online tutors...
# 590578     In this paper we describe our experience in th...
# 590601     The programming language concepts which ought ...
# 590784     This panel discusses the granting of credit fo...
# 590813     This paper explores the framework method for t...
# 590835     Pointer errors are stumbling blocks for studen...
# 590873     Traditional first year computer science course...
# 590874     Passing functions and function objects to gene...
# 590875     In objectoriented design the concept of a cont...
# 590876     This paper describes an elegant method for aut...
# 590910     Objectoriented languages such as C++ allow cla...
# 590929     Students often have difficulty visualizing und...
# 590986     Jeroo is a tool that has been developed to hel...
# 591002     An undergraduate junior or senior level course...
# 591029     What started off as an enrichment assignment f...
# 591099     A standard practice in objectoriented programm...
# 591112     This paper presents a brief overview of Window...
# 591115     Objectoriented programming has become increasi...
# 591144     Although many data communications courses are ...
# 591245     This paper describes our experiences incorpora...
# 591266     Inheritance is a central topic in most introdu...
# 591413     This paper presents RegeXeX Regular expression...
# 591590     It is easy for computer science students and e...
# 591617     The importance of software bug detection tools...
# 591748     We incorporated animation of the data space in...
# 592172     One of the most common problems with program d...
# 592285     Within IBM there are many groups that have mad...
# 596602     The students over reliance upon formulas and r...
# 597937     We show how classical datalog semantics can be...
# 597938     ODE is a database system and environment based...
# 597956     The integration of the NET Common Language Run...
# 598016     Once considered a novelty object oriented syst...
# 598649     Programming nontrivial GUI applications is cur...
# 599015     Building objectoriented applications which acc...
# 599580     The goal of the EXODUS extensible DBMS project...
# 599759     In this paper we present an object oriented da...
# 600061     Multidimensional statistical models are genera...
# 600682     The architecture of an operating system eg mic...
# 600966     Humans have powerful image processing systems ...
# 601032     As database applications become larger and mor...
# 601087     Many software libraries eg the Booch C++ Compo...
# 601168     In runtime safety analysis the executions of a...
# 601289     We consider the problem of software generaliza...
# 608672     It is very desirable to run programs on a vari...
# 612803     Few toolsets for reverseengineering and unders...
# 612813     Data structure visualization can increase prog...
# 612828     In this paper we present an approach to modeli...
# 612832     Making the structure of software visible durin...
# 615795     We developed a dynamic programming approach fo...
# 617070     Object Persistence is an important feature of ...
# 619374     We define and apply two new measures of object...
# 625441     SVISS is a flexible platform for incorporating...
# 625447     SystemC is a systemlevel modeling language and...
# 626313     This paper describes a C++ library that allows...
# 634234     This paper presents a new GUI architecture for...
# 634496     We present the Haptic Shading Framework HSF a ...
# 634530     Ibuild is a user interface builder that lets a...
# 635862     You cant teach an old dog new tricks goes the ...
# 635986     This paper presents a method for developing ob...
# 636064     Current environments for web application devel...
# 636562     Programming highperformance server application...
# 636657     Tame is a new eventbased system for managing c...
# 636883     Modern day programmers are increasingly making...
# 638904     The Visual Code Navigator VCN is an ongoing ef...
# 640642     Attack graphs enable computation of important ...
# 640973     Languages used for design activities in cad so...
# 641143     A previous report identified several usability...
# 641357     The Java programming language eases the creati...
# 644190     In this paper we argue that developing informa...
# 645222     High level synthesis tools transform an algori...
# 651714     Geometric algorithms are based on geometric ob...
# 653061     Software system documentation is almost always...
# 653229     In this paper we present an infrastructure tha...
# 653247     The process of software reverse engineering co...
# 653250     Use case models describe the behavior of a sof...
# 653255     We present a webbased portal site for reverse ...
# 653272     This paper describes a reverse engineering cas...
# 653273     This paper presents an approach for dealing wi...
# 653304     In this paper we describe a technique that can...
# 653352     The paper introduces a number of mapping rules...
# 653369     The University of Queensland Binary Translator...
# 653379     The inherent differences between C++ and Javap...
# 653391     In this paper we present the design and implem...
# 653443     Scripting languages are popular in software de...
# 653511     We present the metric lens a new visualization...
# 653524     This paper reports on a tool for finegrained a...
# 659590     BoozAllen is helping to design and develop a C...
# 659759     Web browsers web servers Java application serv...
# 661465     Whale Calf is a parser generator that uses con...
# 661511     We implement a set of procedures for deciding ...
# 661576     We describe OpenFst an opensource library for ...
# 662081     This paper describes the crucial design and im...
# 666047     This paper discusses the issue of C++ exceptio...
# 666065     In this paper we describe a C++ infrastructure...
# 666280     The design and implementation of distributed r...
# 666544     Componentbased programming is a methodology fo...
# 667454     CPS expresses eventdriven parallel simulation ...
# 667843     The Object Oriented Programming OOP paradigm i...
# 667851     The discrete event simulator OMNeT that is pro...
# 667919     This paper deals with stochastic optimization ...
# 668119     COST ComponentOriented Simulation Toolkit is a...
# 668514     The paper discusses the model specification co...
# 668599     The Hierarchical Modeling and Simulation Syste...
# 668841     One of the greatest challenges in making optim...
# 669216     An objectoriented simulation OOS consisting of...
# 669217     A set of object classes have been written in C...
# 669218     An objectoriented simulation OOS consisting of...
# 669333     Silkreg and SML are software libraries of Java...
# 669425     Much of the research in parallel discreteevent...
# 669598     SIMAIR is a C++ based research tool meant for ...
# 670050     Some applications of simulation require that t...
# 670075     AweSimreg is a generalpurpose simulation syste...
# 670777     Contemporary software development environments...
# 671003     The increasing size and complexity of computer...
# 671197     Semiconductor fabrication factories are large ...
# 671283     There is no universal standard for discrete si...
# 675204     We present a new approach for propagating spam...
# 677816     This paper forms the notes of a twohours lectu...
# 677817     In this paper we sketch some experiments with ...
# 678185     Active libraries are code parts playing an act...
# 678490     C++ applications suffer from the lack of a gar...
# 678497     Discrete event simulation specification DEVS i...
# 679908     During rough cut machining of sculptured parts...
# 679961     Modernizing scientific legacy system to object...
# 681991     Hierarchy is an important relationship among k...
# 685229     This paper studies the performance of generics...
# 685385     In the last years as objectoriented software s...
# 691223     In this paper we present an open source flexib...
# 691471     Programs written in typeunsafe languages such ...
# 691499     Nearly ten years after its first presentation ...
# 693762     Software has been under scrutiny by the verifi...
# 695751     CGAL the Computational Geometry Algorithms Lib...
# 698601     Learning embedded programming is a highly dema...
# 698689     The complexity of languages like Java and C++ ...
# 698767     A demonstration of the integration of a progra...
# 698772     Benchmark tests are often used to evaluate the...
# 698836     This presentation describes our experience in ...
# 699005     This paper describes the Generic Automated Mar...
# 699328     Compiler construction is a widely used softwar...
# 700125     Accurate inference of local ancestry from whol...
# 700704     One of the aspects of applying software engine...
# 700705     We present a software tool called EASYSYN for ...
# 702166     In this work we present Goanna the first tool ...
# 702513     Most Java Virtual Machines JVMs are themselves...
# 702611     The concept of mixin programming has emerged a...
# 708201     Modularity is one of the key features of the O...
# 708369     Developing distributed realtime systems with h...
# 708534     A significant number of cyber assaults and int...
# 708763     The objectoriented design of software in C++ u...
# 708915     How to decompose or map data of programs autom...
# 709064     The ubiquitous game platform implemented by ou...
# 710920     Students need to learn testing skills and usin...
# 713458     Improper access of data buffers is one of the ...
# 715858     Future space missions such as the Mars Science...
# 715884     Java has recently joined C and C++ as a relati...
# 715895     The Java Legacy Interface is designed to use J...
# 716907     This paper introduces a mathematical model cal...
# 717380     MFC program SFFViewer intended for reading dec...
# 717638     Commercial software tools are increasingly use...
# 719164     Telemedicine is being rapidly developed In iso...
# 719268     YetiSim is a new open source C++ discrete even...
# 719560     Wireless Local Area Networks WLANs are current...
# 719978     Future generations of Chip Multiprocessors CMP...
# 719994     Programs written in C++ and OpenMP are still r...
# 719999     This paper proposes extensions to the OpenMP s...
# 720294     OOPar is a C++ library which implements an int...
# 720306     This paper summarizes our work on a parallel a...
# 730526     Many description languages are used in hardwar...
# 730729     The data structure course is a core foundation...
# 731286     Often declared dead or at least dying CC++ is ...
# 731304     In this paper we propose an approach to handle...
# 731332     We investigated errors and vulnerabilities tha...
# 732359     This paper describes Laerte a highlevel test p...
# 736023     Building a productionquality refactoring engin...
# 736769     This paper presents an extension of the IT lib...
# 739500     This paper provides a stateoftheart study of b...
# 743421     Casebased reasoning CBR one of the artificial ...
# 752021     We describe the theory of refinements of speci...
# 760931     Physicsbased animation programs are important ...
# 763169     Summary PermutMatrix is a work space designed ...
# 763230     Summary The purpose of our Bindingsite Estimat...
# 763689     Summary We have investigated the statistics as...
# 763862     Summary Carhta Gene is an integrated genetic a...
# 764037     Summary MesoRD is a tool for stochastic simula...
# 764302     Summary We describe a tool called aCGHSmooth f...
# 764323     Motivation RNA structure motifs contained in m...
# 764413     Motivation Images in cellular and molecular bi...
# 764596     Summary PedSplit facilitates pedigree manageme...
# 764795     Summary Research in proteomics requires powerf...
# 764896     Summary We describe two new Generalized Hidden...
# 765077     Summary IQPNNI is a program to infer maximumli...
# 765125     Motivation Matches to repetitive sequences are...
# 765547     Motivation Much information about new protein ...
# 766049     Motivation Mathematically optimal alignments d...
# 766833     Summary GeneRecon is a tool for finescale asso...
# 766859     Motivation The ability of cells to complete mi...
# 766914     Motivation A tandem repeat in DNA is a sequenc...
# 766933     Motivation Current methods that annotate conse...
# 766955     Summary We describe a software tool to perform...
# 767014     Summary satDNA Analyzer is a program implement...
# 767027     Motivation Recent transcriptomic studies have ...
# 767035     Summary URec is a software based on a concept ...
# 767038     Motivation Highthroughput technologies now all...
# 767230     Summary Hidden Markov models are widely applie...
# 767368     Motivation Largescale genotyping relies on the...
# 767813     Motivation Biological data generation has acce...
# 771659     Enduser development EUD activities range from ...
# 774462     Although Lisp was the host for many of the fir...
# 779939     Assembly sequence planning is one typical comb...
# 787640     The MADE constraint system provides excellent ...
# 792780     Within NASAs High Performance Computing and Co...
# 792819     Development of highperformance distributed app...
# ...
# 1218586    Motivation Modern systems biology aims at unde...
# 1218699    Summary Inferring population admixture from ge...
# 1220069    Motivation Next generation sequencing technolo...
# 1221276    We present a new algorithm for isolating the r...
# 1222123    Concept is a new and powerful language element...
# 1222129    Pipelining is a well understood and often used...
# 1224694    The SANE Virtual Processor SVP is an abstract ...
# 1225886    Dear KV Im working on a networked system that ...
# 1226005    Of the very few practical implementations of p...
# 1226271    Clustering of genes into groups sharing common...
# 1230917    Verification and conformance testing for proto...
# 1230960    Verification and testing are complementary tec...
# 1233734    In this paper we look at combining and compres...
# 1235114    In this work we introduce a novel approach for...
# 1239291    This paper proposes a systemlevel cyclebased f...
# 1240500    For the efficient and effective use of automat...
# 1241382    C++ template metaprogramming has been used wit...
# 1241391    The optimizations in modern compilers are cons...
# 1243385    A new hybrid page layout analysis algorithm is...
# 1243732    In the area of reengineering or repurposing of...
# 1243771    Multithreaded realtime applications run on pla...
# 1244346    This paper presents our experience using a dom...
# 1244347    I describe the initial attempt of experienced ...
# 1250772    Objectoriented languages involve a threefold t...
# 1251704    The era of parallel computing for the masses i...
# 1253524    This paper introduces hyperobjects a linguisti...
# 1253550    Transactional memory TM eliminates many proble...
# 1253570    The era of parallel computing for the masses i...
# 1257291    In order to solve the data integrity nonrepudi...
# 1257722    There are various implementations for the DEVS...
# 1257832    DEVS Modeling and Simulation MS has various im...
# 1259014    In theory the expressive power of an aspect la...
# 1259077    The software development process can be extrem...
# 1263524    During regression testing test cases from an e...
# 1266079    We have developed a new programming framework ...
# 1267146    The generic programming facilities of C++ allo...
# 1268419    Goanna is an industrialstrength static analysi...
# 1268478    Programmers typically have knowledge about pro...
# 1272865    Agent technology is emerging as an important c...
# 1273457    The powerlaw regularities have been discovered...
# 1275457    The query language OVAL which is intended for ...
# 1277857    FleXible yet efficient eXecution of heterogene...
# 1278395    In highperformance scientific software develop...
# 1278409    We have developed a new programming framework ...
# 1278452    In this paper we analyze the suitability of re...
# 1279172    The Bayesian classifier is a fundamental class...
# 1279298    FORTRAN and C software packages are often used...
# 1279299    We present pyMDO an objectoriented framework t...
# 1281765    In developing countries like India the traffic...
# 1284988    This paper describes the Generic Automated Mar...
# 1298684    This work discusses the application of an Arti...
# 1304143    Energybased learning EBL is a general framewor...
# 1305293    In this work an exact approach to solve the Er...
# 1305816    Theoretically multilanguage clients invocating...
# 1307393    A lot of information can be obtained from conf...
# 1307747    Neither the C nor the C++ languages support re...
# 1309601    In picking manipulator location system it is t...
# 1310761    the most time consuming element of a wireless ...
# 1312374    This article introduces the concept of combini...
# 1315246    Specialized networking protocol can be adapted...
# 1317303    A parallel skeleton library is a collection of...
# 1317338    Automated composition and optimization of work...
# 1317444    We address the issue of the development of per...
# 1318659    In this paper we review the computational laws...
# 1329920    Motivation Deregulated signaling cascades are ...
# 1333494    A review of Visual C++ NET Developers Guide by...
# 1333820    To quantify the flow of particles over a heter...
# 1336394    This research develops a realtime implementati...
# 1339356    Incorporating dimensionalanalysis facilities i...
# 1342072    This paper presents a scheme for automatic gra...
# 1342110    In this paper we will examine the Java languag...
# 1342166    The Educational Testing Service has decided th...
# 1342177    By providing a means to ask questions anonymou...
# 1508850    Presents a new specification technique for com...
# 1510193    Resource reservation is a vital issue for grid...
# 1510494    The design of high performance multimedia syst...
# 1511131    The Augmented Ordered Binary Decision Diagram ...
# 1511663    Puma is a framework for the development of app...
# 1514334    Buffer overflows are still a significant probl...
# 1517553    As highlevel models in C and SystemC are incre...
# 1517576    Embedded multiprocessors have always been hete...
# 1517611    High performance provided by multiprocessor Sy...
# 1518903    We propose new data structures for navigation ...
# 1524624    Epistasis or nonlinear genetogene interaction ...
# 1531899    Machine learning techniques are widely used in...
# 1532062    Exergy is a way to sustainable development and...
# 1537561    The web forum is the popular platform used for...
# 1540441    A tool supporting the automatic identification...
# 1540480    Program analysis tools used in software mainte...
# 1542459    In this paper we demonstrate our results of de...
# 1543794    Finitestate methods are well established in la...
# 1545306    Multicore nodes have become ubiquitous in just...
# 1547475    Compilers are typically hardwired to attempt o...
# 1547557    Most mainstream system programming languages p...
# 1550481    This paper describes a software framework we d...
# 1553768    Hardware coprocessors are used for acceleratin...
# 1562612    Programming is taught as foundation module at ...
# 1564626    This paper deals with localizing nodes in a se...
# 1565772    Offload C++ is an extended version of the C++ ...
# 1567913    The Standard Template Adaptive Parallel Librar...
# 1574102    Many countermeasures exist that attempt to pro...
# 1574887    The simulation of natural scenery is a very im...
# 1579526    This paper proposed the development jacquard c...
# 1579778    Traditional model checking methods to find saf...
# 1586234    This paper presents a product dynamic model an...
# 1588085    Motivated by the difficulty in predicting the ...
# 1590560    There are numerous examples of problems in sym...
# 1592321    The message passing interface lets users devel...
# 1592628    UserDefined Functions UDFs represent an extens...
# 1595130    A PDE solvers value is increasingly codetermin...
# 1601366    Modern computer systems require an enormous am...
# 1603925    This paper explores the definition application...
# 1603937    Multiple dispatchthe selection of a function t...
# 1606259    An arithmetic is described that can replace fl...
# 1606286    Efficient and easy implementation of variation...
# 1606299    We describe here a library aimed at automating...
# 1609406    An R package mixAK is introduced which impleme...
# 1622494    This paper studies the temporal communication ...
# Name: abstract, dtype: object
# # Example:
# 16477      This paper proposes a new practical automatic ...
# 24694      The term metaprogramming language is used to d...
# 30159      Presenter First PF is a technique for organizi...
# 30228      One day our customer a famous chip producer su...
# 32488      Dealing with crosscutting requirements in soft...
# 35309      Formal methods technique offer a means of veri...
# 37124      Tablet PCbased engineering software can be use...
# 44984      Interface types are a useful concept in object...
# 47021      Poorly structured code is hard to maintain and...
# 56566      Motivated by recent developments in Category t...
# 61200      We present Mavigator a prototype of a graphica...
# 85524      In this paper we introduce our new quantum cir...
# 125000     This paper gives an overview of OOMeter a soft...
# 142014     Transaction level modeling allows exploring se...
# 167853     Modelbased development methodologies are gaini...
# 175718     In this paper we describe an architectural fra...
# 188766     Dynamic linking supports flexible code deploym...
# 213534     Modeling software features with model programs...
# 260976     In this paper the PASIBC PlatformAgent pentru ...
# 298284     Mobile Agent Systems are not fully utilized be...
# 361390     Increasingly popular languages such as Java an...
# 362922     The contribution of this work is the design im...
# 364913     Source code analysis is important for software...
# 369857     A designing model and implementing method of a...
# 444386     In the development of embedded systems higherl...
# 450992     We present a method for static program analysi...
# 465244     As garbage collected languages become widely u...
# 466348     Reflective environments such as NET have provi...
# 466738     Java programmers cannot but be aware of Micros...
# 471746     Recently the Web Ontology Language OWL and XML...
# 480670     Web search engines have become an indispensabl...
# 521779     Componentbased software engineering enables ap...
# 521803     This paper describes how to add firstclass gen...
# 522124     Distinguishing nonnull references from possibl...
# 522319     Support for objectoriented programming has bec...
# 522365     Generalized algebraic data types GADTs have re...
# 522828     During the presentation we will demonstrate a ...
# 522846     NET Language Integrated Query LINQ is based on...
# 522956     Programs sometimes crash due to unusable value...
# 522979     C++ is a very successful objectoriented langua...
# 523040     When people hear Visual Basic they remember Qu...
# 523044     The NET intermediate language MSIL allows expr...
# 523168     Quota Queue is a new type of queue data struct...
# 526290     We introduce a new programming language constr...
# 538503     In this paper we describe an architecture tosu...
# 542666     The MicrosoftNET Common Language Runtime provi...
# 542958     Concurrent garbage collection is highly attrac...
# 543018     Garbagecollected languages such as Java and C#...
# 546793     Game developers have long been early adopters ...
# 546878     Program errors are hard to detect and are cost...
# 548566     As highperformance computing enters the mainst...
# 557360     The mutation technique inserts faults in a pro...
# 567710     Most mainstream objectoriented languages like ...
# 581503     Programminglanguage mechanisms for throwing an...
# 581684     Enterprise software systems need to deal with ...
# 584711     Microsoft MS NET is one of the recent represen...
# 588198     This paper describes our experience with selec...
# 597956     The integration of the NET Common Language Run...
# 601266     This paper makes two contributions a generaliz...
# 662025     The last decade has seen a wave of new technol...
# 669257     This tutorial is for advanced simulation devel...
# 669333     Silkreg and SML are software libraries of Java...
# 669337     This presentation reports on the opportunities...
# 669339     This tutorial is for advanced simulation devel...
# 674519     XML messaging is at the heart of Web services ...
# 678013     Two major efficiency parameters for garbage co...
# 685229     This paper studies the performance of generics...
# 685385     In the last years as objectoriented software s...
# 692366     A nondestructive detection system based on Xra...
# 693644     In this presentation we describe recent experi...
# 698836     This presentation describes our experience in ...
# 698923     We describe an expressionbased programming lan...
# 699281     Concurrent programming was once the preserve o...
# 699825     Mavigator is a graphical querying and browsing...
# 702399     In this paper a new architecture description l...
# 706472     Program errors are hard to detect and are cost...
# 717398     In this study a controlled fuzzy expert system...
# 717442     In the research are presented experimental sof...
# 725795     We present a new static aspect weaver for C#  ...
# 725800     Annotations are a recent feature introduced in...
# 734675     In this extended abstract we present our appro...
# 736080     Customers and stakeholders have substantial in...
# 736711     Simulation normally serves one of two purposes...
# 766574     Summary OxfordGrid is a web application and da...
# 766582     Summary IntegratedMap is a Web application and...
# 869587     Reasoning about multithreaded objectoriented p...
# 870150     Building multilingual software is a practical ...
# 876505     The state of knowledge in how to specify seque...
# 876535     We take a thread as the behavior of a sequenti...
# 879112     Modern concurrent programming languages like C...
# 981198     Jane Street Capital is a successful proprietar...
# 995702     We propose a method for implementing behaviora...
# 997121     Software components can be implemented and dis...
# 997586     Parameterization is an effective technique for...
# 1008504    This time I look at books designed to help you...
# 1036300    In the paper a new threelevel approach to the ...
# 1056872    We study the incorporation of generic types in...
# 1057028    Metaphor is a multistage programming language ...
# 1067373    This article describes how we extended the C# ...
# 1067677    The need for multimethods is preeminent in the...
# 1068361    This note describes and motivates our current ...
# 1071216    Microsofts nextgeneration platform the NET Fra...
# 1073785    We discuss P our implementation of a tool that...
# 1074137    C# is the new flagship language in the Microso...
# 1095428    Dynamic linking supports flexible code deploym...
# 1170021    This paper presents a new algorithm for recomm...
# 1182519    This case study reveals Daniel Webster College...
# 1182547    The Orthodox Form for C# Classes OFC#C is an i...
# 1182758    An objectoriented recursive descent parsing te...
# 1209213    Superimposition is a composition technique tha...
# 1210917    Applications continue to increase in size and ...
# 1212908    Privacy Integrated Queries PINQ is an extensib...
# 1224856    Large information systems are typically distri...
# 1233522    This paper summarizes the development of a rel...
# 1239403    Contemporary refactoring tools for Java aiding...
# 1241401    Generalized interfaces are an extension of the...
# 1244337    Concurrent ML CML is a highlevel messagepassin...
# 1245895    The adapter or wrapper pattern is one of the m...
# 1255828    We propose Anchor Garden AG an interactive wor...
# 1257832    DEVS Modeling and Simulation MS has various im...
# 1268827    In this study a controlled fuzzy expert system...
# 1277771    We present a new simulator for Underwater Sens...
# 1299663    Separation Logic SL provides a simple but powe...
# 1302335    Mutation testing is a faultbased testing techn...
# 1304968    In this work we focus on creating a benchmark ...
# 1305929    With the emergence of research prototypes prog...
# 1306726    Programming education is very important in eng...
# 1307367    IDEs Integrated Development Environments suppo...
# 1308649    This paper presents the results of the develop...
# 1312485    This paper presents methods and principles use...
# 1313163    We have developed a library for simulation of ...
# 1318836    Managed languages such as Java and C# are incr...
# 1339133    Two major efficiency parameters for garbage co...
# 1513953    Programming C# the top selling book on Microso...
# 1514484    Modern languages like Java and C# rely on dyna...
# 1539598    This paper presents an overview of the design ...
# 1545974    Managed languages such as Java and C# are bein...
# 1545984    Typed assembly language TAL and Hoare logic ca...
# 1545994    We present a new programming model GUEESSTIMAT...
# 1545999    Execution order constraints imposed by depende...
# 1547553    Specifying application interfaces APIs with in...
# 1579518    Dictionary is one of the most important charac...
# 1579790    Web Services for Automated Fault Analysis WSAF...
# Name: abstract, dtype: object

# %%
non_alphabetic_chars_set = set(re.findall(r'[^a-zA-Z\s]', ''.join(clean_data['venue'])))
non_alphabetic_chars_list = list(non_alphabetic_chars_set)
print("List of unique non-alphabetic characters:", non_alphabetic_chars_list)
# Out:
# List of unique non-alphabetic characters: ['+']

# %%
for char in non_alphabetic_chars_list:
    titles_with_char = clean_data[clean_data['venue'].str.contains(re.escape(char))]
    print(f'{char} Example:')
    print(titles_with_char['venue'])
# Out:
# + Example:
# 70104      C++ Workshop
# 70105    C++ Conference
# 70106    C++ Conference
# 70107    C++ Conference
# 70108    C++ Conference
# 70109    C++ Conference
# 70110    C++ Conference
# 70112    C++ Conference
# 70113      C++ Workshop
# 70114    C++ Conference
# 70115    C++ Conference
# 70116    C++ Conference
# 70117    C++ Conference
# 70118    C++ Conference
# 70119    C++ Conference
# 70120      C++ Workshop
# 70121    C++ Conference
# 70122    C++ Conference
# 70123    C++ Conference
# 70124    C++ Conference
# 70125    C++ Conference
# 70126      C++ Workshop
# 70127    C++ Conference
# 70128      C++ Workshop
# 70129    C++ Conference
# 70130    C++ Conference
# 70131    C++ Conference
# 70132    C++ Conference
# 70134    C++ Conference
# 70135    C++ Conference
# 70136    C++ Conference
# 70137      C++ Workshop
# 70138    C++ Conference
# 70139      C++ Workshop
# 70140    C++ Conference
# 70141    C++ Conference
# 70142    C++ Conference
# 70144    C++ Conference
# 70145    C++ Conference
# 70146    C++ Conference
# 70147    C++ Conference
# 70148    C++ Conference
# 70149    C++ Conference
# 70150    C++ Conference
# 70152    C++ Conference
# 70153      C++ Workshop
# 70154    C++ Conference
# 70155    C++ Conference
# 70156    C++ Conference
# 70157    C++ Conference
# 70158    C++ Conference
# 70159      C++ Workshop
# 70161    C++ Conference
# 70162    C++ Conference
# 70163    C++ Conference
# 70164      C++ Workshop
# 70165    C++ Conference
# 70166      C++ Workshop
# 70167    C++ Conference
# 70168    C++ Conference
# 70169      C++ Workshop
# 70170    C++ Conference
# 70171      C++ Workshop
# 70172      C++ Workshop
# 70173    C++ Conference
# 70174      C++ Workshop
# 70175    C++ Conference
# 70176      C++ Workshop
# 70177    C++ Conference
# 70178    C++ Conference
# 70179    C++ Conference
# 70180    C++ Conference
# 70181    C++ Conference
# 70182    C++ Conference
# 70183    C++ Conference
# 70184    C++ Conference
# 70185    C++ Conference
# 70186    C++ Conference
# 70187    C++ Conference
# 70188    C++ Conference
# 70189      C++ Workshop
# 70190    C++ Conference
# 70191      C++ Workshop
# 70192    C++ Conference
# 70193    C++ Conference
# 70194    C++ Conference
# 70195    C++ Conference
# 70196    C++ Conference
# 70197    C++ Conference
# 70198      C++ Workshop
# 70199      C++ Workshop
# 70201    C++ Conference
# 70203      C++ Workshop
# 70204      C++ Workshop
# 70205    C++ Conference
# 70206      C++ Workshop
# 70207    C++ Conference
# 70208    C++ Conference
# 70209    C++ Conference
# 70210    C++ Conference
# 70211    C++ Conference
# 70212    C++ Conference
# 70213    C++ Conference
# 70214      C++ Workshop
# 70215    C++ Conference
# 70216    C++ Conference
# 70217      C++ Workshop
# 70218    C++ Conference
# 70219    C++ Conference
# 70220      C++ Workshop
# 70221    C++ Conference
# 70222    C++ Conference
# 70223    C++ Conference
# 70224      C++ Workshop
# 70225    C++ Conference
# 70226    C++ Conference
# 70227    C++ Conference
# 70228    C++ Conference
# 70229    C++ Conference
# 70230    C++ Conference
# 70231    C++ Conference
# 70233    C++ Conference
# 70234    C++ Conference
# 70235    C++ Conference
# 70236    C++ Conference
# 70237    C++ Conference
# 70238    C++ Conference
# 70239      C++ Workshop
# 70240    C++ Conference
# Name: venue, dtype: object

# %% [markdown]
# ## Add Main Author

# %%
def get_main_author(authors_list):
    return authors_list[0]

# Function to extract secondary authors
def get_secondary_authors(authors_list):
    if len(authors_list) > 1:
        return authors_list[1:]  # Return all authors except the first
    else:
        return []  # Return an empty list if there's only one author

# Apply functions to create new columns
clean_data['MAIN_AUTHOR'] = clean_data['authors'].apply(get_main_author)
clean_data['SECONDARY_AUTHORS'] = clean_data['authors'].apply(get_secondary_authors)

# %%
clean_data.head(5)
# Out:
#                                                title  \
# 0  OQLC++ Extending C++ with an Object Query Capa...
# 1    Transaction Management in Multidatabase Systems
# 2                        Overview of the ADDS System
# 3  Multimedia Information Systems Issues and Appr...
# 4                            Active Database Systems
#
#                                              authors  year  \
# 0                                 [José A. Blakeley]  1995
# 1  [Yuri Breitbart, Hector Garcia-Molina, Abraham...  1995
# 2                     [Yuri Breitbart, Tom C. Reyes]  1995
# 3         [Stavros Christodoulakis, Leonidas Koveos]  1995
# 4   [Umeshwar Dayal, Eric N. Hanson, Jennifer Widom]  1995
#
#                      venue id references abstract  ISCITED_COUNT  \
# 0  Modern Database Systems  0         []                       5
# 1  Modern Database Systems  1         []                       0
# 2  Modern Database Systems  2         []                       0
# 3  Modern Database Systems  3         []                       2
# 4  Modern Database Systems  4   [995520]                      16
#
#    AUTHOR_COUNT  REF_COUNT              MAIN_AUTHOR  \
# 0             1          0         José A. Blakeley
# 1             3          0           Yuri Breitbart
# 2             2          0           Yuri Breitbart
# 3             2          0  Stavros Christodoulakis
# 4             3          1           Umeshwar Dayal
#
#                               SECONDARY_AUTHORS
# 0                                            []
# 1  [Hector Garcia-Molina, Abraham Silberschatz]
# 2                                [Tom C. Reyes]
# 3                             [Leonidas Koveos]
# 4              [Eric N. Hanson, Jennifer Widom]

# %% [markdown]
# ## Tokenize Title & Abstract

# %%
clean_data['TITLE_TOKEN'] = clean_data['title'].str.split()
clean_data['ABSTRACT_TOKEN'] = clean_data['abstract'].str.split()

# %% [markdown]
# # Insights

# %% [markdown]
# ## Author Related

# %%
author_citations_sum = clean_data.groupby('MAIN_AUTHOR')['ISCITED_COUNT'].sum().reset_index()
author_citations_sum_sorted = author_citations_sum.sort_values(by='ISCITED_COUNT', ascending=False)
author_citations_sum_sorted.head(50)
# Out:
#                       MAIN_AUTHOR  ISCITED_COUNT
# 278997             Rakesh Agrawal           6156
# 208727                M. R. Garey           4553
# 43909              C. A. R. Hoare           3160
# 198347             Leslie Lamport           2968
# 110103              Gerard Salton           2891
# 13647               Alfred V. Aho           2775
# 305814            Serge Abiteboul           2487
# 291830               Ronald Fagin           2457
# 232844        Michael Stonebraker           2376
# 334609           Thomas H. Cormen           2320
# 278633                Rajeev Alur           2292
# 58637   Christos H. Papadimitriou           2195
# 268530        Philip A. Bernstein           2145
# 222484               Martín Abadi           1980
# 22764                Anil K. Jain           1962
# 166562           Jon M. Kleinberg           1885
# 370186                Yoav Freund           1881
# 198321          Leslie G. Valiant           1859
# 203368              Luca Cardelli           1816
# 235029              Mihir Bellare           1813
# 226830            Maurice Herlihy           1805
# 306063                Sergey Brin           1774
# 136314              Ian T. Foster           1767
# 85413            Edmund M. Clarke           1763
# 283532     Ricardo A. Baeza-Yates           1761
# 153869          Jeffrey D. Ullman           1720
# 159059                   Jim Gray           1662
# 289609               Robin Milner           1612
# 48692               Catriel Beeri           1512
# 336142          Thorsten Joachims           1477
# 72278                 David Harel           1472
# 299386                Sally Floyd           1430
# 138989                 Ion Stoica           1427
# 369215                Yiming Yang           1359
# 158384                 Jiawei Han           1353
# 251774                  Noga Alon           1338
# 101040        Franco P. Preparata           1331
# 265787              Peter Buneman           1266
# 318539               Stefano Ceri           1247
# 33877              Barbara Liskov           1214
# 87922               Elisa Bertino           1184
# 133179               Hugues Hoppe           1157
# 324349          Surajit Chaudhuri           1129
# 231236         Michael J. Fischer           1123
# 245368             Nancy A. Lynch           1116
# 85490          Edsger W. Dijkstra           1110
# 73270                 David Maier           1089
# 67259                Dana Angluin           1084
# 359357                    Won Kim           1075
# 73083          David Lorge Parnas           1073

# %% [markdown]
# ## Venue Related

# %%
venue_citations_sum = clean_data.groupby('venue')['ISCITED_COUNT'].sum().reset_index()
venue_citations_sum_sorted = venue_citations_sum.sort_values(by='ISCITED_COUNT', ascending=False)
venue_citations_sum_sorted.head(50)
# Out:
#                                                   venue  ISCITED_COUNT
# 989                                          Commun ACM          54891
# 4658                                  SIGMOD Conference          34937
# 5310                                               VLDB          34921
# 0                                                                34632
# 4634                                           SIGGRAPH          28782
# 3231                                              J ACM          24647
# 500                                        Artif Intell          22622
# 2577                            IEEE Trans Software Eng          19873
# 2576                IEEE Trans Pattern Anal Mach Intell          18502
# 2520                                      IEEE Computer          17918
# 5167                                   Theor Comput Sci          17852
# 759                                                 CHI          17463
# 1191                                                DAC          17439
# 4648                                              SIGIR          17353
# 4176                                               POPL          17074
# 4750                                               STOC          16750
# 81                              ACM Trans Database Syst          16512
# 49                                      ACM Comput Surv          15060
# 2568                               IEEE Trans Computers          13529
# 4173                                               PODS          13169
# 2340                                               ICDE          13142
# 2603                                 IEEEACM Trans Netw          12666
# 90                          ACM Trans Program Lang Syst          12641
# 2453                                               ICSE          11340
# 5555                       Winter Simulation Conference          11236
# 4627                                            SIGCOMM          11224
# 84                                      ACM Trans Graph          10909
# 4611                                      SIAM J Comput          10670
# 3737                                   Machine Learning          10382
# 4163                                               PLDI          10158
# 2419                                               ICML          10104
# 881                                              CRYPTO          10047
# 1078                                  Computer Networks           9520
# 3380  Journal of Chemical Information and Computer S...           9069
# 3008                                   Inf Process Lett           9034
# 2572                          IEEE Trans Knowl Data Eng           8997
# 3006                                         Inf Comput           8896
# 3418                                                KDD           8763
# 3250                                  J Comput Syst Sci           8586
# 2813                                               ISCA           8449
# 3694                                            MOBICOM           8434
# 2302                                              ICCAD           8426
# 3984                                 Neural Computation           8132
# 888                                                CSCW           8122
# 4703                                               SODA           8030
# 4710                                               SOSP           7785
# 5518                                                WWW           7562
# 41                                                  ACL           7382
# 4040                                             OOPSLA           7382
# 3189           International Journal of Computer Vision           7367

# %% [markdown]
# ## Title Related

# %%
id_citations_sum = clean_data.groupby('id')['ISCITED_COUNT'].sum().reset_index()

# Step 2: Sort the IDs based on their sum of ISCITED_COUNT in descending order
id_citations_sum_sorted = id_citations_sum.sort_values(by='ISCITED_COUNT', ascending=False)

# Step 3: Select the top 50 IDs
top_50_ids = id_citations_sum_sorted.head(50)['id']

# Step 4: Use the top 50 IDs to retrieve corresponding titles from the 'data' DataFrame
top_50_titles = data[data['id'].isin(top_50_ids)][['id', 'title']]
top_50_titles_with_count = pd.merge(data[data['id'].isin(top_50_ids)], id_citations_sum_sorted, on='id')[['title', 'ISCITED_COUNT']]
top_50_titles_with_count.sort_values(by='ISCITED_COUNT', ascending=False)
# Out:
#                                                 title  ISCITED_COUNT
# 7   Computers and Intractability: A Guide to the T...           4474
# 8                          Introduction to Algorithms           2292
# 12                 Communicating Sequential Processes           1573
# 0        Compilers: Princiles, Techniques, and Tools.           1555
# 26  Mining Association Rules between Sets of Items...           1436
# 31  Fast Algorithms for Mining Association Rules i...           1415
# 9       Introduction to Modern Information Retrieval.           1353
# 1                        Modern Information Retrieval           1177
# 16          Computational Geometry - An Introduction.           1121
# 39  The Anatomy of a Large-Scale Hypertextual Web ...           1107
# 36  Time, Clocks, and the Ordering of Events in a ...           1104
# 25  Chord: A scalable peer-to-peer lookup service ...           1031
# 27  R-Trees: A Dynamic Index Structure for Spatial...            948
# 5   Principles of Database and Knowledge-Base Syst...            915
# 2   Concurrency Control and Recovery in Database S...            900
# 13                     Algorithms for Clustering Data            888
# 29  Authoritative Sources in a Hyperlinked Environ...            881
# 15                Object-Oriented Modeling and Design            800
# 24            A scalable content-addressable network.            795
# 44                                Bagging Predictors.            776
# 21  Pastry: Scalable, Decentralized Object Locatio...            768
# 46  Statecharts: A Visual Formalism for Complex Sy...            726
# 32          Ad-hoc On-Demand Distance Vector Routing.            692
# 43          The Unified Modeling Language User Guide.            661
# 22  Directed diffusion: a scalable and robust comm...            634
# 33    Maintaining Knowledge about Temporal Intervals.            627
# 40                         Data Clustering: A Review.            622
# 28  Access Path Selection in a Relational Database...            612
# 47                        A Theory of Timed Automata.            612
# 48  The Entity-Relationship Model - Toward a Unifi...            608
# 41  A Tutorial on Support Vector Machines for Patt...            605
# 45                           Support-Vector Networks.            600
# 42  Authoritative Sources in a Hyperlinked Environ...            594
# 35                Communicating Sequential Processes.            589
# 14  Combinatorial Optimization: Algorithms and Com...            589
# 17              Notes on Data Base Operating Systems.            588
# 49  Random early detection gateways for congestion...            587
# 34  The Notions of Consistency and Predicate Locks...            584
# 23  GPSR: greedy perimeter stateless routing for w...            582
# 10  Data Mining: Practical Machine Learning Tools ...            582
# 18  Text Categorization with Suport Vector Machine...            581
# 4                              Randomized Algorithms.            563
# 20  MediaBench: A Tool for Evaluating and Synthesi...            563
# 30                          A Theory of the Learnable            561
# 3   Automatic Text Processing: The Transformation,...            558
# 38                Wireless sensor networks: a survey.            551
# 6   Algorithms on Strings, Trees, and Sequences - ...            539
# 11               Data Mining: Concepts and Techniques            539
# 37                         A Theory of the Learnable.            529
# 19                        Mining Sequential Patterns.            522

# %% [markdown]
# # Export CSV

# %%
clean_data.to_csv('clean_data.csv', index=False)
