# %% [markdown]
# # Import dataset and package

# %%
import numpy as np
import pandas as pd
import scipy.stats as st
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

import re

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk import pos_tag

from sklearn.decomposition import LatentDirichletAllocation
from sklearn.model_selection import GridSearchCV
import random
random.seed(10)

import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import spacy
from wordcloud import WordCloud

# %%
citation = pd.read_csv("clean_data.csv")

# %%
citation.head()
# Out:
#                                                title  \
# 0  OQLC++ Extending C++ with an Object Query Capa...
# 1    Transaction Management in Multidatabase Systems
# 2                        Overview of the ADDS System
# 3  Multimedia Information Systems Issues and Appr...
# 4                            Active Database Systems
#
#                                              authors  year  \
# 0                               ['José A. Blakeley']  1995
# 1  ['Yuri Breitbart', 'Hector Garcia-Molina', 'Ab...  1995
# 2                 ['Yuri Breitbart', 'Tom C. Reyes']  1995
# 3     ['Stavros Christodoulakis', 'Leonidas Koveos']  1995
# 4  ['Umeshwar Dayal', 'Eric N. Hanson', 'Jennifer...  1995
#
#                      venue  id  references abstract  ISCITED_COUNT  \
# 0  Modern Database Systems   0          []      NaN              5
# 1  Modern Database Systems   1          []      NaN              0
# 2  Modern Database Systems   2          []      NaN              0
# 3  Modern Database Systems   3          []      NaN              2
# 4  Modern Database Systems   4  ['995520']      NaN             16
#
#    AUTHOR_COUNT  REF_COUNT              MAIN_AUTHOR  \
# 0             1          0         José A. Blakeley
# 1             3          0           Yuri Breitbart
# 2             2          0           Yuri Breitbart
# 3             2          0  Stavros Christodoulakis
# 4             3          1           Umeshwar Dayal
#
#                                   SECONDARY_AUTHORS  \
# 0                                                []
# 1  ['Hector Garcia-Molina', 'Abraham Silberschatz']
# 2                                  ['Tom C. Reyes']
# 3                               ['Leonidas Koveos']
# 4              ['Eric N. Hanson', 'Jennifer Widom']
#
#                                          TITLE_TOKEN ABSTRACT_TOKEN
# 0  ['oqlc++', 'extending', 'c++', 'with', 'an', '...             []
# 1  ['transaction', 'management', 'in', 'multidata...             []
# 2        ['overview', 'of', 'the', 'adds', 'system']             []
# 3  ['multimedia', 'information', 'systems', 'issu...             []
# 4                  ['active', 'database', 'systems']             []

# %%
citation.shape
# Out:
# (1083641, 14)

# %%
citation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1083641 entries, 0 to 1083640
# Data columns (total 14 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   title              1083606 non-null  object
#  1   authors            1083641 non-null  object
#  2   year               1083641 non-null  int64
#  3   venue              1083107 non-null  object
#  4   id                 1083641 non-null  int64
#  5   references         1083641 non-null  object
#  6   abstract           294358 non-null   object
#  7   ISCITED_COUNT      1083641 non-null  int64
#  8   AUTHOR_COUNT       1083641 non-null  int64
#  9   REF_COUNT          1083641 non-null  int64
#  10  MAIN_AUTHOR        1074140 non-null  object
#  11  SECONDARY_AUTHORS  1083641 non-null  object
#  12  TITLE_TOKEN        1083641 non-null  object
#  13  ABSTRACT_TOKEN     1083641 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 115.7+ MB

# %%
citation["ISCITED_COUNT"].describe()
# Out:
# count    1.083641e+06
# mean     1.562385e+00
# std      1.122518e+01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      4.474000e+03
# Name: ISCITED_COUNT, dtype: float64

# %%
# Calculate sample size
# alpha = 0.05
# margin of error = 0.2
std = citation["ISCITED_COUNT"].describe()["std"]
n = st.norm.ppf(.975)**2 * std**2 / 0.2**2
print("Sample size:", round(n))
# Out:
# Sample size: 12101

# %%
np.random.seed(10)
rand_index = np.random.randint(0,citation.shape[0],size=round(n))

# %%
rand_index
# Out:
# array([1048548,  617841,  804336, ...,  879802,  303645,  217263])

# %%
citation_sample = citation.loc[rand_index]

# %%
citation_sample.reset_index(inplace = True)
citation_sample.to_csv("citation_sample.csv", index = False)

# %%
def categorize_citations(citation_count):
    if citation_count == 0:
        return 'Seldom Cited'
    elif 0 < citation_count <= 10:
        return 'Moderately Cited'
    elif 10 < citation_count <= 100:
        return 'Frequently Cited'
    else:
        return 'Highly Cited'

# %%
citation_sample
# Out:
#          index                                              title  \
# 0      1048548  Securing communication using function extracti...
# 1       617841     Compressing Data Cube in Parallel OLAP Systems
# 2       804336  Distributed Resource Administration Using Cfen...
# 3       960506  Existence of positive solutions of BVPs for se...
# 4       710912       Integrating Searching and Authoring in Mizar
# ...        ...                                                ...
# 12096   894852                                          Editorial
# 12097   662346  HDR Image Compression by Local Adaptation for ...
# 12098   879802    Quantifying and setting off network performance
# 12099   303645  HardwareMeasurements of Storage Access Conflic...
# 12100   217263  Detection and Segmentation of Touching Charact...
#
#                                                  authors  year  \
# 0                                     ['K. Vimal Kumar']  2009
# 1      ['Frank K. H. A. Dehne', 'Todd Eavis', 'Boyong...  2007
# 2                      ['Mark Burgess', 'Ricky Ralston']  1997
# 3       ['Wan-Tong Li', 'Ming-Fei Niu', 'Jian-Ping Sun']  2004
# 4                       ['Paul A. Cairns', 'Jeremy Gow']  2007
# ...                                                  ...   ...
# 12096                               ['Richard Zurawski']  2007
# 12097  ['Lijie Wang', 'Takahiko Horiuchi', 'Hiroaki K...  2007
# 12098                                   ['Erik Hofmann']  2006
# 12099  ['Uwe Hercksen', 'Rainer Klar', 'Wolfgang Klei...  1980
# 12100  ['Akihiro Nomura', 'Kazuyuki Michishita', 'Sei...  2003
#
#                                      venue       id  \
# 0                      Computers  Security  1587640
# 1                     Data Science Journal   839971
# 2                        Softw Pract Exper  1073637
# 3      Applied Mathematics and Computation  1280289
# 4                        J Autom Reasoning   955214
# ...                                    ...      ...
# 12096    IEEE Trans Industrial Informatics  1187416
# 12097                   IEICE Transactions   896194
# 12098                                IJNVO  1170232
# 12099                                 ISCA   418893
# 12100                                ICDAR   295322
#
#                                               references  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4      ['595127', '954818', '612606', '893021', '5009...
# ...                                                  ...
# 12096                                                 []
# 12097                                                 []
# 12098                                                 []
# 12099                                                 []
# 12100                                                 []
#
#                                                 abstract  ISCITED_COUNT  \
# 0                                                    NaN              0
# 1                                                    NaN              0
# 2                                                    NaN             15
# 3                                                    NaN              0
# 4      The vision of a computerized assistant to math...              0
# ...                                                  ...            ...
# 12096                                                NaN              0
# 12097  Adaptation process of retina helps human visua...              0
# 12098  While many aspects of the network and the coll...              0
# 12099                                                NaN              0
# 12100  A technique for the detection and the segmenta...              1
#
#        AUTHOR_COUNT  REF_COUNT           MAIN_AUTHOR  \
# 0                 1          0        K. Vimal Kumar
# 1                 3          0  Frank K. H. A. Dehne
# 2                 2          0          Mark Burgess
# 3                 3          0           Wan-Tong Li
# 4                 2         10        Paul A. Cairns
# ...             ...        ...                   ...
# 12096             1          0      Richard Zurawski
# 12097             3          0            Lijie Wang
# 12098             1          0          Erik Hofmann
# 12099             3          0          Uwe Hercksen
# 12100             4          0        Akihiro Nomura
#
#                                        SECONDARY_AUTHORS  \
# 0                                                     []
# 1                         ['Todd Eavis', 'Boyong Liang']
# 2                                      ['Ricky Ralston']
# 3                      ['Ming-Fei Niu', 'Jian-Ping Sun']
# 4                                         ['Jeremy Gow']
# ...                                                  ...
# 12096                                                 []
# 12097            ['Takahiko Horiuchi', 'Hiroaki Kotera']
# 12098                                                 []
# 12099              ['Rainer Klar', 'Wolfgang Kleinöder']
# 12100  ['Kazuyuki Michishita', 'Seiichi Uchida', 'Mas...
#
#                                              TITLE_TOKEN  \
# 0      ['securing', 'communication', 'using', 'functi...
# 1      ['compressing', 'data', 'cube', 'in', 'paralle...
# 2      ['distributed', 'resource', 'administration', ...
# 3      ['existence', 'of', 'positive', 'solutions', '...
# 4      ['integrating', 'searching', 'and', 'authoring...
# ...                                                  ...
# 12096                                      ['editorial']
# 12097  ['hdr', 'image', 'compression', 'by', 'local',...
# 12098  ['quantifying', 'and', 'setting', 'off', 'netw...
# 12099  ['hardwaremeasurements', 'of', 'storage', 'acc...
# 12100  ['detection', 'and', 'segmentation', 'of', 'to...
#
#                                           ABSTRACT_TOKEN
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4      ['the', 'vision', 'of', 'a', 'computerized', '...
# ...                                                  ...
# 12096                                                 []
# 12097  ['adaptation', 'process', 'of', 'retina', 'hel...
# 12098  ['while', 'many', 'aspects', 'of', 'the', 'net...
# 12099                                                 []
# 12100  ['a', 'technique', 'for', 'the', 'detection', ...
#
# [12101 rows x 15 columns]

# %%
cite_counts = citation_sample["ISCITED_COUNT"].apply(categorize_citations)

# %%
cite_counts.value_counts()
# Out:
# ISCITED_COUNT
# Seldom Cited        9417
# Moderately Cited    2317
# Frequently Cited     354
# Highly Cited          13
# Name: count, dtype: int64

# %%
sel_cite_prop = 9417/(9417+2317+354+13)
mod_cite_prop = 2317/(9417+2317+354+13)
fre_cite_prop = 354/(9417+2317+354+13)
high_cite_prop = 13/(9417+2317+354+13)
print(sel_cite_prop, mod_cite_prop, fre_cite_prop, high_cite_prop)
# Out:
# 0.7782001487480373 0.19147177919180233 0.029253780679282703 0.0010742913808776135

# %%
cite_counts_full = citation["ISCITED_COUNT"].apply(categorize_citations)

# %%
cite_counts_full.value_counts()
# Out:
# ISCITED_COUNT
# Seldom Cited        840792
# Moderately Cited    208274
# Frequently Cited     33213
# Highly Cited          1362
# Name: count, dtype: int64

# %%
sel_cite_prop = 840792/(840792+208274+33213+1362)
mod_cite_prop = 208274/(840792+208274+33213+1362)
fre_cite_prop = 33213/(840792+208274+33213+1362)
high_cite_prop = 1362/(840792+208274+33213+1362)
print(sel_cite_prop, mod_cite_prop, fre_cite_prop, high_cite_prop)
# Out:
# 0.7758953380316913 0.19219833874871844 0.03064944940252353 0.0012568738170667224
