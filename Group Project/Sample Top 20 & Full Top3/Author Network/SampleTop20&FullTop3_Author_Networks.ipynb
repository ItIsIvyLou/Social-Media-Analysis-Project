# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from itertools import combinations
import community
import community as community_louvain
from networkx.algorithms.community import k_clique_communities

import random
import plotly.graph_objects as go
import heapq
import numpy as np

from igraph import *
import igraph as ig

from IPython.display import display

# Set random seed for Python's random module
random.seed(42)

# Set random seed for NumPy
np.random.seed(42)

# %% [markdown]
# ### Visualization Function

# %%
def visualize_network_with_plotly(G, layout_type='spring', color_dict=None, node_size=300, title="Network", pos=None):
    # Compute node positions using the specified layout algorithm
    if pos is None:
        if layout_type == 'spring':
            pos = nx.spring_layout(G)
        elif layout_type == 'random':
            pos = nx.random_layout(G)
        elif layout_type == 'circular':
            pos = nx.circular_layout(G)
        elif layout_type == 'kamada_kawai':
            pos = nx.kamada_kawai_layout(G)
        elif layout_type == 'shell':
            pos = nx.shell_layout(G)

    # Create edge trace
    edge_x = []
    edge_y = []
    for edge in G.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])

    edge_trace = go.Scatter(
        x=edge_x, y=edge_y,
        line=dict(width=0.5, color='#888'),
        hoverinfo='none',
        mode='lines')

    # Create node trace
    node_x = []
    node_y = []
    for node in G.nodes():
        x, y = pos[node]
        node_x.append(x)
        node_y.append(y)

    node_trace = go.Scatter(
        x=node_x, y=node_y,
        mode='markers',
        hoverinfo='text',
        marker=dict(
            showscale=True,
            colorscale='viridis',
            reversescale=True,
            color=[],
            size=node_size,
            colorbar=dict(
                thickness=15,
                title='Node Connections',
                xanchor='left',
                titleside='right'
            ),
            line_width=2))

    node_adjacencies = []
    node_text = []
    for node, adjacencies in G.adjacency():
        x, y = pos[node]
        node_adjacencies.append(len(adjacencies))
        node_text.append(f'Node {node}<br># of connections: {len(adjacencies)}')

    node_trace.marker.color = node_adjacencies
    node_trace.text = node_text

    # Create figure
    fig = go.Figure(data=[edge_trace, node_trace],
                    layout=go.Layout(
                        title=title,
                        titlefont_size=16,
                        showlegend=False,
                        hovermode='closest',
                        margin=dict(b=20, l=5, r=5, t=40),
                        annotations=[dict(
                            showarrow=False,
                            xref="paper", yref="paper",
                            x=0.005, y=-0.002)],
                        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
                    )

    # Show plot
    fig.show()

# %% [markdown]
# ### Community Library

# %%
def community_layout(g, partition):
    """
    Compute the layout for a modular graph.
    """

    pos_communities = _position_communities(g, partition, scale=3.)

    pos_nodes = _position_nodes(g, partition, scale=1.)

    # combine positions
    pos = dict()
    for node in g.nodes():
        pos[node] = pos_communities[node] + pos_nodes[node]

    return pos

def _position_communities(g, partition, **kwargs):

    # create a weighted graph, in which each node corresponds to a community,
    # and each edge weight to the number of edges between communities
    between_community_edges = _find_between_community_edges(g, partition)

    communities = set(partition.values())
    hypergraph = nx.DiGraph()
    hypergraph.add_nodes_from(communities)
    for (ci, cj), edges in between_community_edges.items():
        hypergraph.add_edge(ci, cj, weight=len(edges))

    # find layout for communities
    pos_communities = nx.spring_layout(hypergraph, **kwargs)

    # set node positions to position of community
    pos = dict()
    for node, community in partition.items():
        pos[node] = pos_communities[community]

    return pos

def _find_between_community_edges(g, partition):

    edges = dict()

    for (ni, nj) in g.edges():
        ci = partition[ni]
        cj = partition[nj]

        if ci != cj:
            try:
                edges[(ci, cj)] += [(ni, nj)]
            except KeyError:
                edges[(ci, cj)] = [(ni, nj)]

    return edges

def _position_nodes(g, partition, **kwargs):
    """
    Positions nodes within communities.
    """

    communities = dict()
    for node, community in partition.items():
        try:
            communities[community] += [node]
        except KeyError:
            communities[community] = [node]

    pos = dict()
    for ci, nodes in communities.items():
        subgraph = g.subgraph(nodes)
        pos_subgraph = nx.spring_layout(subgraph, **kwargs)
        pos.update(pos_subgraph)

    return pos

# %% [markdown]
# ## 1. Sample Top 20 Paper Author Network

# %% [markdown]
# ### Network Graph

# %%
# Read the CSV file into a pandas DataFrame
df_sample = pd.read_csv('/Users/zy/Documents/GitHub/Social-Media-Analysis-Project/Group Project/Sample Top 20 & Full Top3/Citation Network/top_20_sample.csv', index_col=0)  # Assuming the first column contains the author names

# Function to construct co-authorship network
def construct_coauthorship_network(data):
    G = nx.Graph()
    
    # Add nodes (authors)
    authors = set()
    for authors_list in data['authors']:
        authors.update(eval(authors_list))
    for author in authors:
        G.add_node(author)
    
    # Add edges (co-authorships)
    for authors_list in data['authors']:
        authors_list = eval(authors_list)
        for i in range(len(authors_list)):
            for j in range(i + 1, len(authors_list)):
                if not G.has_edge(authors_list[i], authors_list[j]):
                    G.add_edge(authors_list[i], authors_list[j])
    
    return G

network_author = construct_coauthorship_network(df_sample)
visualize_network_with_plotly(network_author, node_size=10, title="Sample Co-authorship Network", pos=nx.spring_layout(network_author, k=0.2, seed=42))

# %% [markdown]
# #### 1.1 Influencer Analysis

# %%
def calculate_degree_centrality(G):
    degree_centrality = nx.degree_centrality(G)
    sorted_degree_centrality = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)
    return sorted_degree_centrality

def calculate_closeness_centrality(G):
    closeness_centrality = nx.closeness_centrality(G)
    sorted_closeness_centrality = sorted(closeness_centrality.items(), key=lambda x: x[1], reverse=True)
    return sorted_closeness_centrality

def calculate_betweenness_centrality(G):
    betweenness_centrality = nx.betweenness_centrality(G)
    sorted_betweenness_centrality = sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True)
    return sorted_betweenness_centrality

def calculate_igenvector_entrality(G):
    eigenvector_centrality = nx.eigenvector_centrality(G)
    sorted_eigenvector_centrality = sorted(eigenvector_centrality.items(), key=lambda x: x[1], reverse=True)
    return sorted_eigenvector_centrality

# %%
degree_centrality = calculate_degree_centrality(network_author)[:5]
closeness_centrality = calculate_closeness_centrality(network_author)[:5]
betweenness_centrality = calculate_betweenness_centrality(network_author)[:5]
eigenvector_centrality = calculate_igenvector_entrality(network_author)[:5]

# Create DataFrames
df_degree_centrality = pd.DataFrame(degree_centrality, columns=['Author', 'Degree Centrality'])
df_closeness_centrality = pd.DataFrame(closeness_centrality, columns=['Author', 'Closeness Centrality'])
df_betweenness_centrality = pd.DataFrame(betweenness_centrality, columns=['Author', 'Betweenness Centrality'])
df_eigenvector_centrality = pd.DataFrame(eigenvector_centrality, columns=['Author', 'Eigenvector Centrality'])

# %%
df_degree_centrality
# Out:
#                   Author  Degree Centrality
# 0      W. Frank King III           0.035326
# 1  Gianfranco R. Putzolu           0.035326
# 2               Jim Gray           0.035326
# 3        Paul R. McJones           0.035326
# 4     Morton M. Astrahan           0.035326

# %%
df_closeness_centrality
# Out:
#                   Author  Closeness Centrality
# 0      W. Frank King III              0.035326
# 1  Gianfranco R. Putzolu              0.035326
# 2               Jim Gray              0.035326
# 3        Paul R. McJones              0.035326
# 4     Morton M. Astrahan              0.035326

# %%
df_betweenness_centrality
# Out:
#                   Author  Betweenness Centrality
# 0    Narciso Martí-Oliet                0.000267
# 1          Samuel Madden                0.000148
# 2  Joseph M. Hellerstein                0.000089
# 3       John D. Lafferty                0.000030
# 4        David J. DeWitt                0.000030

# %%
df_eigenvector_centrality
# Out:
#                   Author  Eigenvector Centrality
# 0      W. Frank King III                0.267261
# 1  Gianfranco R. Putzolu                0.267261
# 2               Jim Gray                0.267261
# 3        Paul R. McJones                0.267261
# 4     Morton M. Astrahan                0.267261

# %% [markdown]
# 1. **Degree Centrality:**
#    - All of these authors have the same degree centrality score, indicating that they have collaborated on the same number of papers with other authors in the network.
#    - This suggests that these authors are equally influential in terms of the number of collaborations they have.
#
# 2. **Closeness Centrality:**
#    - Again, all of these authors have the same closeness centrality score, indicating that they are equally central in terms of their proximity to other authors in the network.
#    - This suggests that these authors are equally well-connected to other authors in the network.
#
# 3. **Betweenness Centrality:**
#    - These authors have higher betweenness centrality scores compared to others, indicating that they act as bridges or intermediaries between different clusters of authors in the network.
#    - This suggests that these authors play a significant role in connecting different parts of the collaboration network and facilitating the flow of information between them.
#
# 4. **Eigenvector Centrality:**
#    - All of these authors have the same eigenvector centrality score, indicating that they are equally influential based on their connections to other influential authors in the network.
#    - This suggests that these authors are not only well-connected but also connected to other influential authors, which enhances their overall influence in the network.

# %% [markdown]
# #### 1.2 Community Detection

# %%
def detect_communities(G):
    partition = community_louvain.best_partition(G)
    return partition

communities = detect_communities(network_author)

# Convert communities dictionary to DataFrame
community_df = pd.DataFrame(communities.items(), columns=['Author', 'Community'])

# Display the result DataFrame
print(community_df)
# Out:
#                     Author  Community
# 0    Heiner Stuckenschmidt          0
# 1          Petros Maniatis          1
# 2         Olivier Chapelle          2
# 3             André Seznec          3
# 4       Raghu Ramakrishnan          4
# ..                     ...        ...
# 364    Ralf Hartmut Güting         46
# 365       Raymond A. Lorie         32
# 366            Sally Floyd        120
# 367   Hector Garcia-Molina         57
# 368        Fabrizio Falchi         36
#
# [369 rows x 2 columns]

# %%
def compute_community_statistics(G, partition):
    # Invert the partition dictionary to map community IDs to nodes
    community_nodes = {}
    for node, community_id in partition.items():
        if community_id not in community_nodes:
            community_nodes[community_id] = []
        community_nodes[community_id].append(node)
    
    # Compute statistics for each community
    community_stats = {}
    for community_id, nodes in community_nodes.items():
        subgraph = G.subgraph(nodes)
        avg_degree_centrality = np.mean(list(nx.degree_centrality(subgraph).values()))
        collaboration_count = subgraph.number_of_edges()
        avg_closeness_centrality = np.mean(list(nx.closeness_centrality(subgraph).values()))
        avg_betweenness_centrality = np.mean(list(nx.betweenness_centrality(subgraph).values()))
        community_size = len(nodes)
        community_stats[community_id] = {
            'Average Degree Centrality': avg_degree_centrality,
            'Collaboration Count': collaboration_count,
            'Average Closeness Centrality': avg_closeness_centrality,
            'Average Betweenness Centrality': avg_betweenness_centrality,
            'Community Size': community_size
        }
    return community_stats

# Compute community statistics
partition = community.best_partition(network_author.to_undirected())
community_stats = compute_community_statistics(network_author, partition)

# Print insightful information for each community
for community_id, stats in community_stats.items():
    print(f"Community {community_id} Statistics:")
    for metric, value in stats.items():
        print(f"- {metric}: {value}")
    print()
# Out:
# Community 0 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 1 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 15
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 6
#
# Community 2 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 28
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 8
#
# Community 3 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 4 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 10
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 5
#
# Community 5 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 99 Statistics:
# - Average Degree Centrality: 0.49999999999999994
# - Collaboration Count: 14
# - Average Closeness Centrality: 0.6620459401709402
# - Average Betweenness Centrality: 0.09523809523809523
# - Community Size: 8
#
# Community 7 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 8 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 9 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 10 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 11 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 21
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 7
#
# Community 12 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 13 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 14 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 15 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 10
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 5
#
# Community 16 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 17 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 18 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 19 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 2
# - Average Closeness Centrality: 0.7777777777777777
# - Average Betweenness Centrality: 0.3333333333333333
# - Community Size: 3
#
# Community 20 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 21 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 10
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 5
#
# Community 22 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 23 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 24 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 25 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 26 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 27 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 28 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 29 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 30 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 31 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 10
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 5
#
# Community 32 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 91
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 14
#
# Community 33 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 34 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 10
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 5
#
# Community 35 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 10
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 5
#
# Community 36 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 37 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 38 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 39 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 40 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 41 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 4
# - Average Closeness Centrality: 0.775
# - Average Betweenness Centrality: 0.16666666666666666
# - Community Size: 4
#
# Community 42 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 43 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 44 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 45 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 46 Statistics:
# - Average Degree Centrality: 0.6
# - Collaboration Count: 27
# - Average Closeness Centrality: 0.73
# - Average Betweenness Centrality: 0.05
# - Community Size: 10
#
# Community 47 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 48 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 49 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 50 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 51 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 10
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 5
#
# Community 52 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 53 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 54 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 55 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 56 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 57 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 58 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 59 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 60 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 61 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 62 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 63 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 64 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 65 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 66 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 67 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 15
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 6
#
# Community 68 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 69 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 70 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 71 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 72 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 73 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 74 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 75 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 77 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 78 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 79 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 80 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 81 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 82 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 83 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 84 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 85 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 4
# - Average Closeness Centrality: 0.775
# - Average Betweenness Centrality: 0.16666666666666666
# - Community Size: 4
#
# Community 86 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 87 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 2
# - Average Closeness Centrality: 0.7777777777777777
# - Average Betweenness Centrality: 0.3333333333333333
# - Community Size: 3
#
# Community 88 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 89 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 90 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 91 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 92 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 93 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 94 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 95 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 96 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 97 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 98 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 100 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 101 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 102 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 103 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 104 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 105 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 106 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 107 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 108 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 109 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 110 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 111 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 112 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 113 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 114 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 115 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 116 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 117 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 118 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 119 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 120 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 2
# - Average Closeness Centrality: 0.7777777777777777
# - Average Betweenness Centrality: 0.3333333333333333
# - Community Size: 3
#
# Community 121 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 122 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 123 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 124 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 125 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 126 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 127 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 76 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 6 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1

# %% [markdown]
# Community 0 consists of 3 authors. Here's what each statistic means:
#
# 1. **Average Degree Centrality**: The average degree centrality of 1.0 indicates that, on average, each author in this community is directly connected to all other authors within the community. This suggests a tightly interconnected group where each author collaborates with the other two authors.
#
# 2. **Collaboration Count**: The collaboration count of 3 indicates that there are a total of 3 collaborations within this community. Each collaboration represents a co-authored paper or project involving authors within the community.
#
# 3. **Average Closeness Centrality**: The average closeness centrality of 1.0 suggests that, on average, each author in this community is close to all other authors in terms of the shortest path length. This indicates a high level of closeness and efficient communication among the authors within the community.
#
# 4. **Average Betweenness Centrality**: The average betweenness centrality of 0.0 indicates that none of the authors in this community act as intermediaries or bridges between other authors in the network. Each author's position within the community does not significantly influence the flow of information between other authors.
#
# 5. **Community Size**: The community size of 3 indicates that there are a total of 3 authors within this community.
#
# In summary, Community 0 represents a tightly-knit group of 3 authors who collaborate closely with each other on multiple projects, with efficient communication and no clear intermediaries.

# %% [markdown]
# The insights from Community 0 can be valuable for several business considerations:
#
# 1. **Efficient Collaboration**: The high degree centrality and collaboration count indicate that the authors within this community work closely together on multiple projects. This suggests a high level of efficiency in collaboration, which can lead to faster project completion, innovative ideas, and potentially higher productivity.
#
# 2. **Strong Communication**: The high average closeness centrality suggests that communication among authors within the community is efficient and direct. This can lead to better coordination, reduced miscommunication, and faster decision-making processes.
#
# 3. **Team Dynamics**: Understanding the dynamics within Community 0 can provide insights into effective team structures and collaboration strategies. Businesses can learn from these dynamics to enhance teamwork and foster stronger relationships among team members.
#
# 4. **Identifying Key Contributors**: While there is no clear intermediary (as indicated by the low average betweenness centrality), businesses can identify key contributors within this community who play essential roles in collaboration and knowledge sharing. Recognizing these key contributors can help in promoting leadership and facilitating knowledge transfer within the organization.
#
# 5. **Potential for Innovation**: The tightly-knit nature of this community suggests a conducive environment for innovation and idea generation. Businesses can leverage the synergies within this community to drive innovation initiatives, develop new products or services, and stay competitive in the market.

# %% [markdown]
# #### 1.3 Collaboration Pattern Over Time

# %%
def analyze_collaboration_over_time(data):
    collaboration_over_time = {}
    for i, row in data.iterrows():
        year = row['year']
        authors_list = eval(row['authors'])
        for i in range(len(authors_list)):
            for j in range(i + 1, len(authors_list)):
                collaboration = tuple(sorted([authors_list[i], authors_list[j]]))
                if collaboration not in collaboration_over_time:
                    collaboration_over_time[collaboration] = []
                collaboration_over_time[collaboration].append(year)
    return collaboration_over_time

# Use the function
collaboration_over_time = analyze_collaboration_over_time(df_sample)

# Convert to DataFrame
collaboration_df = pd.DataFrame(columns=['Author 1', 'Author 2', 'Collaboration Years'])
rows = []
for collab, years in collaboration_over_time.items():
    author1, author2 = collab
    rows.append({'Author 1': author1, 'Author 2': author2, 'Collaboration Years': years})

collaboration_df = pd.concat([collaboration_df, pd.DataFrame(rows)], ignore_index=True)

# Print the collaboration patterns over time
print(collaboration_df)
# Out:
#                   Author 1              Author 2 Collaboration Years
# 0    Joseph M. Hellerstein   Michael Stonebraker  [1993, 1993, 1993]
# 1       Richard H. Lathrop  Thomas G. Dietterich              [1997]
# 2     Thomas G. Dietterich    Tomás Lozano-Pérez              [1997]
# 3       Richard H. Lathrop    Tomás Lozano-Pérez              [1997]
# 4          David J. DeWitt          Goetz Graefe  [1987, 1987, 1987]
# ..                     ...                   ...                 ...
# 517       Geneviève Jomier         Khaled Jouini              [2007]
# 518        George Beskales    Mohamed A. Soliman              [2008]
# 519        George Beskales         Ihab F. Ilyas              [2008]
# 520          Ihab F. Ilyas    Mohamed A. Soliman              [2008]
# 521        Christian Kalus           Peter Dadam              [1995]
#
# [522 rows x 3 columns]

# %% [markdown]
# 1. **Identifying Strong Collaborative Relationships**: Authors who collaborate frequently over multiple years, as evidenced by repeated entries in the collaboration years column, likely have strong collaborative relationships. Leveraging these relationships can lead to more successful joint projects and research endeavors.
#
# 2. **Assessing Research Impact**: Authors who collaborate across multiple years and with a diverse range of collaborators may have a broader impact on their field. Collaborations that span several years and involve different partners indicate sustained research efforts and potentially higher-quality research output.
#
# 3. **Strategic Partnership Opportunities**: Organizations seeking to establish strategic partnerships or collaborations can use this data to identify potential partners with a history of productive collaboration and aligned research interests. Building partnerships with these collaborators can lead to mutually beneficial outcomes and facilitate knowledge exchange.

# %% [markdown]
# #### 1.4 Potential Collaborators

# %%
def identify_potential_collaborators(G, author):
    potential_collaborators = []
    for other_author in G.nodes():
        if other_author != author and not G.has_edge(author, other_author):
            common_neighbors = len(list(nx.common_neighbors(G, author, other_author)))
            if common_neighbors > 0:
                potential_collaborators.append((other_author, common_neighbors))
    # Sort potential collaborators by number of common neighbors
    potential_collaborators.sort(key=lambda x: x[1], reverse=True)
    return potential_collaborators

# Use the function
author = 'Joseph M. Hellerstein'
potential_collaborators = identify_potential_collaborators(network_author, author)
print(potential_collaborators)  # Print the potential collaborators for the author
# Out:
# [('Ramesh Govindan', 1), ('Alec Woo', 1)]

# %% [markdown]
# In the output [('Ramesh Govindan', 1), ('Alec Woo', 1)], the numbers represent the number of common neighbors that each potential collaborator shares with the given author ('Joseph M. Hellerstein').
#
# 1. 'Ramesh Govindan' shares 1 common neighbor with 'Joseph M. Hellerstein'.
# 2. 'Alec Woo' also shares 1 common neighbor with 'Joseph M. Hellerstein'.
#
# These numbers indicate the degree of connection or overlap between the given author and each potential collaborator within the collaboration network. In this context, a higher number of common neighbors suggests a stronger potential for collaboration and mutual interests between the author and the potential collaborator.

# %% [markdown]
# 1. **Facilitating Collaboration**: By identifying potential collaborators based on common neighbors in the collaboration network, the function helps authors or organizations identify individuals with whom they share connections or mutual interests. This facilitates the initiation of collaboration efforts, which can lead to joint research projects, publications, grant proposals, and other collaborative endeavors.
#
# 2. **Expanding Networks**: For researchers or organizations looking to expand their professional networks, the function offers a systematic approach to discovering new potential collaborators beyond their immediate circle. Engaging with these potential collaborators can lead to the exchange of ideas, access to new resources, and opportunities for interdisciplinary collaboration.
#
# 3. **Strategic Partnership Development**: For organizations or research institutions seeking to strategically develop partnerships, the function provides valuable insights into potential collaborators who may align with specific research priorities or strategic objectives. This information can inform partnership development strategies and help identify key stakeholders for collaboration initiatives.
#
# 5. **Efficient Resource Allocation**: By focusing on potential collaborators who share common neighbors with the given author, the function offers a targeted approach to resource allocation for collaboration outreach and engagement. Authors or organizations can prioritize efforts to establish connections with individuals who are more likely to have synergistic interests and collaborative potential.

# %% [markdown]
# ## 2. Full Data Top 3 Paper Author Network

# %% [markdown]
# ### Network Graph

# %%
# Read the CSV file into a pandas DataFrame
df_full = pd.read_csv('/Users/zy/Documents/GitHub/Social-Media-Analysis-Project/Group Project/Sample Top 20 & Full Top3/Citation Network/top_3_paper.csv', index_col=0)  # Assuming the first column contains the author names

network_author_top = construct_coauthorship_network(df_full)
visualize_network_with_plotly(network_author_top, node_size=5, title="Top 3 Paper Co-authorship Network", pos=nx.spring_layout(network_author_top, k=0.2, seed=42))

# %% [markdown]
# #### 2.1 Influencer Analysis

# %%
degree_centrality = calculate_degree_centrality(network_author_top)[:5]
closeness_centrality = calculate_closeness_centrality(network_author_top)[:5]
betweenness_centrality = calculate_betweenness_centrality(network_author_top)[:5]
eigenvector_centrality = calculate_igenvector_entrality(network_author_top)[:5]

# Create DataFrames
df_degree_centrality = pd.DataFrame(degree_centrality, columns=['Author', 'Degree Centrality'])
df_closeness_centrality = pd.DataFrame(closeness_centrality, columns=['Author', 'Closeness Centrality'])
df_betweenness_centrality = pd.DataFrame(betweenness_centrality, columns=['Author', 'Betweenness Centrality'])
df_eigenvector_centrality = pd.DataFrame(eigenvector_centrality, columns=['Author', 'Eigenvector Centrality'])

# %%
for i in (df_degree_centrality, df_closeness_centrality, df_betweenness_centrality, df_eigenvector_centrality):
    display(i)
# Out:
#                                Author  Degree Centrality
# 0                   Miodrag Potkonjak           0.005042
# 1  Alberto L. Sangiovanni-Vincentelli           0.003810
# 2                    Chung-Kuan Cheng           0.003025
# 3                Gerhard J. Woeginger           0.002913
# 4                      Rajeev Rastogi           0.002465
#                       Author  Closeness Centrality
# 0  Christos H. Papadimitriou              0.028636
# 1            Esther M. Arkin              0.028314
# 2           Sándor P. Fekete              0.027934
# 3         Mihalis Yannakakis              0.027591
# 4               Sudipto Guha              0.027588
#                                Author  Betweenness Centrality
# 0           Christos H. Papadimitriou                0.016319
# 1                    Sándor P. Fekete                0.014304
# 2                     Esther M. Arkin                0.012581
# 3                  Mihalis Yannakakis                0.012539
# 4  Alberto L. Sangiovanni-Vincentelli                0.012178
#              Author  Eigenvector Centrality
# 0      John Derrick                0.265659
# 1  Rance Cleaveland                0.265571
# 2    Gerald Lüttgen                0.257847
# 3     Hussein Zedan                0.256773
# 4   Marian Gheorghe                0.256773

# %% [markdown]
# 1. **Miodrag Potkonjak** has the highest degree centrality, indicating that they are connected to a relatively large number of other authors in the network. This suggests that Miodrag Potkonjak may be actively collaborating with many other researchers.
#
# 2. **Christos H. Papadimitriou** has the highest closeness centrality, implying that they are relatively close to other authors in terms of network distance. This could indicate that Christos H. Papadimitriou has efficient access to information and resources within the network.
#
# 3. **Christos H. Papadimitriou** also has the highest betweenness centrality, indicating that they act as a bridge between different groups of authors in the network. This suggests that Christos H. Papadimitriou may play a critical role in facilitating communication and collaboration between different research communities.
#
# 4. **John Derrick** has the highest eigenvector centrality, suggesting that they are connected to other influential authors in the network. This implies that John Derrick may have a significant influence within the research community represented by the network.

# %% [markdown]
# #### 2.2 Community Detection

# %%
# Compute community statistics
partition = community.best_partition(network_author_top.to_undirected())
community_stats = compute_community_statistics(network_author_top, partition)

# Print insightful information for each community
for community_id, stats in community_stats.items():
    print(f"Community {community_id} Statistics:")
    for metric, value in stats.items():
        print(f"- {metric}: {value}")
    print()
# Out:
# Community 0 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 10
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 5
#
# Community 1 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 4
# - Average Closeness Centrality: 0.775
# - Average Betweenness Centrality: 0.16666666666666666
# - Community Size: 4
#
# Community 2 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 10
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 5
#
# Community 3 Statistics:
# - Average Degree Centrality: 0.027797576621525304
# - Collaboration Count: 468
# - Average Closeness Centrality: 0.2196183574060138
# - Average Betweenness Centrality: 0.020753865996203845
# - Community Size: 184
#
# Community 4 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 5 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 6 Statistics:
# - Average Degree Centrality: 0.37777777777777777
# - Collaboration Count: 17
# - Average Closeness Centrality: 0.5917805878332195
# - Average Betweenness Centrality: 0.09444444444444444
# - Community Size: 10
#
# Community 7 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 8 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 9 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 10 Statistics:
# - Average Degree Centrality: 0.38181818181818183
# - Collaboration Count: 21
# - Average Closeness Centrality: 0.5423438868414945
# - Average Betweenness Centrality: 0.098989898989899
# - Community Size: 11
#
# Community 11 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 12 Statistics:
# - Average Degree Centrality: 0.04002998500749626
# - Collaboration Count: 267
# - Average Closeness Centrality: 0.18929101162595538
# - Average Betweenness Centrality: 0.03925537231384307
# - Community Size: 116
#
# Community 13 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 14 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 15 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 16 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 17 Statistics:
# - Average Degree Centrality: 0.6
# - Collaboration Count: 9
# - Average Closeness Centrality: 0.7321428571428572
# - Average Betweenness Centrality: 0.10000000000000002
# - Community Size: 6
#
# Community 18 Statistics:
# - Average Degree Centrality: 0.02845657463239184
# - Collaboration Count: 269
# - Average Closeness Centrality: 0.18017989730035952
# - Average Betweenness Centrality: 0.03570761849646238
# - Community Size: 138
#
# Community 19 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 45 Statistics:
# - Average Degree Centrality: 0.033719845395175266
# - Collaboration Count: 253
# - Average Closeness Centrality: 0.21347989132309309
# - Average Betweenness Centrality: 0.031715137636405495
# - Community Size: 123
#
# Community 21 Statistics:
# - Average Degree Centrality: 0.4666666666666666
# - Collaboration Count: 21
# - Average Closeness Centrality: 0.6568942628578851
# - Average Betweenness Centrality: 0.07222222222222222
# - Community Size: 10
#
# Community 411 Statistics:
# - Average Degree Centrality: 0.04847963281698223
# - Collaboration Count: 169
# - Average Closeness Centrality: 0.22267592295036073
# - Average Betweenness Centrality: 0.04437960902844829
# - Community Size: 84
#
# Community 23 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 10
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 5
#
# Community 24 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 25 Statistics:
# - Average Degree Centrality: 0.21818181818181823
# - Collaboration Count: 12
# - Average Closeness Centrality: 0.47771472693102784
# - Average Betweenness Centrality: 0.13131313131313133
# - Community Size: 11
#
# Community 27 Statistics:
# - Average Degree Centrality: 0.3047619047619047
# - Collaboration Count: 32
# - Average Closeness Centrality: 0.5139583686250353
# - Average Betweenness Centrality: 0.0783882783882784
# - Community Size: 15
#
# Community 28 Statistics:
# - Average Degree Centrality: 0.5555555555555556
# - Collaboration Count: 25
# - Average Closeness Centrality: 0.6607650501672241
# - Average Betweenness Centrality: 0.07222222222222222
# - Community Size: 10
#
# Community 29 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 30 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 2
# - Average Closeness Centrality: 0.7777777777777777
# - Average Betweenness Centrality: 0.3333333333333333
# - Community Size: 3
#
# Community 31 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 32 Statistics:
# - Average Degree Centrality: 0.8055555555555556
# - Collaboration Count: 29
# - Average Closeness Centrality: 0.8617283950617283
# - Average Betweenness Centrality: 0.027777777777777776
# - Community Size: 9
#
# Community 33 Statistics:
# - Average Degree Centrality: 0.5238095238095238
# - Collaboration Count: 11
# - Average Closeness Centrality: 0.6976190476190476
# - Average Betweenness Centrality: 0.09523809523809523
# - Community Size: 7
#
# Community 34 Statistics:
# - Average Degree Centrality: 0.20952380952380956
# - Collaboration Count: 22
# - Average Closeness Centrality: 0.38146237679380307
# - Average Betweenness Centrality: 0.1347985347985348
# - Community Size: 15
#
# Community 35 Statistics:
# - Average Degree Centrality: 0.5555555555555556
# - Collaboration Count: 20
# - Average Closeness Centrality: 0.7037037037037037
# - Average Betweenness Centrality: 0.06349206349206349
# - Community Size: 9
#
# Community 36 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 37 Statistics:
# - Average Degree Centrality: 0.8888888888888888
# - Collaboration Count: 32
# - Average Closeness Centrality: 0.911111111111111
# - Average Betweenness Centrality: 0.015873015873015872
# - Community Size: 9
#
# Community 38 Statistics:
# - Average Degree Centrality: 0.0539947322212467
# - Collaboration Count: 123
# - Average Closeness Centrality: 0.29251125516006277
# - Average Betweenness Centrality: 0.0383510256205603
# - Community Size: 68
#
# Community 71 Statistics:
# - Average Degree Centrality: 0.026225387515710095
# - Collaboration Count: 313
# - Average Closeness Centrality: 0.1829261413215265
# - Average Betweenness Centrality: 0.030719228062681573
# - Community Size: 155
#
# Community 40 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 41 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 42 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 43 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 44 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 46 Statistics:
# - Average Degree Centrality: 0.7333333333333334
# - Collaboration Count: 11
# - Average Closeness Centrality: 0.8148148148148149
# - Average Betweenness Centrality: 0.06666666666666667
# - Community Size: 6
#
# Community 47 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 48 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 49 Statistics:
# - Average Degree Centrality: 0.11822660098522167
# - Collaboration Count: 48
# - Average Closeness Centrality: 0.34527467659191385
# - Average Betweenness Centrality: 0.07361795292829776
# - Community Size: 29
#
# Community 50 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 51 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 52 Statistics:
# - Average Degree Centrality: 0.07738095238095237
# - Collaboration Count: 156
# - Average Closeness Centrality: 0.29155119529117246
# - Average Betweenness Centrality: 0.04111463133640553
# - Community Size: 64
#
# Community 53 Statistics:
# - Average Degree Centrality: 0.5714285714285714
# - Collaboration Count: 16
# - Average Closeness Centrality: 0.7136363636363636
# - Average Betweenness Centrality: 0.07142857142857142
# - Community Size: 8
#
# Community 54 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 55 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 56 Statistics:
# - Average Degree Centrality: 0.6
# - Collaboration Count: 6
# - Average Closeness Centrality: 0.7409523809523809
# - Average Betweenness Centrality: 0.13333333333333333
# - Community Size: 5
#
# Community 57 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 22 Statistics:
# - Average Degree Centrality: 0.13960113960113962
# - Collaboration Count: 49
# - Average Closeness Centrality: 0.35227747456545516
# - Average Betweenness Centrality: 0.07897435897435898
# - Community Size: 27
#
# Community 59 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 60 Statistics:
# - Average Degree Centrality: 0.22727272727272727
# - Collaboration Count: 15
# - Average Closeness Centrality: 0.4725596185767755
# - Average Betweenness Centrality: 0.11969696969696969
# - Community Size: 12
#
# Community 61 Statistics:
# - Average Degree Centrality: 0.47619047619047616
# - Collaboration Count: 10
# - Average Closeness Centrality: 0.6217687074829933
# - Average Betweenness Centrality: 0.13333333333333333
# - Community Size: 7
#
# Community 62 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 226 Statistics:
# - Average Degree Centrality: 0.037690457097032885
# - Collaboration Count: 141
# - Average Closeness Centrality: 0.17695288216076904
# - Average Betweenness Centrality: 0.05743352673868264
# - Community Size: 87
#
# Community 64 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 65 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 66 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 67 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 68 Statistics:
# - Average Degree Centrality: 0.8222222222222222
# - Collaboration Count: 37
# - Average Closeness Centrality: 0.8729411764705883
# - Average Betweenness Centrality: 0.02222222222222222
# - Community Size: 10
#
# Community 69 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 70 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 72 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 73 Statistics:
# - Average Degree Centrality: 0.4
# - Collaboration Count: 22
# - Average Closeness Centrality: 0.6415252703952394
# - Average Betweenness Centrality: 0.06666666666666667
# - Community Size: 11
#
# Community 74 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 21
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 7
#
# Community 75 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 76 Statistics:
# - Average Degree Centrality: 0.6
# - Collaboration Count: 6
# - Average Closeness Centrality: 0.7409523809523809
# - Average Betweenness Centrality: 0.13333333333333333
# - Community Size: 5
#
# Community 77 Statistics:
# - Average Degree Centrality: 0.6
# - Collaboration Count: 6
# - Average Closeness Centrality: 0.7333333333333333
# - Average Betweenness Centrality: 0.13333333333333333
# - Community Size: 5
#
# Community 78 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 79 Statistics:
# - Average Degree Centrality: 0.14736842105263157
# - Collaboration Count: 28
# - Average Closeness Centrality: 0.3717678791641711
# - Average Betweenness Centrality: 0.09912280701754386
# - Community Size: 20
#
# Community 80 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 81 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 82 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 83 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 84 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 85 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 86 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 87 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 88 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 89 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 90 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 91 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 92 Statistics:
# - Average Degree Centrality: 0.03483870967741935
# - Collaboration Count: 270
# - Average Closeness Centrality: 0.2197187003386544
# - Average Betweenness Centrality: 0.03060162601626016
# - Community Size: 125
#
# Community 93 Statistics:
# - Average Degree Centrality: 0.3611111111111111
# - Collaboration Count: 13
# - Average Closeness Centrality: 0.5457327712229674
# - Average Betweenness Centrality: 0.12698412698412698
# - Community Size: 9
#
# Community 94 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 95 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 96 Statistics:
# - Average Degree Centrality: 0.28787878787878785
# - Collaboration Count: 19
# - Average Closeness Centrality: 0.5277231121281464
# - Average Betweenness Centrality: 0.09545454545454546
# - Community Size: 12
#
# Community 97 Statistics:
# - Average Degree Centrality: 0.0531883632089333
# - Collaboration Count: 181
# - Average Closeness Centrality: 0.21802426487639714
# - Average Betweenness Centrality: 0.04707901162010281
# - Community Size: 83
#
# Community 98 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 99 Statistics:
# - Average Degree Centrality: 0.3088235294117647
# - Collaboration Count: 42
# - Average Closeness Centrality: 0.4176142755411378
# - Average Betweenness Centrality: 0.09999999999999999
# - Community Size: 17
#
# Community 100 Statistics:
# - Average Degree Centrality: 0.7333333333333334
# - Collaboration Count: 11
# - Average Closeness Centrality: 0.8095238095238096
# - Average Betweenness Centrality: 0.06666666666666667
# - Community Size: 6
#
# Community 101 Statistics:
# - Average Degree Centrality: 0.09426847662141777
# - Collaboration Count: 125
# - Average Closeness Centrality: 0.39868308422022697
# - Average Betweenness Centrality: 0.03158371040723982
# - Community Size: 52
#
# Community 102 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 4
# - Average Closeness Centrality: 0.775
# - Average Betweenness Centrality: 0.16666666666666666
# - Community Size: 4
#
# Community 103 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 4
# - Average Closeness Centrality: 0.775
# - Average Betweenness Centrality: 0.16666666666666666
# - Community Size: 4
#
# Community 104 Statistics:
# - Average Degree Centrality: 0.16781609195402297
# - Collaboration Count: 73
# - Average Closeness Centrality: 0.3800706100142656
# - Average Betweenness Centrality: 0.061247947454844014
# - Community Size: 30
#
# Community 105 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 106 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 107 Statistics:
# - Average Degree Centrality: 0.23333333333333334
# - Collaboration Count: 28
# - Average Closeness Centrality: 0.38871121912608986
# - Average Betweenness Centrality: 0.11845238095238096
# - Community Size: 16
#
# Community 109 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 110 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 111 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 112 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 113 Statistics:
# - Average Degree Centrality: 0.12392156862745099
# - Collaboration Count: 158
# - Average Closeness Centrality: 0.3909431988034112
# - Average Betweenness Centrality: 0.0346218487394958
# - Community Size: 51
#
# Community 114 Statistics:
# - Average Degree Centrality: 0.0314987885081343
# - Collaboration Count: 182
# - Average Closeness Centrality: 0.15123720141052518
# - Average Betweenness Centrality: 0.05511634893578113
# - Community Size: 108
#
# Community 115 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 116 Statistics:
# - Average Degree Centrality: 0.7333333333333334
# - Collaboration Count: 11
# - Average Closeness Centrality: 0.8148148148148149
# - Average Betweenness Centrality: 0.06666666666666667
# - Community Size: 6
#
# Community 117 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 118 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 119 Statistics:
# - Average Degree Centrality: 0.5
# - Collaboration Count: 5
# - Average Closeness Centrality: 0.6533333333333333
# - Average Betweenness Centrality: 0.2
# - Community Size: 5
#
# Community 120 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 121 Statistics:
# - Average Degree Centrality: 0.5714285714285714
# - Collaboration Count: 16
# - Average Closeness Centrality: 0.7136363636363636
# - Average Betweenness Centrality: 0.07142857142857142
# - Community Size: 8
#
# Community 122 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 123 Statistics:
# - Average Degree Centrality: 0.11582491582491579
# - Collaboration Count: 172
# - Average Closeness Centrality: 0.2289486192761016
# - Average Betweenness Centrality: 0.06651419858967028
# - Community Size: 55
#
# Community 124 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 125 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 126 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 127 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 581 Statistics:
# - Average Degree Centrality: 0.023323013415892675
# - Collaboration Count: 339
# - Average Closeness Centrality: 0.18660456724889615
# - Average Betweenness Centrality: 0.026728789719978094
# - Community Size: 171
#
# Community 129 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 130 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 10
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 5
#
# Community 131 Statistics:
# - Average Degree Centrality: 0.6
# - Collaboration Count: 9
# - Average Closeness Centrality: 0.7321428571428572
# - Average Betweenness Centrality: 0.10000000000000002
# - Community Size: 6
#
# Community 132 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 55
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 11
#
# Community 133 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 134 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 135 Statistics:
# - Average Degree Centrality: 0.4222222222222222
# - Collaboration Count: 19
# - Average Closeness Centrality: 0.6512790885585003
# - Average Betweenness Centrality: 0.07222222222222222
# - Community Size: 10
#
# Community 136 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 137 Statistics:
# - Average Degree Centrality: 0.6181818181818183
# - Collaboration Count: 34
# - Average Closeness Centrality: 0.7408473879062115
# - Average Betweenness Centrality: 0.04242424242424243
# - Community Size: 11
#
# Community 138 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 139 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 140 Statistics:
# - Average Degree Centrality: 0.5333333333333333
# - Collaboration Count: 8
# - Average Closeness Centrality: 0.625
# - Average Betweenness Centrality: 0.16666666666666666
# - Community Size: 6
#
# Community 141 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 142 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 143 Statistics:
# - Average Degree Centrality: 0.5
# - Collaboration Count: 5
# - Average Closeness Centrality: 0.6107936507936508
# - Average Betweenness Centrality: 0.2333333333333333
# - Community Size: 5
#
# Community 144 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 15
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 6
#
# Community 145 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 2
# - Average Closeness Centrality: 0.7777777777777777
# - Average Betweenness Centrality: 0.3333333333333333
# - Community Size: 3
#
# Community 146 Statistics:
# - Average Degree Centrality: 0.23076923076923078
# - Collaboration Count: 18
# - Average Closeness Centrality: 0.4293314089448345
# - Average Betweenness Centrality: 0.12937062937062938
# - Community Size: 13
#
# Community 147 Statistics:
# - Average Degree Centrality: 0.2857142857142857
# - Collaboration Count: 8
# - Average Closeness Centrality: 0.4789828431372549
# - Average Betweenness Centrality: 0.1964285714285714
# - Community Size: 8
#
# Community 148 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 149 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 150 Statistics:
# - Average Degree Centrality: 0.07764705882352943
# - Collaboration Count: 99
# - Average Closeness Centrality: 0.22148879693645046
# - Average Betweenness Centrality: 0.0754701880752301
# - Community Size: 51
#
# Community 151 Statistics:
# - Average Degree Centrality: 0.14285714285714285
# - Collaboration Count: 58
# - Average Closeness Centrality: 0.3582276559645308
# - Average Betweenness Centrality: 0.06914796569968983
# - Community Size: 29
#
# Community 152 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 153 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 10
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 5
#
# Community 154 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 155 Statistics:
# - Average Degree Centrality: 0.4222222222222222
# - Collaboration Count: 19
# - Average Closeness Centrality: 0.586048951048951
# - Average Betweenness Centrality: 0.09444444444444444
# - Community Size: 10
#
# Community 156 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 157 Statistics:
# - Average Degree Centrality: 0.17195767195767195
# - Collaboration Count: 65
# - Average Closeness Centrality: 0.33866797817136735
# - Average Betweenness Centrality: 0.07794057794057795
# - Community Size: 28
#
# Community 158 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 159 Statistics:
# - Average Degree Centrality: 0.2761904761904762
# - Collaboration Count: 29
# - Average Closeness Centrality: 0.4851467280970822
# - Average Betweenness Centrality: 0.08498168498168497
# - Community Size: 15
#
# Community 160 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 161 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 10
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 5
#
# Community 162 Statistics:
# - Average Degree Centrality: 0.06386946386946388
# - Collaboration Count: 137
# - Average Closeness Centrality: 0.2658694819134134
# - Average Betweenness Centrality: 0.04569493006993008
# - Community Size: 66
#
# Community 163 Statistics:
# - Average Degree Centrality: 0.4722222222222222
# - Collaboration Count: 17
# - Average Closeness Centrality: 0.6717948717948719
# - Average Betweenness Centrality: 0.07539682539682539
# - Community Size: 9
#
# Community 164 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 165 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 166 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 4
# - Average Closeness Centrality: 0.775
# - Average Betweenness Centrality: 0.16666666666666666
# - Community Size: 4
#
# Community 167 Statistics:
# - Average Degree Centrality: 0.10795454545454546
# - Collaboration Count: 57
# - Average Closeness Centrality: 0.2678011685895738
# - Average Betweenness Centrality: 0.09194770283479961
# - Community Size: 33
#
# Community 168 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 170 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 171 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 172 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 173 Statistics:
# - Average Degree Centrality: 0.34848484848484845
# - Collaboration Count: 23
# - Average Closeness Centrality: 0.5888687099700527
# - Average Betweenness Centrality: 0.07727272727272727
# - Community Size: 12
#
# Community 174 Statistics:
# - Average Degree Centrality: 0.4722222222222222
# - Collaboration Count: 17
# - Average Closeness Centrality: 0.6717948717948717
# - Average Betweenness Centrality: 0.07539682539682539
# - Community Size: 9
#
# Community 175 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 176 Statistics:
# - Average Degree Centrality: 0.2857142857142857
# - Collaboration Count: 26
# - Average Closeness Centrality: 0.544906355248972
# - Average Betweenness Centrality: 0.07417582417582416
# - Community Size: 14
#
# Community 177 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 179 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 28
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 8
#
# Community 180 Statistics:
# - Average Degree Centrality: 0.7
# - Collaboration Count: 7
# - Average Closeness Centrality: 0.7942857142857143
# - Average Betweenness Centrality: 0.1
# - Community Size: 5
#
# Community 181 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 2
# - Average Closeness Centrality: 0.7777777777777777
# - Average Betweenness Centrality: 0.3333333333333333
# - Community Size: 3
#
# Community 182 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 183 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 184 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 185 Statistics:
# - Average Degree Centrality: 0.10924369747899158
# - Collaboration Count: 65
# - Average Closeness Centrality: 0.3179807775119679
# - Average Betweenness Centrality: 0.06824548001018588
# - Community Size: 35
#
# Community 186 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 187 Statistics:
# - Average Degree Centrality: 0.6
# - Collaboration Count: 9
# - Average Closeness Centrality: 0.7321428571428572
# - Average Betweenness Centrality: 0.10000000000000002
# - Community Size: 6
#
# Community 188 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 4
# - Average Closeness Centrality: 0.775
# - Average Betweenness Centrality: 0.16666666666666666
# - Community Size: 4
#
# Community 189 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 190 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 21
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 7
#
# Community 191 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 192 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 193 Statistics:
# - Average Degree Centrality: 0.3636363636363636
# - Collaboration Count: 24
# - Average Closeness Centrality: 0.546364150539119
# - Average Betweenness Centrality: 0.0909090909090909
# - Community Size: 12
#
# Community 194 Statistics:
# - Average Degree Centrality: 0.49999999999999994
# - Collaboration Count: 3
# - Average Closeness Centrality: 0.625
# - Average Betweenness Centrality: 0.3333333333333333
# - Community Size: 4
#
# Community 195 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 196 Statistics:
# - Average Degree Centrality: 0.15579710144927536
# - Collaboration Count: 43
# - Average Closeness Centrality: 0.37895454606139795
# - Average Betweenness Centrality: 0.07888669301712779
# - Community Size: 24
#
# Community 197 Statistics:
# - Average Degree Centrality: 0.3333333333333333
# - Collaboration Count: 12
# - Average Closeness Centrality: 0.547442680776014
# - Average Betweenness Centrality: 0.12698412698412698
# - Community Size: 9
#
# Community 198 Statistics:
# - Average Degree Centrality: 0.4166666666666667
# - Collaboration Count: 15
# - Average Closeness Centrality: 0.5888020476255771
# - Average Betweenness Centrality: 0.10714285714285714
# - Community Size: 9
#
# Community 199 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 200 Statistics:
# - Average Degree Centrality: 0.5
# - Collaboration Count: 5
# - Average Closeness Centrality: 0.6533333333333333
# - Average Betweenness Centrality: 0.2
# - Community Size: 5
#
# Community 201 Statistics:
# - Average Degree Centrality: 0.7142857142857143
# - Collaboration Count: 15
# - Average Closeness Centrality: 0.7976190476190476
# - Average Betweenness Centrality: 0.05714285714285715
# - Community Size: 7
#
# Community 202 Statistics:
# - Average Degree Centrality: 0.303030303030303
# - Collaboration Count: 20
# - Average Closeness Centrality: 0.5294202898550725
# - Average Betweenness Centrality: 0.09696969696969697
# - Community Size: 12
#
# Community 203 Statistics:
# - Average Degree Centrality: 0.5333333333333333
# - Collaboration Count: 8
# - Average Closeness Centrality: 0.708994708994709
# - Average Betweenness Centrality: 0.11666666666666668
# - Community Size: 6
#
# Community 204 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 205 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 206 Statistics:
# - Average Degree Centrality: 0.7333333333333334
# - Collaboration Count: 11
# - Average Closeness Centrality: 0.8148148148148149
# - Average Betweenness Centrality: 0.06666666666666667
# - Community Size: 6
#
# Community 207 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 208 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 209 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 210 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 211 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 212 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 213 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 214 Statistics:
# - Average Degree Centrality: 0.33333333333333337
# - Collaboration Count: 15
# - Average Closeness Centrality: 0.5839448051948052
# - Average Betweenness Centrality: 0.09722222222222222
# - Community Size: 10
#
# Community 215 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 4
# - Average Closeness Centrality: 0.775
# - Average Betweenness Centrality: 0.16666666666666666
# - Community Size: 4
#
# Community 216 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 217 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 2
# - Average Closeness Centrality: 0.7777777777777777
# - Average Betweenness Centrality: 0.3333333333333333
# - Community Size: 3
#
# Community 218 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 219 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 2
# - Average Closeness Centrality: 0.7777777777777777
# - Average Betweenness Centrality: 0.3333333333333333
# - Community Size: 3
#
# Community 220 Statistics:
# - Average Degree Centrality: 0.4642857142857143
# - Collaboration Count: 13
# - Average Closeness Centrality: 0.6294034090909091
# - Average Betweenness Centrality: 0.10714285714285714
# - Community Size: 8
#
# Community 221 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 4
# - Average Closeness Centrality: 0.775
# - Average Betweenness Centrality: 0.16666666666666666
# - Community Size: 4
#
# Community 222 Statistics:
# - Average Degree Centrality: 0.5714285714285714
# - Collaboration Count: 16
# - Average Closeness Centrality: 0.7136363636363636
# - Average Betweenness Centrality: 0.07142857142857142
# - Community Size: 8
#
# Community 223 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 4
# - Average Closeness Centrality: 0.775
# - Average Betweenness Centrality: 0.16666666666666666
# - Community Size: 4
#
# Community 224 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 225 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 227 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 228 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 229 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 230 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 231 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 21
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 7
#
# Community 232 Statistics:
# - Average Degree Centrality: 0.19117647058823528
# - Collaboration Count: 26
# - Average Closeness Centrality: 0.45472408470611697
# - Average Betweenness Centrality: 0.08529411764705881
# - Community Size: 17
#
# Community 233 Statistics:
# - Average Degree Centrality: 0.2287581699346405
# - Collaboration Count: 35
# - Average Closeness Centrality: 0.5089136107284028
# - Average Betweenness Centrality: 0.06535947712418301
# - Community Size: 18
#
# Community 234 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 235 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 4
# - Average Closeness Centrality: 0.775
# - Average Betweenness Centrality: 0.16666666666666666
# - Community Size: 4
#
# Community 236 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 2
# - Average Closeness Centrality: 0.7777777777777777
# - Average Betweenness Centrality: 0.3333333333333333
# - Community Size: 3
#
# Community 237 Statistics:
# - Average Degree Centrality: 0.6666666666666666
# - Collaboration Count: 4
# - Average Closeness Centrality: 0.775
# - Average Betweenness Centrality: 0.16666666666666666
# - Community Size: 4
#
# Community 238 Statistics:
# - Average Degree Centrality: 0.7999999999999999
# - Collaboration Count: 12
# - Average Closeness Centrality: 0.8541666666666666
# - Average Betweenness Centrality: 0.05000000000000001
# - Community Size: 6
#
# Community 239 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 10
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 5
#
# Community 240 Statistics:
# - Average Degree Centrality: 0.7
# - Collaboration Count: 7
# - Average Closeness Centrality: 0.7942857142857143
# - Average Betweenness Centrality: 0.1
# - Community Size: 5
#
# Community 241 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 242 Statistics:
# - Average Degree Centrality: 0.7333333333333333
# - Collaboration Count: 11
# - Average Closeness Centrality: 0.8148148148148148
# - Average Betweenness Centrality: 0.06666666666666667
# - Community Size: 6
#
# Community 243 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 370 Statistics:
# - Average Degree Centrality: 0.03751803751803752
# - Collaboration Count: 182
# - Average Closeness Centrality: 0.1757445722599028
# - Average Betweenness Centrality: 0.050887584024550146
# - Community Size: 99
#
# Community 246 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 247 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 6
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 4
#
# Community 248 Statistics:
# - Average Degree Centrality: 0.6
# - Collaboration Count: 6
# - Average Closeness Centrality: 0.7333333333333332
# - Average Betweenness Centrality: 0.13333333333333333
# - Community Size: 5
#
# Community 249 Statistics:
# - Average Degree Centrality: 0.9333333333333332
# - Collaboration Count: 14
# - Average Closeness Centrality: 0.9444444444444445
# - Average Betweenness Centrality: 0.016666666666666666
# - Community Size: 6
#
# Community 250 Statistics:
# - Average Degree Centrality: 1.0
# ...
# Community 2180 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2181 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2182 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2183 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2184 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2185 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 2186 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2187 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2188 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 2189 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2190 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 3
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 3
#
# Community 2191 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2192 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 2193 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 2194 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2195 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2196 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2197 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2198 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2199 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2200 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2201 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2202 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2203 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 2204 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 2205 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2206 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2207 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2208 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 2209 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2210 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2211 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2212 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2213 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2214 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2215 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2216 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2217 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2218 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2219 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2220 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2221 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2222 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2223 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2224 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2225 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2226 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2227 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2228 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2229 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2230 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2231 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2232 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2233 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2234 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2235 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2236 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2237 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2238 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2239 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2240 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2241 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2242 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2243 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2244 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2245 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 2246 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2247 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 2248 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 2249 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2250 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 1
# - Average Closeness Centrality: 1.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 2
#
# Community 2251 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2252 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2253 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 2254 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 128 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 865 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 58 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 838 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 39 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 169 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 108 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 750 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 178 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 20 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 244 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 245 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 26 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1
#
# Community 63 Statistics:
# - Average Degree Centrality: 1.0
# - Collaboration Count: 0
# - Average Closeness Centrality: 0.0
# - Average Betweenness Centrality: 0.0
# - Community Size: 1

# %% [markdown]
# Community 0 appears to be a densely connected community within the network, with the following statistics:
#
# 1. **Average Degree Centrality**: The average degree centrality of 0.077 suggests that, on average, authors within this community collaborate with approximately 7.7 other authors. This indicates a relatively high level of collaboration within the community.
#
# 2. **Collaboration Count**: The community has been involved in a total of 156 collaborations. This indicates a high level of collaborative activity within the community.
#
# 3. **Average Closeness Centrality**: The average closeness centrality of 0.291 suggests that, on average, authors within this community are relatively close to each other in terms of network distance. This implies efficient communication and information flow within the community.
#
# 4. **Average Betweenness Centrality**: The average betweenness centrality of 0.041 suggests that, on average, authors within this community act as intermediaries or bridges between other authors in the network. This indicates that the community plays a significant role in facilitating communication and collaboration between different groups of authors.
#
# 5. **Community Size**: The community consists of 64 authors. This sizeable community suggests a substantial presence within the overall network.
#
# Overall, Community 0 appears to be a cohesive and influential group within the network, characterized by high levels of collaboration, efficient communication, and significant intermediary roles.

# %% [markdown]
# #### 2.3 Collaboration Pattern

# %%
# Use the function
collaboration_over_time = analyze_collaboration_over_time(df_full)

# Convert to DataFrame
collaboration_df = pd.DataFrame(columns=['Author 1', 'Author 2', 'Collaboration Years'])
rows = []
for collab, years in collaboration_over_time.items():
    author1, author2 = collab
    rows.append({'Author 1': author1, 'Author 2': author2, 'Collaboration Years': years})

collaboration_df = pd.concat([collaboration_df, pd.DataFrame(rows)], ignore_index=True)

# Print the collaboration patterns over time
print(collaboration_df)
# Out:
#                    Author 1          Author 2 Collaboration Years
# 0          David S. Johnson       M. R. Garey        [1979, 1983]
# 1      Charles E. Leiserson  Thomas H. Cormen              [1989]
# 2          Ronald L. Rivest  Thomas H. Cormen              [1989]
# 3      Charles E. Leiserson  Ronald L. Rivest              [1989]
# 4              Richard Hull   Serge Abiteboul        [1995, 1988]
# ...                     ...               ...                 ...
# 12729       Daniel Hausmann     Dennis Walter              [2009]
# 12730        Christoph Lüth     Holger Täubig              [2009]
# 12731        Christoph Lüth     Dennis Walter              [2009]
# 12732         Dennis Walter     Holger Täubig              [2009]
# 12733    Isabella Mastroeni     Musard Balliu              [2009]
#
# [12734 rows x 3 columns]

# %% [markdown]
# #### 2.4 Potential Collaboration

# %%
# Use the function
author = 'David S. Johnson'
potential_collaborators = identify_potential_collaborators(network_author_top, author)

# Convert potential collaborators to a DataFrame
potential_collaborators_df = pd.DataFrame(potential_collaborators, columns=['Potential Collaborator', 'Common Neighbors'])

# Print the potential collaborators in a more readable way
print("Potential Collaborators for", author)
print(potential_collaborators_df)
# Out:
# Potential Collaborators for David S. Johnson
#    Potential Collaborator  Common Neighbors
# 0         Edmund K. Burke                 1
# 1            Carol Meyers                 1
# 2             Anne Condon                 1
# 3         Joan Feigenbaum                 1
# 4           Bonnie Berger                 1
# 5        Mohamed Mostagir                 1
# 6           Diego Klabjan                 1
# 7       David Simchi-Levi                 1
# 8              Moshe Dror                 1
# 9              Nir Halman                 1
# 10           Carsten Lund                 1
